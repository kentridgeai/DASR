# %% [markdown]
# # DASR

# %%
import pandas as pd
from sklearn.metrics import mean_squared_error

def concordance_correlation_coefficient(y_true, y_pred):
    """Concordance correlation coefficient."""
    # Raw data
    dct = {
        'y_true': y_true,
        'y_pred': y_pred
    }
    df_others = pd.DataFrame(dct)
    # Remove NaNs
    df_others = df_others.dropna()
    # Pearson product-moment correlation coefficients
    y_true = df_others['y_true']
    y_pred = df_others['y_pred']
    cor = np.corrcoef(y_true, y_pred)[0][1]
    # Means
    mean_true = np.mean(y_true)
    mean_pred = np.mean(y_pred)
    # Population variances
    var_true = np.var(y_true)
    var_pred = np.var(y_pred)
    # Population standard deviations
    sd_true = np.std(y_true)
    sd_pred = np.std(y_pred)
    # Calculate CCC
    numerator = 2 * cor * sd_true * sd_pred
    denominator = var_true + var_pred + (mean_true - mean_pred)**2
    return numerator / denominator

def get_stats(string_name):
    print(mean_squared_error(df_others["mGFR"],df_others[string_name]), sum(np.equal(df_others["mGFR"]>60, df_others[string_name]>60)), concordance_correlation_coefficient(df_others["mGFR"],df_others[string_name]),
          sum((np.abs(df_others[string_name]-df_others["mGFR"])/df_others["mGFR"])<0.1),
          sum((np.abs(df_others[string_name]-df_others["mGFR"])/df_others["mGFR"])<0.3)
         )

# %%
from DASR import *
import numpy as np
from tqdm import tqdm
import pandas as pd
from collections.abc import Iterable

# %%
symbol_list = ["Pow","Add","Sub","Mul","Div","age","R","height","weight"]
orig = ("Add","Div","R","age","R")
orig2 = ("Add","Div","R","height","R")
orig3 = ("Add","Div","R","weight","R")
exp_set = []
for orig_eq in [orig,orig2,orig3]:
    for index1 in range(len(orig_eq)):
        for index2 in range(index1+1,len(orig_eq)):
            temp_list = list(orig_eq)
            for j in symbol_list:
                temp_list[index1] = j
                for k in symbol_list:
                    temp_list[index2] = k
                    exp_set.append(tuple(temp_list))    
exp_set = [tree_to_exp(kexp_to_tree(list(i)+["R"]*(max([len(i) for i in [orig,orig2,orig3]])+1))) for i in exp_set]
exp_set = sorted(set(exp_set))

# %%
exp_set
# Out:
# ['Add(Add(Add(R,R),R),R)',
#  'Add(Add(Add(R,R),age),R)',
#  'Add(Add(Add(R,R),height),R)',
#  'Add(Add(Add(R,R),weight),R)',
#  'Add(Add(Div(R,R),R),R)',
#  'Add(Add(Div(R,R),age),R)',
#  'Add(Add(Div(R,R),height),R)',
#  'Add(Add(Div(R,R),weight),R)',
#  'Add(Add(Mul(R,R),R),R)',
#  'Add(Add(Mul(R,R),age),R)',
#  'Add(Add(Mul(R,R),height),R)',
#  'Add(Add(Mul(R,R),weight),R)',
#  'Add(Add(Pow(R,R),R),R)',
#  'Add(Add(Pow(R,R),age),R)',
#  'Add(Add(Pow(R,R),height),R)',
#  'Add(Add(Pow(R,R),weight),R)',
#  'Add(Add(R,R),Div(Add(R,R),R))',
#  'Add(Add(R,R),Div(Div(R,R),R))',
#  'Add(Add(R,R),Div(Mul(R,R),R))',
#  'Add(Add(R,R),Div(Pow(R,R),R))',
#  'Add(Add(R,R),Div(R,R))',
#  'Add(Add(R,R),Div(Sub(R,R),R))',
#  'Add(Add(R,R),Div(age,Add(R,R)))',
#  'Add(Add(R,R),Div(age,Div(R,R)))',
#  'Add(Add(R,R),Div(age,Mul(R,R)))',
#  'Add(Add(R,R),Div(age,Pow(R,R)))',
#  'Add(Add(R,R),Div(age,R))',
#  'Add(Add(R,R),Div(age,Sub(R,R)))',
#  'Add(Add(R,R),Div(age,age))',
#  'Add(Add(R,R),Div(age,height))',
#  'Add(Add(R,R),Div(age,weight))',
#  'Add(Add(R,R),Div(height,Add(R,R)))',
#  'Add(Add(R,R),Div(height,Div(R,R)))',
#  'Add(Add(R,R),Div(height,Mul(R,R)))',
#  'Add(Add(R,R),Div(height,Pow(R,R)))',
#  'Add(Add(R,R),Div(height,R))',
#  'Add(Add(R,R),Div(height,Sub(R,R)))',
#  'Add(Add(R,R),Div(height,age))',
#  'Add(Add(R,R),Div(height,height))',
#  'Add(Add(R,R),Div(height,weight))',
#  'Add(Add(R,R),Div(weight,Add(R,R)))',
#  'Add(Add(R,R),Div(weight,Div(R,R)))',
#  'Add(Add(R,R),Div(weight,Mul(R,R)))',
#  'Add(Add(R,R),Div(weight,Pow(R,R)))',
#  'Add(Add(R,R),Div(weight,R))',
#  'Add(Add(R,R),Div(weight,Sub(R,R)))',
#  'Add(Add(R,R),Div(weight,age))',
#  'Add(Add(R,R),Div(weight,height))',
#  'Add(Add(R,R),Div(weight,weight))',
#  'Add(Add(R,R),Mul(R,age))',
#  'Add(Add(R,R),Mul(R,height))',
#  'Add(Add(R,R),Mul(R,weight))',
#  'Add(Add(R,R),Pow(age,R))',
#  'Add(Add(R,R),Pow(height,R))',
#  'Add(Add(R,R),Pow(weight,R))',
#  'Add(Add(R,R),R)',
#  'Add(Add(R,R),Sub(age,R))',
#  'Add(Add(R,R),Sub(height,R))',
#  'Add(Add(R,R),Sub(weight,R))',
#  'Add(Add(R,Sub(R,R)),R)',
#  'Add(Add(R,age),Add(R,R))',
#  'Add(Add(R,age),Div(R,R))',
#  'Add(Add(R,age),Mul(R,R))',
#  'Add(Add(R,age),Pow(R,R))',
#  'Add(Add(R,age),R)',
#  'Add(Add(R,age),Sub(R,R))',
#  'Add(Add(R,age),age)',
#  'Add(Add(R,age),height)',
#  'Add(Add(R,age),weight)',
#  'Add(Add(R,height),Add(R,R))',
#  'Add(Add(R,height),Div(R,R))',
#  'Add(Add(R,height),Mul(R,R))',
#  'Add(Add(R,height),Pow(R,R))',
#  'Add(Add(R,height),R)',
#  'Add(Add(R,height),Sub(R,R))',
#  'Add(Add(R,height),age)',
#  'Add(Add(R,height),height)',
#  'Add(Add(R,height),weight)',
#  'Add(Add(R,weight),Add(R,R))',
#  'Add(Add(R,weight),Div(R,R))',
#  'Add(Add(R,weight),Mul(R,R))',
#  'Add(Add(R,weight),Pow(R,R))',
#  'Add(Add(R,weight),R)',
#  'Add(Add(R,weight),Sub(R,R))',
#  'Add(Add(R,weight),age)',
#  'Add(Add(R,weight),height)',
#  'Add(Add(R,weight),weight)',
#  'Add(Add(Sub(R,R),age),R)',
#  'Add(Add(Sub(R,R),height),R)',
#  'Add(Add(Sub(R,R),weight),R)',
#  'Add(Add(age,age),R)',
#  'Add(Add(age,height),R)',
#  'Add(Add(age,weight),R)',
#  'Add(Add(height,height),R)',
#  'Add(Add(height,weight),R)',
#  'Add(Add(weight,weight),R)',
#  'Add(Div(Add(R,R),Add(R,R)),R)',
#  'Add(Div(Add(R,R),Div(R,R)),R)',
#  'Add(Div(Add(R,R),Mul(R,R)),R)',
#  'Add(Div(Add(R,R),Pow(R,R)),R)',
#  'Add(Div(Add(R,R),R),Div(R,R))',
#  'Add(Div(Add(R,R),R),Mul(R,R))',
#  'Add(Div(Add(R,R),R),Pow(R,R))',
#  'Add(Div(Add(R,R),R),R)',
#  'Add(Div(Add(R,R),R),Sub(R,R))',
#  'Add(Div(Add(R,R),R),age)',
#  'Add(Div(Add(R,R),R),height)',
#  'Add(Div(Add(R,R),R),weight)',
#  'Add(Div(Add(R,R),Sub(R,R)),R)',
#  'Add(Div(Add(R,R),age),R)',
#  'Add(Div(Add(R,R),height),R)',
#  'Add(Div(Add(R,R),weight),R)',
#  'Add(Div(Div(R,R),Add(R,R)),R)',
#  'Add(Div(Div(R,R),Div(R,R)),R)',
#  'Add(Div(Div(R,R),Mul(R,R)),R)',
#  'Add(Div(Div(R,R),Pow(R,R)),R)',
#  'Add(Div(Div(R,R),R),Div(R,R))',
#  'Add(Div(Div(R,R),R),Mul(R,R))',
#  'Add(Div(Div(R,R),R),Pow(R,R))',
#  'Add(Div(Div(R,R),R),R)',
#  'Add(Div(Div(R,R),R),Sub(R,R))',
#  'Add(Div(Div(R,R),R),age)',
#  'Add(Div(Div(R,R),R),height)',
#  'Add(Div(Div(R,R),R),weight)',
#  'Add(Div(Div(R,R),Sub(R,R)),R)',
#  'Add(Div(Div(R,R),age),R)',
#  'Add(Div(Div(R,R),height),R)',
#  'Add(Div(Div(R,R),weight),R)',
#  'Add(Div(Mul(R,R),Add(R,R)),R)',
#  'Add(Div(Mul(R,R),Div(R,R)),R)',
#  'Add(Div(Mul(R,R),Mul(R,R)),R)',
#  'Add(Div(Mul(R,R),Pow(R,R)),R)',
#  'Add(Div(Mul(R,R),R),Div(R,R))',
#  'Add(Div(Mul(R,R),R),Mul(R,R))',
#  'Add(Div(Mul(R,R),R),Pow(R,R))',
#  'Add(Div(Mul(R,R),R),R)',
#  'Add(Div(Mul(R,R),R),Sub(R,R))',
#  'Add(Div(Mul(R,R),R),age)',
#  'Add(Div(Mul(R,R),R),height)',
#  'Add(Div(Mul(R,R),R),weight)',
#  'Add(Div(Mul(R,R),Sub(R,R)),R)',
#  'Add(Div(Mul(R,R),age),R)',
#  'Add(Div(Mul(R,R),height),R)',
#  'Add(Div(Mul(R,R),weight),R)',
#  'Add(Div(Pow(R,R),Add(R,R)),R)',
#  'Add(Div(Pow(R,R),Div(R,R)),R)',
#  'Add(Div(Pow(R,R),Mul(R,R)),R)',
#  'Add(Div(Pow(R,R),Pow(R,R)),R)',
#  'Add(Div(Pow(R,R),R),Div(R,R))',
#  'Add(Div(Pow(R,R),R),Mul(R,R))',
#  'Add(Div(Pow(R,R),R),Pow(R,R))',
#  'Add(Div(Pow(R,R),R),R)',
#  'Add(Div(Pow(R,R),R),Sub(R,R))',
#  'Add(Div(Pow(R,R),R),age)',
#  'Add(Div(Pow(R,R),R),height)',
#  'Add(Div(Pow(R,R),R),weight)',
#  'Add(Div(Pow(R,R),Sub(R,R)),R)',
#  'Add(Div(Pow(R,R),age),R)',
#  'Add(Div(Pow(R,R),height),R)',
#  'Add(Div(Pow(R,R),weight),R)',
#  'Add(Div(R,Add(R,R)),R)',
#  'Add(Div(R,Div(R,R)),R)',
#  'Add(Div(R,Mul(R,R)),R)',
#  'Add(Div(R,Pow(R,R)),R)',
#  'Add(Div(R,R),Div(R,R))',
#  'Add(Div(R,R),Mul(R,R))',
#  'Add(Div(R,R),Mul(R,age))',
#  'Add(Div(R,R),Mul(R,height))',
#  'Add(Div(R,R),Mul(R,weight))',
#  'Add(Div(R,R),Pow(R,R))',
#  'Add(Div(R,R),Pow(age,R))',
#  'Add(Div(R,R),Pow(height,R))',
#  'Add(Div(R,R),Pow(weight,R))',
#  'Add(Div(R,R),R)',
#  'Add(Div(R,R),Sub(R,R))',
#  'Add(Div(R,R),Sub(age,R))',
#  'Add(Div(R,R),Sub(height,R))',
#  'Add(Div(R,R),Sub(weight,R))',
#  'Add(Div(R,R),age)',
#  'Add(Div(R,R),height)',
#  'Add(Div(R,R),weight)',
#  'Add(Div(R,Sub(R,R)),R)',
#  'Add(Div(R,age),R)',
#  'Add(Div(R,height),R)',
#  'Add(Div(R,weight),R)',
#  'Add(Div(Sub(R,R),Add(R,R)),R)',
#  'Add(Div(Sub(R,R),Div(R,R)),R)',
#  'Add(Div(Sub(R,R),Mul(R,R)),R)',
#  'Add(Div(Sub(R,R),Pow(R,R)),R)',
#  'Add(Div(Sub(R,R),R),Div(R,R))',
#  'Add(Div(Sub(R,R),R),Mul(R,R))',
#  'Add(Div(Sub(R,R),R),Pow(R,R))',
#  'Add(Div(Sub(R,R),R),R)',
#  'Add(Div(Sub(R,R),R),Sub(R,R))',
#  'Add(Div(Sub(R,R),R),age)',
#  'Add(Div(Sub(R,R),R),height)',
#  'Add(Div(Sub(R,R),R),weight)',
#  'Add(Div(Sub(R,R),Sub(R,R)),R)',
#  'Add(Div(Sub(R,R),age),R)',
#  'Add(Div(Sub(R,R),height),R)',
#  'Add(Div(Sub(R,R),weight),R)',
#  'Add(Div(age,Add(R,R)),Div(R,R))',
#  'Add(Div(age,Add(R,R)),Mul(R,R))',
#  'Add(Div(age,Add(R,R)),Pow(R,R))',
#  'Add(Div(age,Add(R,R)),R)',
#  'Add(Div(age,Add(R,R)),Sub(R,R))',
#  'Add(Div(age,Add(R,R)),age)',
#  'Add(Div(age,Add(R,R)),height)',
#  'Add(Div(age,Add(R,R)),weight)',
#  'Add(Div(age,Div(R,R)),Div(R,R))',
#  'Add(Div(age,Div(R,R)),Mul(R,R))',
#  'Add(Div(age,Div(R,R)),Pow(R,R))',
#  'Add(Div(age,Div(R,R)),R)',
#  'Add(Div(age,Div(R,R)),Sub(R,R))',
#  'Add(Div(age,Div(R,R)),age)',
#  'Add(Div(age,Div(R,R)),height)',
#  'Add(Div(age,Div(R,R)),weight)',
#  'Add(Div(age,Mul(R,R)),Div(R,R))',
#  'Add(Div(age,Mul(R,R)),Mul(R,R))',
#  'Add(Div(age,Mul(R,R)),Pow(R,R))',
#  'Add(Div(age,Mul(R,R)),R)',
#  'Add(Div(age,Mul(R,R)),Sub(R,R))',
#  'Add(Div(age,Mul(R,R)),age)',
#  'Add(Div(age,Mul(R,R)),height)',
#  'Add(Div(age,Mul(R,R)),weight)',
#  'Add(Div(age,Pow(R,R)),Div(R,R))',
#  'Add(Div(age,Pow(R,R)),Mul(R,R))',
#  'Add(Div(age,Pow(R,R)),Pow(R,R))',
#  'Add(Div(age,Pow(R,R)),R)',
#  'Add(Div(age,Pow(R,R)),Sub(R,R))',
#  'Add(Div(age,Pow(R,R)),age)',
#  'Add(Div(age,Pow(R,R)),height)',
#  'Add(Div(age,Pow(R,R)),weight)',
#  'Add(Div(age,R),Div(R,R))',
#  'Add(Div(age,R),Mul(R,R))',
#  'Add(Div(age,R),Pow(R,R))',
#  'Add(Div(age,R),R)',
#  'Add(Div(age,R),Sub(R,R))',
#  'Add(Div(age,R),age)',
#  'Add(Div(age,R),height)',
#  'Add(Div(age,R),weight)',
#  'Add(Div(age,Sub(R,R)),Div(R,R))',
#  'Add(Div(age,Sub(R,R)),Mul(R,R))',
#  'Add(Div(age,Sub(R,R)),Pow(R,R))',
#  'Add(Div(age,Sub(R,R)),R)',
#  'Add(Div(age,Sub(R,R)),Sub(R,R))',
#  'Add(Div(age,Sub(R,R)),age)',
#  'Add(Div(age,Sub(R,R)),height)',
#  'Add(Div(age,Sub(R,R)),weight)',
#  'Add(Div(age,age),Div(R,R))',
#  'Add(Div(age,age),Mul(R,R))',
#  'Add(Div(age,age),Pow(R,R))',
#  'Add(Div(age,age),R)',
#  'Add(Div(age,age),Sub(R,R))',
#  'Add(Div(age,age),age)',
#  'Add(Div(age,age),height)',
#  'Add(Div(age,age),weight)',
#  'Add(Div(age,height),Div(R,R))',
#  'Add(Div(age,height),Mul(R,R))',
#  'Add(Div(age,height),Pow(R,R))',
#  'Add(Div(age,height),R)',
#  'Add(Div(age,height),Sub(R,R))',
#  'Add(Div(age,height),age)',
#  'Add(Div(age,height),height)',
#  'Add(Div(age,height),weight)',
#  'Add(Div(age,weight),Div(R,R))',
#  'Add(Div(age,weight),Mul(R,R))',
#  'Add(Div(age,weight),Pow(R,R))',
#  'Add(Div(age,weight),R)',
#  'Add(Div(age,weight),Sub(R,R))',
#  'Add(Div(age,weight),age)',
#  'Add(Div(age,weight),height)',
#  'Add(Div(age,weight),weight)',
#  'Add(Div(height,Add(R,R)),Div(R,R))',
#  'Add(Div(height,Add(R,R)),Mul(R,R))',
#  'Add(Div(height,Add(R,R)),Pow(R,R))',
#  'Add(Div(height,Add(R,R)),R)',
#  'Add(Div(height,Add(R,R)),Sub(R,R))',
#  'Add(Div(height,Add(R,R)),age)',
#  'Add(Div(height,Add(R,R)),height)',
#  'Add(Div(height,Add(R,R)),weight)',
#  'Add(Div(height,Div(R,R)),Div(R,R))',
#  'Add(Div(height,Div(R,R)),Mul(R,R))',
#  'Add(Div(height,Div(R,R)),Pow(R,R))',
#  'Add(Div(height,Div(R,R)),R)',
#  'Add(Div(height,Div(R,R)),Sub(R,R))',
#  'Add(Div(height,Div(R,R)),age)',
#  'Add(Div(height,Div(R,R)),height)',
#  'Add(Div(height,Div(R,R)),weight)',
#  'Add(Div(height,Mul(R,R)),Div(R,R))',
#  'Add(Div(height,Mul(R,R)),Mul(R,R))',
#  'Add(Div(height,Mul(R,R)),Pow(R,R))',
#  'Add(Div(height,Mul(R,R)),R)',
#  'Add(Div(height,Mul(R,R)),Sub(R,R))',
#  'Add(Div(height,Mul(R,R)),age)',
#  'Add(Div(height,Mul(R,R)),height)',
#  'Add(Div(height,Mul(R,R)),weight)',
#  'Add(Div(height,Pow(R,R)),Div(R,R))',
#  'Add(Div(height,Pow(R,R)),Mul(R,R))',
#  'Add(Div(height,Pow(R,R)),Pow(R,R))',
#  'Add(Div(height,Pow(R,R)),R)',
#  'Add(Div(height,Pow(R,R)),Sub(R,R))',
#  'Add(Div(height,Pow(R,R)),age)',
#  'Add(Div(height,Pow(R,R)),height)',
#  'Add(Div(height,Pow(R,R)),weight)',
#  'Add(Div(height,R),Div(R,R))',
#  'Add(Div(height,R),Mul(R,R))',
#  'Add(Div(height,R),Pow(R,R))',
#  'Add(Div(height,R),R)',
#  'Add(Div(height,R),Sub(R,R))',
#  'Add(Div(height,R),age)',
#  'Add(Div(height,R),height)',
#  'Add(Div(height,R),weight)',
#  'Add(Div(height,Sub(R,R)),Div(R,R))',
#  'Add(Div(height,Sub(R,R)),Mul(R,R))',
#  'Add(Div(height,Sub(R,R)),Pow(R,R))',
#  'Add(Div(height,Sub(R,R)),R)',
#  'Add(Div(height,Sub(R,R)),Sub(R,R))',
#  'Add(Div(height,Sub(R,R)),age)',
#  'Add(Div(height,Sub(R,R)),height)',
#  'Add(Div(height,Sub(R,R)),weight)',
#  'Add(Div(height,age),Div(R,R))',
#  'Add(Div(height,age),Mul(R,R))',
#  'Add(Div(height,age),Pow(R,R))',
#  'Add(Div(height,age),R)',
#  'Add(Div(height,age),Sub(R,R))',
#  'Add(Div(height,age),age)',
#  'Add(Div(height,age),height)',
#  'Add(Div(height,age),weight)',
#  'Add(Div(height,height),Div(R,R))',
#  'Add(Div(height,height),Mul(R,R))',
#  'Add(Div(height,height),Pow(R,R))',
#  'Add(Div(height,height),R)',
#  'Add(Div(height,height),Sub(R,R))',
#  'Add(Div(height,height),age)',
#  'Add(Div(height,height),height)',
#  'Add(Div(height,height),weight)',
#  'Add(Div(height,weight),Div(R,R))',
#  'Add(Div(height,weight),Mul(R,R))',
#  'Add(Div(height,weight),Pow(R,R))',
#  'Add(Div(height,weight),R)',
#  'Add(Div(height,weight),Sub(R,R))',
#  'Add(Div(height,weight),age)',
#  'Add(Div(height,weight),height)',
#  'Add(Div(height,weight),weight)',
#  'Add(Div(weight,Add(R,R)),Div(R,R))',
#  'Add(Div(weight,Add(R,R)),Mul(R,R))',
#  'Add(Div(weight,Add(R,R)),Pow(R,R))',
#  'Add(Div(weight,Add(R,R)),R)',
#  'Add(Div(weight,Add(R,R)),Sub(R,R))',
#  'Add(Div(weight,Add(R,R)),age)',
#  'Add(Div(weight,Add(R,R)),height)',
#  'Add(Div(weight,Add(R,R)),weight)',
#  'Add(Div(weight,Div(R,R)),Div(R,R))',
#  'Add(Div(weight,Div(R,R)),Mul(R,R))',
#  'Add(Div(weight,Div(R,R)),Pow(R,R))',
#  'Add(Div(weight,Div(R,R)),R)',
#  'Add(Div(weight,Div(R,R)),Sub(R,R))',
#  'Add(Div(weight,Div(R,R)),age)',
#  'Add(Div(weight,Div(R,R)),height)',
#  'Add(Div(weight,Div(R,R)),weight)',
#  'Add(Div(weight,Mul(R,R)),Div(R,R))',
#  'Add(Div(weight,Mul(R,R)),Mul(R,R))',
#  'Add(Div(weight,Mul(R,R)),Pow(R,R))',
#  'Add(Div(weight,Mul(R,R)),R)',
#  'Add(Div(weight,Mul(R,R)),Sub(R,R))',
#  'Add(Div(weight,Mul(R,R)),age)',
#  'Add(Div(weight,Mul(R,R)),height)',
#  'Add(Div(weight,Mul(R,R)),weight)',
#  'Add(Div(weight,Pow(R,R)),Div(R,R))',
#  'Add(Div(weight,Pow(R,R)),Mul(R,R))',
#  'Add(Div(weight,Pow(R,R)),Pow(R,R))',
#  'Add(Div(weight,Pow(R,R)),R)',
#  'Add(Div(weight,Pow(R,R)),Sub(R,R))',
#  'Add(Div(weight,Pow(R,R)),age)',
#  'Add(Div(weight,Pow(R,R)),height)',
#  'Add(Div(weight,Pow(R,R)),weight)',
#  'Add(Div(weight,R),Div(R,R))',
#  'Add(Div(weight,R),Mul(R,R))',
#  'Add(Div(weight,R),Pow(R,R))',
#  'Add(Div(weight,R),R)',
#  'Add(Div(weight,R),Sub(R,R))',
#  'Add(Div(weight,R),age)',
#  'Add(Div(weight,R),height)',
#  'Add(Div(weight,R),weight)',
#  'Add(Div(weight,Sub(R,R)),Div(R,R))',
#  'Add(Div(weight,Sub(R,R)),Mul(R,R))',
#  'Add(Div(weight,Sub(R,R)),Pow(R,R))',
#  'Add(Div(weight,Sub(R,R)),R)',
#  'Add(Div(weight,Sub(R,R)),Sub(R,R))',
#  'Add(Div(weight,Sub(R,R)),age)',
#  'Add(Div(weight,Sub(R,R)),height)',
#  'Add(Div(weight,Sub(R,R)),weight)',
#  'Add(Div(weight,age),Div(R,R))',
#  'Add(Div(weight,age),Mul(R,R))',
#  'Add(Div(weight,age),Pow(R,R))',
#  'Add(Div(weight,age),R)',
#  'Add(Div(weight,age),Sub(R,R))',
#  'Add(Div(weight,age),age)',
#  'Add(Div(weight,age),height)',
#  'Add(Div(weight,age),weight)',
#  'Add(Div(weight,height),Div(R,R))',
#  'Add(Div(weight,height),Mul(R,R))',
#  'Add(Div(weight,height),Pow(R,R))',
#  'Add(Div(weight,height),R)',
#  'Add(Div(weight,height),Sub(R,R))',
#  'Add(Div(weight,height),age)',
#  'Add(Div(weight,height),height)',
#  'Add(Div(weight,height),weight)',
#  'Add(Div(weight,weight),Div(R,R))',
#  'Add(Div(weight,weight),Mul(R,R))',
#  'Add(Div(weight,weight),Pow(R,R))',
#  'Add(Div(weight,weight),R)',
#  'Add(Div(weight,weight),Sub(R,R))',
#  'Add(Div(weight,weight),age)',
#  'Add(Div(weight,weight),height)',
#  'Add(Div(weight,weight),weight)',
#  'Add(Mul(Add(R,R),R),R)',
#  'Add(Mul(Add(R,R),age),R)',
#  'Add(Mul(Add(R,R),height),R)',
#  'Add(Mul(Add(R,R),weight),R)',
#  'Add(Mul(Div(R,R),R),R)',
#  'Add(Mul(Div(R,R),age),R)',
#  'Add(Mul(Div(R,R),height),R)',
#  'Add(Mul(Div(R,R),weight),R)',
#  'Add(Mul(Mul(R,R),R),R)',
#  'Add(Mul(Mul(R,R),age),R)',
#  'Add(Mul(Mul(R,R),height),R)',
#  'Add(Mul(Mul(R,R),weight),R)',
#  'Add(Mul(Pow(R,R),R),R)',
#  'Add(Mul(Pow(R,R),age),R)',
#  'Add(Mul(Pow(R,R),height),R)',
#  'Add(Mul(Pow(R,R),weight),R)',
#  'Add(Mul(R,R),Pow(age,R))',
#  'Add(Mul(R,R),Pow(height,R))',
#  'Add(Mul(R,R),Pow(weight,R))',
#  'Add(Mul(R,R),R)',
#  'Add(Mul(R,R),Sub(age,R))',
#  'Add(Mul(R,R),Sub(height,R))',
#  'Add(Mul(R,R),Sub(weight,R))',
#  'Add(Mul(R,Sub(R,R)),R)',
#  'Add(Mul(R,age),Mul(R,R))',
#  'Add(Mul(R,age),Pow(R,R))',
#  'Add(Mul(R,age),R)',
#  'Add(Mul(R,age),Sub(R,R))',
#  'Add(Mul(R,age),age)',
#  'Add(Mul(R,age),height)',
#  'Add(Mul(R,age),weight)',
#  'Add(Mul(R,height),Mul(R,R))',
#  'Add(Mul(R,height),Pow(R,R))',
#  'Add(Mul(R,height),R)',
#  'Add(Mul(R,height),Sub(R,R))',
#  'Add(Mul(R,height),age)',
#  'Add(Mul(R,height),height)',
#  'Add(Mul(R,height),weight)',
#  'Add(Mul(R,weight),Mul(R,R))',
#  'Add(Mul(R,weight),Pow(R,R))',
#  'Add(Mul(R,weight),R)',
#  'Add(Mul(R,weight),Sub(R,R))',
#  'Add(Mul(R,weight),age)',
#  'Add(Mul(R,weight),height)',
#  'Add(Mul(R,weight),weight)',
#  'Add(Mul(Sub(R,R),age),R)',
#  'Add(Mul(Sub(R,R),height),R)',
#  'Add(Mul(Sub(R,R),weight),R)',
#  'Add(Mul(age,age),R)',
#  'Add(Mul(age,height),R)',
#  'Add(Mul(age,weight),R)',
#  'Add(Mul(height,height),R)',
#  'Add(Mul(height,weight),R)',
#  'Add(Mul(weight,weight),R)',
#  'Add(Pow(Add(R,R),R),R)',
#  'Add(Pow(Div(R,R),R),R)',
#  'Add(Pow(Mul(R,R),R),R)',
#  'Add(Pow(Pow(R,R),R),R)',
#  'Add(Pow(R,R),R)',
#  'Add(Pow(R,R),Sub(age,R))',
#  'Add(Pow(R,R),Sub(height,R))',
#  'Add(Pow(R,R),Sub(weight,R))',
#  'Add(Pow(Sub(R,R),R),R)',
#  'Add(Pow(age,Add(R,R)),R)',
#  'Add(Pow(age,Div(R,R)),R)',
#  'Add(Pow(age,Mul(R,R)),R)',
#  'Add(Pow(age,Pow(R,R)),R)',
#  'Add(Pow(age,R),Pow(R,R))',
#  'Add(Pow(age,R),R)',
#  'Add(Pow(age,R),Sub(R,R))',
#  'Add(Pow(age,R),age)',
#  'Add(Pow(age,R),height)',
#  'Add(Pow(age,R),weight)',
#  'Add(Pow(age,Sub(R,R)),R)',
#  'Add(Pow(age,age),R)',
#  'Add(Pow(age,height),R)',
#  'Add(Pow(age,weight),R)',
#  'Add(Pow(height,Add(R,R)),R)',
#  'Add(Pow(height,Div(R,R)),R)',
#  'Add(Pow(height,Mul(R,R)),R)',
#  'Add(Pow(height,Pow(R,R)),R)',
#  'Add(Pow(height,R),Pow(R,R))',
#  'Add(Pow(height,R),R)',
#  'Add(Pow(height,R),Sub(R,R))',
#  'Add(Pow(height,R),age)',
#  'Add(Pow(height,R),height)',
#  'Add(Pow(height,R),weight)',
#  'Add(Pow(height,Sub(R,R)),R)',
#  'Add(Pow(height,age),R)',
#  'Add(Pow(height,height),R)',
#  'Add(Pow(height,weight),R)',
#  'Add(Pow(weight,Add(R,R)),R)',
#  'Add(Pow(weight,Div(R,R)),R)',
#  'Add(Pow(weight,Mul(R,R)),R)',
#  'Add(Pow(weight,Pow(R,R)),R)',
#  'Add(Pow(weight,R),Pow(R,R))',
#  'Add(Pow(weight,R),R)',
#  'Add(Pow(weight,R),Sub(R,R))',
#  'Add(Pow(weight,R),age)',
#  'Add(Pow(weight,R),height)',
#  'Add(Pow(weight,R),weight)',
#  'Add(Pow(weight,Sub(R,R)),R)',
#  'Add(Pow(weight,age),R)',
#  'Add(Pow(weight,height),R)',
#  'Add(Pow(weight,weight),R)',
#  'Add(R,R)',
#  'Add(R,Sub(Add(R,R),R))',
#  'Add(R,Sub(Div(R,R),R))',
#  'Add(R,Sub(Mul(R,R),R))',
#  'Add(R,Sub(Pow(R,R),R))',
#  'Add(R,Sub(R,R))',
#  'Add(R,Sub(Sub(R,R),R))',
#  'Add(R,Sub(age,Add(R,R)))',
#  'Add(R,Sub(age,Div(R,R)))',
#  'Add(R,Sub(age,Mul(R,R)))',
#  'Add(R,Sub(age,Pow(R,R)))',
#  'Add(R,Sub(age,R))',
#  'Add(R,Sub(age,Sub(R,R)))',
#  'Add(R,Sub(age,age))',
#  'Add(R,Sub(age,height))',
#  'Add(R,Sub(age,weight))',
#  'Add(R,Sub(height,Add(R,R)))',
#  'Add(R,Sub(height,Div(R,R)))',
#  'Add(R,Sub(height,Mul(R,R)))',
#  'Add(R,Sub(height,Pow(R,R)))',
#  'Add(R,Sub(height,R))',
#  'Add(R,Sub(height,Sub(R,R)))',
#  'Add(R,Sub(height,age))',
#  'Add(R,Sub(height,height))',
#  'Add(R,Sub(height,weight))',
#  'Add(R,Sub(weight,Add(R,R)))',
#  'Add(R,Sub(weight,Div(R,R)))',
#  'Add(R,Sub(weight,Mul(R,R)))',
#  'Add(R,Sub(weight,Pow(R,R)))',
#  'Add(R,Sub(weight,R))',
#  'Add(R,Sub(weight,Sub(R,R)))',
#  'Add(R,Sub(weight,age))',
#  'Add(R,Sub(weight,height))',
#  'Add(R,Sub(weight,weight))',
#  'Add(R,age)',
#  'Add(R,height)',
#  'Add(R,weight)',
#  'Add(Sub(age,R),Sub(R,R))',
#  'Add(Sub(age,R),age)',
#  'Add(Sub(age,R),height)',
#  'Add(Sub(age,R),weight)',
#  'Add(Sub(height,R),Sub(R,R))',
#  'Add(Sub(height,R),age)',
#  'Add(Sub(height,R),height)',
#  'Add(Sub(height,R),weight)',
#  'Add(Sub(weight,R),Sub(R,R))',
#  'Add(Sub(weight,R),age)',
#  'Add(Sub(weight,R),height)',
#  'Add(Sub(weight,R),weight)',
#  'Add(age,age)',
#  'Add(age,height)',
#  'Add(age,weight)',
#  'Add(height,height)',
#  'Add(height,weight)',
#  'Add(weight,weight)',
#  'Div(Add(R,age),R)',
#  'Div(Add(R,height),R)',
#  'Div(Add(R,weight),R)',
#  'Div(Div(Add(R,R),R),R)',
#  'Div(Div(Div(R,R),R),R)',
#  'Div(Div(Mul(R,R),R),R)',
#  'Div(Div(Pow(R,R),R),R)',
#  'Div(Div(R,R),R)',
#  'Div(Div(Sub(R,R),R),R)',
#  'Div(Div(age,Add(R,R)),R)',
#  'Div(Div(age,Div(R,R)),R)',
#  'Div(Div(age,Mul(R,R)),R)',
#  'Div(Div(age,Pow(R,R)),R)',
#  'Div(Div(age,R),Add(R,R))',
#  'Div(Div(age,R),Div(R,R))',
#  'Div(Div(age,R),Mul(R,R))',
#  'Div(Div(age,R),Pow(R,R))',
#  'Div(Div(age,R),R)',
#  'Div(Div(age,R),Sub(R,R))',
#  'Div(Div(age,R),age)',
#  'Div(Div(age,R),height)',
#  'Div(Div(age,R),weight)',
#  'Div(Div(age,Sub(R,R)),R)',
#  'Div(Div(age,age),R)',
#  'Div(Div(age,height),R)',
#  'Div(Div(age,weight),R)',
#  'Div(Div(height,Add(R,R)),R)',
#  'Div(Div(height,Div(R,R)),R)',
#  'Div(Div(height,Mul(R,R)),R)',
#  'Div(Div(height,Pow(R,R)),R)',
#  'Div(Div(height,R),Add(R,R))',
#  'Div(Div(height,R),Div(R,R))',
#  'Div(Div(height,R),Mul(R,R))',
#  'Div(Div(height,R),Pow(R,R))',
#  'Div(Div(height,R),R)',
#  'Div(Div(height,R),Sub(R,R))',
#  'Div(Div(height,R),age)',
#  'Div(Div(height,R),height)',
#  'Div(Div(height,R),weight)',
#  'Div(Div(height,Sub(R,R)),R)',
#  'Div(Div(height,age),R)',
#  'Div(Div(height,height),R)',
#  'Div(Div(height,weight),R)',
#  'Div(Div(weight,Add(R,R)),R)',
#  'Div(Div(weight,Div(R,R)),R)',
#  'Div(Div(weight,Mul(R,R)),R)',
#  'Div(Div(weight,Pow(R,R)),R)',
#  'Div(Div(weight,R),Add(R,R))',
#  'Div(Div(weight,R),Div(R,R))',
#  'Div(Div(weight,R),Mul(R,R))',
#  'Div(Div(weight,R),Pow(R,R))',
#  'Div(Div(weight,R),R)',
#  'Div(Div(weight,R),Sub(R,R))',
#  'Div(Div(weight,R),age)',
#  'Div(Div(weight,R),height)',
#  'Div(Div(weight,R),weight)',
#  'Div(Div(weight,Sub(R,R)),R)',
#  'Div(Div(weight,age),R)',
#  'Div(Div(weight,height),R)',
#  'Div(Div(weight,weight),R)',
#  'Div(Mul(R,age),R)',
#  'Div(Mul(R,height),R)',
#  'Div(Mul(R,weight),R)',
#  'Div(Pow(age,R),R)',
#  'Div(Pow(height,R),R)',
#  'Div(Pow(weight,R),R)',
#  'Div(R,R)',
#  'Div(Sub(age,R),R)',
#  'Div(Sub(height,R),R)',
#  'Div(Sub(weight,R),R)',
#  'Div(age,R)',
#  'Div(height,R)',
#  'Div(weight,R)',
#  'Mul(Add(R,R),Div(age,R))',
#  'Mul(Add(R,R),Div(height,R))',
#  'Mul(Add(R,R),Div(weight,R))',
#  'Mul(Add(R,age),R)',
#  'Mul(Add(R,height),R)',
#  'Mul(Add(R,weight),R)',
#  'Mul(Div(Add(R,R),R),R)',
#  'Mul(Div(Div(R,R),R),R)',
#  'Mul(Div(Mul(R,R),R),R)',
#  'Mul(Div(Pow(R,R),R),R)',
#  'Mul(Div(R,R),R)',
#  'Mul(Div(Sub(R,R),R),R)',
#  'Mul(Div(age,Add(R,R)),R)',
#  'Mul(Div(age,Div(R,R)),R)',
#  'Mul(Div(age,Mul(R,R)),R)',
#  'Mul(Div(age,Pow(R,R)),R)',
#  'Mul(Div(age,R),Div(R,R))',
#  'Mul(Div(age,R),Mul(R,R))',
#  'Mul(Div(age,R),Pow(R,R))',
#  'Mul(Div(age,R),R)',
#  'Mul(Div(age,R),Sub(R,R))',
#  'Mul(Div(age,R),age)',
#  'Mul(Div(age,R),height)',
#  'Mul(Div(age,R),weight)',
#  'Mul(Div(age,Sub(R,R)),R)',
#  'Mul(Div(age,age),R)',
#  'Mul(Div(age,height),R)',
#  'Mul(Div(age,weight),R)',
#  'Mul(Div(height,Add(R,R)),R)',
#  'Mul(Div(height,Div(R,R)),R)',
#  'Mul(Div(height,Mul(R,R)),R)',
#  'Mul(Div(height,Pow(R,R)),R)',
#  'Mul(Div(height,R),Div(R,R))',
#  'Mul(Div(height,R),Mul(R,R))',
#  'Mul(Div(height,R),Pow(R,R))',
#  'Mul(Div(height,R),R)',
#  'Mul(Div(height,R),Sub(R,R))',
#  'Mul(Div(height,R),age)',
#  'Mul(Div(height,R),height)',
#  'Mul(Div(height,R),weight)',
#  'Mul(Div(height,Sub(R,R)),R)',
#  'Mul(Div(height,age),R)',
#  'Mul(Div(height,height),R)',
#  'Mul(Div(height,weight),R)',
#  'Mul(Div(weight,Add(R,R)),R)',
#  'Mul(Div(weight,Div(R,R)),R)',
#  'Mul(Div(weight,Mul(R,R)),R)',
#  'Mul(Div(weight,Pow(R,R)),R)',
#  'Mul(Div(weight,R),Div(R,R))',
#  'Mul(Div(weight,R),Mul(R,R))',
#  'Mul(Div(weight,R),Pow(R,R))',
#  'Mul(Div(weight,R),R)',
#  'Mul(Div(weight,R),Sub(R,R))',
#  'Mul(Div(weight,R),age)',
#  'Mul(Div(weight,R),height)',
#  'Mul(Div(weight,R),weight)',
#  'Mul(Div(weight,Sub(R,R)),R)',
#  'Mul(Div(weight,age),R)',
#  'Mul(Div(weight,height),R)',
#  'Mul(Div(weight,weight),R)',
#  'Mul(Mul(R,age),R)',
#  'Mul(Mul(R,height),R)',
#  'Mul(Mul(R,weight),R)',
#  'Mul(Pow(age,R),R)',
#  'Mul(Pow(height,R),R)',
#  'Mul(Pow(weight,R),R)',
#  'Mul(R,R)',
#  'Mul(R,Sub(age,R))',
#  'Mul(R,Sub(height,R))',
#  'Mul(R,Sub(weight,R))',
#  'Mul(R,age)',
#  'Mul(R,height)',
#  'Mul(R,weight)',
#  'Pow(Add(R,age),R)',
#  'Pow(Add(R,height),R)',
#  'Pow(Add(R,weight),R)',
#  'Pow(Div(Add(R,R),R),R)',
#  'Pow(Div(Div(R,R),R),R)',
#  'Pow(Div(Mul(R,R),R),R)',
#  'Pow(Div(Pow(R,R),R),R)',
#  'Pow(Div(R,R),R)',
#  'Pow(Div(Sub(R,R),R),R)',
#  'Pow(Div(age,Add(R,R)),R)',
#  'Pow(Div(age,Div(R,R)),R)',
#  'Pow(Div(age,Mul(R,R)),R)',
#  'Pow(Div(age,Pow(R,R)),R)',
#  'Pow(Div(age,R),Add(R,R))',
#  'Pow(Div(age,R),Div(R,R))',
#  'Pow(Div(age,R),Mul(R,R))',
#  'Pow(Div(age,R),Pow(R,R))',
#  'Pow(Div(age,R),R)',
#  'Pow(Div(age,R),Sub(R,R))',
#  'Pow(Div(age,R),age)',
#  'Pow(Div(age,R),height)',
#  'Pow(Div(age,R),weight)',
#  'Pow(Div(age,Sub(R,R)),R)',
#  'Pow(Div(age,age),R)',
#  'Pow(Div(age,height),R)',
#  'Pow(Div(age,weight),R)',
#  'Pow(Div(height,Add(R,R)),R)',
#  'Pow(Div(height,Div(R,R)),R)',
#  'Pow(Div(height,Mul(R,R)),R)',
#  'Pow(Div(height,Pow(R,R)),R)',
#  'Pow(Div(height,R),Add(R,R))',
#  'Pow(Div(height,R),Div(R,R))',
#  'Pow(Div(height,R),Mul(R,R))',
#  'Pow(Div(height,R),Pow(R,R))',
#  'Pow(Div(height,R),R)',
#  'Pow(Div(height,R),Sub(R,R))',
#  'Pow(Div(height,R),age)',
#  'Pow(Div(height,R),height)',
#  'Pow(Div(height,R),weight)',
#  'Pow(Div(height,Sub(R,R)),R)',
#  'Pow(Div(height,age),R)',
#  'Pow(Div(height,height),R)',
#  'Pow(Div(height,weight),R)',
#  'Pow(Div(weight,Add(R,R)),R)',
#  'Pow(Div(weight,Div(R,R)),R)',
#  'Pow(Div(weight,Mul(R,R)),R)',
#  'Pow(Div(weight,Pow(R,R)),R)',
#  'Pow(Div(weight,R),Add(R,R))',
#  'Pow(Div(weight,R),Div(R,R))',
#  'Pow(Div(weight,R),Mul(R,R))',
#  'Pow(Div(weight,R),Pow(R,R))',
#  'Pow(Div(weight,R),R)',
#  'Pow(Div(weight,R),Sub(R,R))',
#  'Pow(Div(weight,R),age)',
#  'Pow(Div(weight,R),height)',
#  'Pow(Div(weight,R),weight)',
#  'Pow(Div(weight,Sub(R,R)),R)',
#  'Pow(Div(weight,age),R)',
#  'Pow(Div(weight,height),R)',
#  'Pow(Div(weight,weight),R)',
#  'Pow(Mul(R,age),R)',
#  'Pow(Mul(R,height),R)',
#  'Pow(Mul(R,weight),R)',
#  'Pow(Pow(age,R),R)',
#  'Pow(Pow(height,R),R)',
#  'Pow(Pow(weight,R),R)',
#  'Pow(R,R)',
#  'Pow(Sub(age,R),R)',
#  'Pow(Sub(height,R),R)',
#  'Pow(Sub(weight,R),R)',
#  'Pow(age,R)',
#  'Pow(height,R)',
#  'Pow(weight,R)',
#  'R',
#  'Sub(Add(R,age),R)',
#  'Sub(Add(R,height),R)',
#  'Sub(Add(R,weight),R)',
#  'Sub(Div(Add(R,R),R),R)',
#  'Sub(Div(Div(R,R),R),R)',
#  'Sub(Div(Mul(R,R),R),R)',
#  'Sub(Div(Pow(R,R),R),R)',
#  'Sub(Div(R,R),R)',
#  'Sub(Div(Sub(R,R),R),R)',
#  'Sub(Div(age,Add(R,R)),R)',
#  'Sub(Div(age,Div(R,R)),R)',
#  'Sub(Div(age,Mul(R,R)),R)',
#  'Sub(Div(age,Pow(R,R)),R)',
#  'Sub(Div(age,R),Add(R,R))',
#  'Sub(Div(age,R),Div(R,R))',
#  'Sub(Div(age,R),Mul(R,R))',
#  'Sub(Div(age,R),Pow(R,R))',
#  'Sub(Div(age,R),R)',
#  'Sub(Div(age,R),Sub(R,R))',
#  'Sub(Div(age,R),age)',
#  'Sub(Div(age,R),height)',
#  'Sub(Div(age,R),weight)',
#  'Sub(Div(age,Sub(R,R)),R)',
#  'Sub(Div(age,age),R)',
#  'Sub(Div(age,height),R)',
#  'Sub(Div(age,weight),R)',
#  'Sub(Div(height,Add(R,R)),R)',
#  'Sub(Div(height,Div(R,R)),R)',
#  'Sub(Div(height,Mul(R,R)),R)',
#  'Sub(Div(height,Pow(R,R)),R)',
#  'Sub(Div(height,R),Add(R,R))',
#  'Sub(Div(height,R),Div(R,R))',
#  'Sub(Div(height,R),Mul(R,R))',
#  'Sub(Div(height,R),Pow(R,R))',
#  'Sub(Div(height,R),R)',
#  'Sub(Div(height,R),Sub(R,R))',
#  'Sub(Div(height,R),age)',
#  'Sub(Div(height,R),height)',
#  'Sub(Div(height,R),weight)',
#  'Sub(Div(height,Sub(R,R)),R)',
#  'Sub(Div(height,age),R)',
#  'Sub(Div(height,height),R)',
#  'Sub(Div(height,weight),R)',
#  'Sub(Div(weight,Add(R,R)),R)',
#  'Sub(Div(weight,Div(R,R)),R)',
#  'Sub(Div(weight,Mul(R,R)),R)',
#  'Sub(Div(weight,Pow(R,R)),R)',
#  'Sub(Div(weight,R),Add(R,R))',
#  'Sub(Div(weight,R),Div(R,R))',
#  'Sub(Div(weight,R),Mul(R,R))',
#  'Sub(Div(weight,R),Pow(R,R))',
#  'Sub(Div(weight,R),R)',
#  'Sub(Div(weight,R),Sub(R,R))',
#  'Sub(Div(weight,R),age)',
#  'Sub(Div(weight,R),height)',
#  'Sub(Div(weight,R),weight)',
#  'Sub(Div(weight,Sub(R,R)),R)',
#  'Sub(Div(weight,age),R)',
#  'Sub(Div(weight,height),R)',
#  'Sub(Div(weight,weight),R)',
#  'Sub(Mul(R,age),R)',
#  'Sub(Mul(R,height),R)',
#  'Sub(Mul(R,weight),R)',
#  'Sub(Pow(age,R),R)',
#  'Sub(Pow(height,R),R)',
#  'Sub(Pow(weight,R),R)',
#  'Sub(R,R)',
#  'Sub(Sub(age,R),R)',
#  'Sub(Sub(height,R),R)',
#  'Sub(Sub(weight,R),R)',
#  'Sub(age,R)',
#  'Sub(height,R)',
#  'Sub(weight,R)',
#  'age',
#  'height',
#  'weight']

# %%
len(exp_set)
# Out:
# 873

# %%
df = pd.read_csv("df_2308.csv")
df = df[["age_cal","height","weight","airway_tube_size"]]
df.columns = ["age","height","weight","airway_tube_size"]
df = df.dropna()
df
# Out:
#              age  height  weight  airway_tube_size
# 0       8.542270   134.2   34.40               6.5
# 1       1.034929    78.0   10.10               4.0
# 3       6.612045   127.3   23.05               6.0
# 6       1.248486    76.4   11.00               4.0
# 8      12.777812   142.3   53.25               6.5
# ...          ...     ...     ...               ...
# 32043   0.372355    67.0    5.10               3.5
# 32045   6.434081   119.9   20.90               5.0
# 32046   8.972121   137.0   28.00               5.5
# 32047   5.084293   111.7   18.75               5.0
# 32048   0.873392    72.7   10.30               4.0
#
# [29570 rows x 4 columns]

# %%
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
from scipy.optimize import minimize
from tqdm import tqdm
import itertools
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
import numpy as np
from sklearn.model_selection import train_test_split
from pmlb import fetch_data, regression_dataset_names
import time


def cost(x, xdata, ydata, lambda_string): 
    y_pred = eval(lambda_string)(x, xdata)
    return np.mean(((y_pred - ydata))**2) 

def cost2(x, xdata, ydata, lambda_string): 
    y_pred = eval(lambda_string)(x, xdata)
    return concordance_correlation_coefficient(ydata,y_pred)

def cust_pred(x, xdata, ydata, lambda_string): 
    y_pred = eval(lambda_string)(x, xdata)
    return y_pred

def random_constant():
        return np.random.randint(1, 31)/10

# %%
X, y = np.array(df.iloc[:,:-1]).T, np.array(df.iloc[:,-1])
num_of_feature = X.shape[1]
mse_tuple = tuple()
np.random.seed(0)
master_list = []
for repeat_trial in range(1):
    for test_eq in tqdm(exp_set):
        test_eq_orig = test_eq
        R_count = test_eq.count("R")
        if R_count==0:
            continue
        lambda_string = "lambda x,xdata:"
        index = 0    
        for i in range(R_count):
            test_eq = test_eq.replace("R", f"x[{i}]", 1)
        lambda_string += test_eq
        optimized_cost = 0
        ypred =[]
        ytrue =[]
        lambda_string_list = []
        res_x_list =[]
        try:
            for xdata, ydata in zip([X],[y]):
                lambda_string_new = lambda_string.replace("height","(xdata[1])")
                lambda_string_new = lambda_string_new.replace("age","(xdata[0])")
                lambda_string_new = lambda_string_new.replace("weight","(xdata[2])")
                res = minimize(cost,
                               x0 = [random_constant() for i in range(R_count)],
                               args=(xdata,ydata,lambda_string_new),
                               method="BFGS")                      
                optimized_cost = cost(res.x, xdata, ydata, lambda_string_new)
            optimized_cost = optimized_cost*(1/len(y))
            master_list.append((test_eq_orig,test_eq,lambda_string_new,res.x,optimized_cost))
        except RuntimeError:
            print("No fit found")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 873/873 [13:06<00:00,  1.11it/s]

# %%
sorted(master_list,key=lambda x: x[-1])
# Out:
# [('Add(Pow(age,R),Pow(R,R))',
#   'Add(Pow(age,x[0]),Pow(x[1],x[2]))',
#   'lambda x,xdata:Add(Pow((xdata[0]),x[0]),Pow(x[1],x[2]))',
#   array([0.48872132, 3.75099387, 0.85763306]),
#   4.909772605612621e-06),
#  ('Add(Div(R,R),Pow(age,R))',
#   'Add(Div(x[0],x[1]),Pow(age,x[2]))',
#   'lambda x,xdata:Add(Div(x[0],x[1]),Pow((xdata[0]),x[2]))',
#   array([1.00007952, 0.32183084, 0.48872131]),
#   4.909772605613428e-06),
#  ('Add(Add(R,R),Pow(age,R))',
#   'Add(Add(x[0],x[1]),Pow(age,x[2]))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Pow((xdata[0]),x[2]))',
#   array([0.9037346 , 2.2037346 , 0.48872151]),
#   4.909772605623933e-06),
#  ('Add(Add(R,R),Pow(height,R))',
#   'Add(Add(x[0],x[1]),Pow(height,x[2]))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Pow((xdata[1]),x[2]))',
#   array([-1.60251705, -0.70251705,  0.43275881]),
#   4.943636934869172e-06),
#  ('Add(Div(R,R),Pow(height,R))',
#   'Add(Div(x[0],x[1]),Pow(height,x[2]))',
#   'lambda x,xdata:Add(Div(x[0],x[1]),Pow((xdata[1]),x[2]))',
#   array([-54.50700418,  23.64695995,   0.43275875]),
#   4.943636934896125e-06),
#  ('Add(Add(R,R),Div(height,R))',
#   'Add(Add(x[0],x[1]),Div(height,x[2]))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[1]),x[2]))',
#   array([1.44560635e-02, 1.71445606e+00, 3.10774330e+01]),
#   5.468437345930421e-06),
#  ('Add(Div(height,Pow(R,R)),Sub(R,R))',
#   'Add(Div(height,Pow(x[0],x[1])),Sub(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Pow(x[0],x[1])),Sub(x[2],x[3]))',
#   array([2.51445466, 3.72697767, 3.7133728 , 1.98446066]),
#   5.468437345930448e-06),
#  ('Add(Div(height,Sub(R,R)),Sub(R,R))',
#   'Add(Div(height,Sub(x[0],x[1])),Sub(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Sub(x[0],x[1])),Sub(x[2],x[3]))',
#   array([ 16.42325522, -14.65417655,   2.68526712,   0.95635503]),
#   5.468437345930801e-06),
#  ('Add(Div(height,Add(R,R)),Div(R,R))',
#   'Add(Div(height,Add(x[0],x[1])),Div(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Add(x[0],x[1])),Div(x[2],x[3]))',
#   array([16.38872195, 14.68872195,  6.90235521,  3.99230843]),
#   5.468437345932313e-06),
#  ('Add(Div(height,Add(R,R)),R)',
#   'Add(Div(height,Add(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Div((xdata[1]),Add(x[0],x[1])),x[2])',
#   array([15.88871242, 15.18871242,  1.72891136]),
#   5.468437345934243e-06),
#  ('Add(Div(height,Add(R,R)),Sub(R,R))',
#   'Add(Div(height,Add(x[0],x[1])),Sub(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Add(x[0],x[1])),Sub(x[2],x[3]))',
#   array([15.28872413, 15.78872413,  1.5645099 , -0.16440397]),
#   5.468437345935854e-06),
#  ('Add(Div(height,Pow(R,R)),Pow(R,R))',
#   'Add(Div(height,Pow(x[0],x[1])),Pow(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Pow(x[0],x[1])),Pow(x[2],x[3]))',
#   array([2.39138887, 3.94148731, 7.68542518, 0.26846704]),
#   5.468437345937467e-06),
#  ('Add(Div(height,R),Mul(R,R))',
#   'Add(Div(height,x[0]),Mul(x[1],x[2]))',
#   'lambda x,xdata:Add(Div((xdata[1]),x[0]),Mul(x[1],x[2]))',
#   array([31.07743585, -0.53205716, -3.24948527]),
#   5.468437345940538e-06),
#  ('Add(Div(height,Sub(R,R)),Pow(R,R))',
#   'Add(Div(height,Sub(x[0],x[1])),Pow(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Sub(x[0],x[1])),Pow(x[2],x[3]))',
#   array([ 16.79085146, -14.28659057,   9.72246513,   0.24071574]),
#   5.468437345946463e-06),
#  ('Add(Div(height,R),Div(R,R))',
#   'Add(Div(height,x[0]),Div(x[1],x[2]))',
#   'lambda x,xdata:Add(Div((xdata[1]),x[0]),Div(x[1],x[2]))',
#   array([31.07745999, -0.15788244, -0.0913188 ]),
#   5.4684373459492794e-06),
#  ('Add(Div(height,Div(R,R)),Pow(R,R))',
#   'Add(Div(height,Div(x[0],x[1])),Pow(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Div(x[0],x[1])),Pow(x[2],x[3]))',
#   array([1.88791358, 0.06074865, 4.62974427, 0.35725491]),
#   5.46843734595077e-06),
#  ('Add(Div(height,Div(R,R)),R)',
#   'Add(Div(height,Div(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Div((xdata[1]),Div(x[0],x[1])),x[2])',
#   array([1.73640099, 0.05587331, 1.72891639]),
#   5.468437345976178e-06),
#  ('Add(Div(height,Pow(R,R)),R)',
#   'Add(Div(height,Pow(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Div((xdata[1]),Pow(x[0],x[1])),x[2])',
#   array([2.27966488, 4.17034573, 1.72891734]),
#   5.46843734600248e-06),
#  ('Add(Div(height,Div(R,R)),Div(R,R))',
#   'Add(Div(height,Div(x[0],x[1])),Div(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Div(x[0],x[1])),Div(x[2],x[3]))',
#   array([1.81859215, 0.058518  , 2.39468042, 1.38507499]),
#   5.468437346005389e-06),
#  ('Add(Div(height,Add(R,R)),Mul(R,R))',
#   'Add(Div(height,Add(x[0],x[1])),Mul(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Add(x[0],x[1])),Mul(x[2],x[3]))',
#   array([16.63870097, 14.43870097,  0.72011634,  2.40087591]),
#   5.468437346005395e-06),
#  ('Add(Div(height,Div(R,R)),Mul(R,R))',
#   'Add(Div(height,Div(x[0],x[1])),Mul(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Div(x[0],x[1])),Mul(x[2],x[3]))',
#   array([1.51901107, 0.04887818, 5.02234607, 0.3442451 ]),
#   5.4684373460268905e-06),
#  ('Add(Add(R,R),Div(height,Div(R,R)))',
#   'Add(Add(x[0],x[1]),Div(height,Div(x[2],x[3])))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[1]),Div(x[2],x[3])))',
#   array([1.26445971, 0.46445971, 1.33615366, 0.04299424]),
#   5.468437346079285e-06),
#  ('Add(Div(height,Sub(R,R)),Mul(R,R))',
#   'Add(Div(height,Sub(x[0],x[1])),Mul(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Sub(x[0],x[1])),Mul(x[2],x[3]))',
#   array([8.25309553e+01, 5.14535843e+01, 1.20149345e-02, 1.43896301e+02]),
#   5.468437346107818e-06),
#  ('Add(Div(height,Div(R,R)),Sub(R,R))',
#   'Add(Div(height,Div(x[0],x[1])),Sub(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Div(x[0],x[1])),Sub(x[2],x[3]))',
#   array([1.10249062, 0.03547551, 2.46446403, 0.73554333]),
#   5.468437346138755e-06),
#  ('Add(Div(R,R),Mul(R,height))',
#   'Add(Div(x[0],x[1]),Mul(x[2],height))',
#   'lambda x,xdata:Add(Div(x[0],x[1]),Mul(x[2],(xdata[1])))',
#   array([-27.62553103, -15.97847675,   0.0321776 ]),
#   5.468437346164453e-06),
#  ('Add(Add(R,R),Mul(R,height))',
#   'Add(Add(x[0],x[1]),Mul(x[2],height))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Mul(x[2],(xdata[1])))',
#   array([0.01446072, 1.71446072, 0.0321776 ]),
#   5.4684373461771855e-06),
#  ('Add(Div(height,Mul(R,R)),R)',
#   'Add(Div(height,Mul(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Div((xdata[1]),Mul(x[0],x[1])),x[2])',
#   array([4.9842173 , 6.23515691, 1.72890955]),
#   5.468437346393171e-06),
#  ('Add(Div(height,R),R)',
#   'Add(Div(height,x[0]),x[1])',
#   'lambda x,xdata:Add(Div((xdata[1]),x[0]),x[1])',
#   array([31.07732014,  1.72890172]),
#   5.4684373464257516e-06),
#  ('Add(Div(height,Mul(R,R)),Div(R,R))',
#   'Add(Div(height,Mul(x[0],x[1])),Div(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Mul(x[0],x[1])),Div(x[2],x[3]))',
#   array([ 9.66362973,  3.21589875, 16.10278371,  9.31392131]),
#   5.468437347015336e-06),
#  ('Add(Div(height,R),Sub(R,R))',
#   'Add(Div(height,x[0]),Sub(x[1],x[2]))',
#   'lambda x,xdata:Add(Div((xdata[1]),x[0]),Sub(x[1],x[2]))',
#   array([31.07709395,  2.16478347,  0.43590272]),
#   5.468437350252281e-06),
#  ('Add(Add(R,R),Div(height,Add(R,R)))',
#   'Add(Add(x[0],x[1]),Div(height,Add(x[2],x[3])))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[1]),Add(x[2],x[3])))',
#   array([ 0.61443958,  1.11443958, 14.38853812, 16.68853812]),
#   5.468437350727548e-06),
#  ('Add(Div(Mul(R,R),height),R)',
#   'Add(Div(Mul(x[0],x[1]),height),x[2])',
#   'lambda x,xdata:Add(Div(Mul(x[0],x[1]),(xdata[1])),x[2])',
#   array([-502.89748322,    0.50435125,    7.75404398]),
#   6.609726814041766e-06),
#  ('Add(Div(Pow(R,R),height),R)',
#   'Add(Div(Pow(x[0],x[1]),height),x[2])',
#   'lambda x,xdata:Add(Div(Pow(x[0],x[1]),(xdata[1])),x[2])',
#   array([-19.48865672,   1.86404587,   7.75404448]),
#   6.609726814042699e-06),
#  ('Add(Div(Sub(R,R),height),R)',
#   'Add(Div(Sub(x[0],x[1]),height),x[2])',
#   'lambda x,xdata:Add(Div(Sub(x[0],x[1]),(xdata[1])),x[2])',
#   array([-124.96856869,  128.6683126 ,    7.75404264]),
#   6.609726814048407e-06),
#  ('Add(Div(R,height),R)',
#   'Add(Div(x[0],height),x[1])',
#   'lambda x,xdata:Add(Div(x[0],(xdata[1])),x[1])',
#   array([-253.6388429 ,    7.75406503]),
#   6.6097268157013975e-06),
#  ('Add(Div(Add(R,R),height),R)',
#   'Add(Div(Add(x[0],x[1]),height),x[2])',
#   'lambda x,xdata:Add(Div(Add(x[0],x[1]),(xdata[1])),x[2])',
#   array([-127.87009728, -125.77009728,    7.75407985]),
#   6.609726818966058e-06),
#  ('Add(Div(R,R),Pow(weight,R))',
#   'Add(Div(x[0],x[1]),Pow(weight,x[2]))',
#   'lambda x,xdata:Add(Div(x[0],x[1]),Pow((xdata[2]),x[2]))',
#   array([3.59716682, 2.04410549, 0.413434  ]),
#   7.504928194601158e-06),
#  ('Add(Add(R,R),Pow(weight,R))',
#   'Add(Add(x[0],x[1]),Pow(weight,x[2]))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Pow((xdata[2]),x[2]))',
#   array([ 1.8798884 , -0.1201116 ,  0.41343386]),
#   7.50492819463163e-06),
#  ('Add(Div(age,Add(R,R)),R)',
#   'Add(Div(age,Add(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Div((xdata[0]),Add(x[0],x[1])),x[2])',
#   array([1.67734612, 2.47734612, 3.86477699]),
#   8.119262905865192e-06),
#  ('Add(Div(age,Div(R,R)),Div(R,R))',
#   'Add(Div(age,Div(x[0],x[1])),Div(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Div(x[0],x[1])),Div(x[2],x[3]))',
#   array([1.35098831, 0.3251717 , 2.96430719, 0.76700601]),
#   8.119262905865235e-06),
#  ('Add(Div(age,Mul(R,R)),Div(R,R))',
#   'Add(Div(age,Mul(x[0],x[1])),Div(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Mul(x[0],x[1])),Div(x[2],x[3]))',
#   array([3.03353496, 1.36958766, 2.8458141 , 0.73634628]),
#   8.119262905865336e-06),
#  ('Add(Div(age,Pow(R,R)),Pow(R,R))',
#   'Add(Div(age,Pow(x[0],x[1])),Pow(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Pow(x[0],x[1])),Pow(x[2],x[3]))',
#   array([2.94715197, 1.31771529, 1.60649932, 2.85177231]),
#   8.119262905865348e-06),
#  ('Add(Div(age,Sub(R,R)),Pow(R,R))',
#   'Add(Div(age,Sub(x[0],x[1])),Pow(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Sub(x[0],x[1])),Pow(x[2],x[3]))',
#   array([ 2.95183691, -1.20285531, 17.33612399,  0.47388795]),
#   8.119262905865416e-06),
#  ('Add(Add(R,R),Div(age,Mul(R,R)))',
#   'Add(Add(x[0],x[1]),Div(age,Mul(x[2],x[3])))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[0]),Mul(x[2],x[3])))',
#   array([3.28238853, 0.58238853, 5.38813143, 0.77108219]),
#   8.119262905865426e-06),
#  ('Add(Div(age,R),Pow(R,R))',
#   'Add(Div(age,x[0]),Pow(x[1],x[2]))',
#   'lambda x,xdata:Add(Div((xdata[0]),x[0]),Pow(x[1],x[2]))',
#   array([4.15469224, 2.37096408, 1.56597843]),
#   8.11926290586585e-06),
#  ('Add(Div(age,Add(R,R)),Pow(R,R))',
#   'Add(Div(age,Add(x[0],x[1])),Pow(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Add(x[0],x[1])),Pow(x[2],x[3]))',
#   array([2.72734583, 1.42734583, 2.39685553, 1.54652184]),
#   8.119262905865934e-06),
#  ('Add(Div(age,Div(R,R)),R)',
#   'Add(Div(age,Div(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Div((xdata[0]),Div(x[0],x[1])),x[2])',
#   array([0.9032935 , 0.21741522, 3.86477715]),
#   8.119262905866009e-06),
#  ('Add(Add(R,R),Mul(R,age))',
#   'Add(Add(x[0],x[1]),Mul(x[2],age))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Mul(x[2],(xdata[0])))',
#   array([2.08238859, 1.78238859, 0.24069167]),
#   8.119262905866097e-06),
#  ('Add(Div(age,Pow(R,R)),Mul(R,R))',
#   'Add(Div(age,Pow(x[0],x[1])),Mul(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Pow(x[0],x[1])),Mul(x[2],x[3]))',
#   array([3.155914  , 1.23924601, 2.17077084, 1.7803709 ]),
#   8.11926290586665e-06),
#  ('Add(Div(age,R),R)',
#   'Add(Div(age,x[0]),x[1])',
#   'lambda x,xdata:Add(Div((xdata[0]),x[0]),x[1])',
#   array([4.15469181, 3.86477665]),
#   8.119262905867564e-06),
#  ('Add(Div(age,Mul(R,R)),Pow(R,R))',
#   'Add(Div(age,Mul(x[0],x[1])),Pow(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Mul(x[0],x[1])),Pow(x[2],x[3]))',
#   array([1.37886172, 3.01313101, 2.7625458 , 1.33041419]),
#   8.119262905868135e-06),
#  ('Add(Div(R,R),Mul(R,age))',
#   'Add(Div(x[0],x[1]),Mul(x[2],age))',
#   'lambda x,xdata:Add(Div(x[0],x[1]),Mul(x[2],(xdata[0])))',
#   array([3.80399554, 0.98427299, 0.24069166]),
#   8.119262905869295e-06),
#  ('Add(Div(age,Mul(R,R)),Mul(R,R))',
#   'Add(Div(age,Mul(x[0],x[1])),Mul(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Mul(x[0],x[1])),Mul(x[2],x[3]))',
#   array([0.63061673, 6.58830239, 1.17796974, 3.28088022]),
#   8.119262905870212e-06),
#  ('Add(Div(age,Div(R,R)),Mul(R,R))',
#   'Add(Div(age,Div(x[0],x[1])),Mul(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Div(x[0],x[1])),Mul(x[2],x[3]))',
#   array([1.16550187, 0.28052652, 2.45912451, 1.57160716]),
#   8.119262905871655e-06),
#  ('Add(Div(age,R),Mul(R,R))',
#   'Add(Div(age,x[0]),Mul(x[1],x[2]))',
#   'lambda x,xdata:Add(Div((xdata[0]),x[0]),Mul(x[1],x[2]))',
#   array([4.15469062, 2.67897617, 1.44263202]),
#   8.119262905872187e-06),
#  ('Add(Div(age,Mul(R,R)),Sub(R,R))',
#   'Add(Div(age,Mul(x[0],x[1])),Sub(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Mul(x[0],x[1])),Sub(x[2],x[3]))',
#   array([ 2.03830669,  2.03830669,  2.08238849, -1.78238925]),
#   8.119262905872765e-06),
#  ('Add(Div(age,Add(R,R)),Mul(R,R))',
#   'Add(Div(age,Add(x[0],x[1])),Mul(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Add(x[0],x[1])),Mul(x[2],x[3]))',
#   array([2.27734678, 1.87734678, 2.4730079 , 1.56278426]),
#   8.119262905875821e-06),
#  ('Add(Add(R,R),Div(age,Div(R,R)))',
#   'Add(Add(x[0],x[1]),Div(age,Div(x[2],x[3])))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[0]),Div(x[2],x[3])))',
#   array([2.53238827, 1.33238827, 1.78432992, 0.42947336]),
#   8.11926290587912e-06),
#  ('Add(Div(age,Pow(R,R)),Sub(R,R))',
#   'Add(Div(age,Pow(x[0],x[1])),Sub(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Pow(x[0],x[1])),Sub(x[2],x[3]))',
#   array([ 1.6548388 ,  2.82753157,  2.93238827, -0.93238857]),
#   8.119262905879628e-06),
#  ('Add(Div(age,Pow(R,R)),Div(R,R))',
#   'Add(Div(age,Pow(x[0],x[1])),Div(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Pow(x[0],x[1])),Div(x[2],x[3]))',
#   array([2.43190948, 1.60264976, 4.58732989, 1.18695872]),
#   8.119262905884918e-06),
#  ('Add(Div(age,R),Div(R,R))',
#   'Add(Div(age,x[0]),Div(x[1],x[2]))',
#   'lambda x,xdata:Add(Div((xdata[0]),x[0]),Div(x[1],x[2]))',
#   array([4.15469538, 7.06381827, 1.82774222]),
#   8.11926290588545e-06),
#  ('Add(Div(age,Div(R,R)),Sub(R,R))',
#   'Add(Div(age,Div(x[0],x[1])),Sub(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Div(x[0],x[1])),Sub(x[2],x[3]))',
#   array([ 3.30837396,  0.79629807,  3.63238876, -0.23238921]),
#   8.119262905887234e-06),
#  ('Add(Div(age,Add(R,R)),Sub(R,R))',
#   'Add(Div(age,Add(x[0],x[1])),Sub(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Add(x[0],x[1])),Sub(x[2],x[3]))',
#   array([2.1273481 , 2.0273481 , 4.08238844, 0.21761021]),
#   8.11926290589163e-06),
#  ('Add(Div(age,Pow(R,R)),R)',
#   'Add(Div(age,Pow(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Div((xdata[0]),Pow(x[0],x[1])),x[2])',
#   array([1.77087436, 2.49222   , 3.86477637]),
#   8.119262905893492e-06),
#  ('Add(Div(age,Div(R,R)),Pow(R,R))',
#   'Add(Div(age,Div(x[0],x[1])),Pow(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Div(x[0],x[1])),Pow(x[2],x[3]))',
#   array([2.02655421, 0.48777473, 2.4406314 , 1.51515171]),
#   8.119262905928864e-06),
#  ('Add(Add(R,R),Div(age,R))',
#   'Add(Add(x[0],x[1]),Div(age,x[2]))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[0]),x[2]))',
#   array([2.38238994, 1.48238994, 4.15470026]),
#   8.119262905992027e-06),
#  ('Add(Div(age,R),Sub(R,R))',
#   'Add(Div(age,x[0]),Sub(x[1],x[2]))',
#   'lambda x,xdata:Add(Div((xdata[0]),x[0]),Sub(x[1],x[2]))',
#   array([4.15468417, 3.98238712, 0.11761158]),
#   8.119262905992305e-06),
#  ('Add(Add(R,R),Div(age,Add(R,R)))',
#   'Add(Add(x[0],x[1]),Div(age,Add(x[2],x[3])))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[0]),Add(x[2],x[3])))',
#   array([1.13238963, 2.73238963, 1.92734664, 2.22734664]),
#   8.119262906001316e-06),
#  ('Add(Add(R,R),Div(age,Pow(R,R)))',
#   'Add(Add(x[0],x[1]),Div(age,Pow(x[2],x[3])))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[0]),Pow(x[2],x[3])))',
#   array([2.38238927, 1.48238927, 2.75041096, 1.40769636]),
#   8.11926290615069e-06),
#  ('Add(Div(age,Mul(R,R)),R)',
#   'Add(Div(age,Mul(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Div((xdata[0]),Mul(x[0],x[1])),x[2])',
#   array([1.6725002 , 2.4841304 , 3.86478238]),
#   8.119262906351959e-06),
#  ('Add(Div(age,Add(R,R)),Div(R,R))',
#   'Add(Div(age,Add(x[0],x[1])),Div(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Add(x[0],x[1])),Div(x[2],x[3]))',
#   array([1.77732956, 2.37732956, 6.69532337, 1.73239881]),
#   8.119262907849321e-06),
#  ('Add(Add(R,R),Div(weight,Div(R,R)))',
#   'Add(Add(x[0],x[1]),Div(weight,Div(x[2],x[3])))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[2]),Div(x[2],x[3])))',
#   array([2.21404701, 1.51404701, 2.12076231, 0.13686099]),
#   1.2471928976202556e-05),
#  ('Add(Add(R,R),Div(weight,Sub(R,R)))',
#   'Add(Add(x[0],x[1]),Div(weight,Sub(x[2],x[3])))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[2]),Sub(x[2],x[3])))',
#   array([ 1.81404673,  1.91404673,  9.89788462, -5.59784766]),
#   1.2471928976203839e-05),
#  ('Add(Add(R,R),Mul(R,weight))',
#   'Add(Add(x[0],x[1]),Mul(x[2],weight))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Mul(x[2],(xdata[2])))',
#   array([0.76404712, 2.96404712, 0.06453386]),
#   1.2471928976204963e-05),
#  ('Add(Div(R,R),Mul(R,weight))',
#   'Add(Div(x[0],x[1]),Mul(x[2],weight))',
#   'lambda x,xdata:Add(Div(x[0],x[1]),Mul(x[2],(xdata[2])))',
#   array([3.65813618, 0.98123486, 0.06453385]),
#   1.2471928976207635e-05),
#  ('Add(Add(R,R),Div(weight,Mul(R,R)))',
#   'Add(Add(x[0],x[1]),Div(weight,Mul(x[2],x[3])))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[2]),Mul(x[2],x[3])))',
#   array([ 3.11404633,  0.61404633, 19.23112217,  0.80576271]),
#   1.247192897622693e-05),
#  ('Add(Add(R,R),Div(weight,Add(R,R)))',
#   'Add(Add(x[0],x[1]),Div(weight,Add(x[2],x[3])))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[2]),Add(x[2],x[3])))',
#   array([2.46404623, 1.26404623, 7.2478597 , 8.2478597 ]),
#   1.2471928976232794e-05),
#  ('Add(Add(R,R),Div(weight,R))',
#   'Add(Add(x[0],x[1]),Div(weight,x[2]))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[2]),x[2]))',
#   array([ 2.41404378,  1.31404378, 15.49565478]),
#   1.2471928976895971e-05),
#  ('Add(Div(R,weight),R)',
#   'Add(Div(x[0],weight),x[1])',
#   'lambda x,xdata:Add(Div(x[0],(xdata[2])),x[1])',
#   array([-11.38275633,   5.94765204]),
#   1.3375841035662283e-05),
#  ('Add(Div(Sub(R,R),weight),R)',
#   'Add(Div(Sub(x[0],x[1]),weight),x[2])',
#   'lambda x,xdata:Add(Div(Sub(x[0],x[1]),(xdata[2])),x[2])',
#   array([-3.79138031,  7.59138202,  5.94765295]),
#   1.3375841035663367e-05),
#  ('Add(Div(Add(R,R),weight),R)',
#   'Add(Div(Add(x[0],x[1]),weight),x[2])',
#   'lambda x,xdata:Add(Div(Add(x[0],x[1]),(xdata[2])),x[2])',
#   array([-6.29137871, -5.09137871,  5.94765156]),
#   1.3375841035689703e-05),
#  ('Add(Div(Mul(R,R),weight),R)',
#   'Add(Div(Mul(x[0],x[1]),weight),x[2])',
#   'lambda x,xdata:Add(Div(Mul(x[0],x[1]),(xdata[2])),x[2])',
#   array([  0.65480953, -17.38328872,   5.94765019]),
#   1.3375841035730017e-05),
#  ('Add(Div(height,Add(R,R)),Pow(R,R))',
#   'Add(Div(height,Add(x[0],x[1])),Pow(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Add(x[0],x[1])),Pow(x[2],x[3]))',
#   array([ 10.16442681,  10.66442681,  38.76721272, -18.52105343]),
#   1.3855745824667052e-05),
#  ('Add(Div(height,R),Pow(R,R))',
#   'Add(Div(height,x[0]),Pow(x[1],x[2]))',
#   'lambda x,xdata:Add(Div((xdata[1]),x[0]),Pow(x[1],x[2]))',
#   array([ 20.82885286, 271.6000831 ,  -7.03105832]),
#   1.3855745824669529e-05),
#  ('Add(Div(height,Div(R,R)),height)',
#   'Add(Div(height,Div(x[0],x[1])),height)',
#   'lambda x,xdata:Add(Div((xdata[1]),Div(x[0],x[1])),(xdata[1]))',
#   array([ 1.23899951, -1.17951475]),
#   1.385574582467108e-05),
#  ('Add(Div(height,Mul(R,R)),height)',
#   'Add(Div(height,Mul(x[0],x[1])),height)',
#   'lambda x,xdata:Add(Div((xdata[1]),Mul(x[0],x[1])),(xdata[1]))',
#   array([ 7.31715589, -0.14355736]),
#   1.3855745824671374e-05),
#  ('Add(Div(height,Sub(R,R)),height)',
#   'Add(Div(height,Sub(x[0],x[1])),height)',
#   'lambda x,xdata:Add(Div((xdata[1]),Sub(x[0],x[1])),(xdata[1]))',
#   array([1.02366693, 2.07409846]),
#   1.3855745824826322e-05),
#  ('Add(Div(age,weight),Mul(R,R))',
#   'Add(Div(age,weight),Mul(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[0]),(xdata[2])),Mul(x[0],x[1]))',
#   array([2.44947714, 1.94053415]),
#   3.154737447304241e-05),
#  ('Add(Div(age,weight),Sub(R,R))',
#   'Add(Div(age,weight),Sub(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[0]),(xdata[2])),Sub(x[0],x[1]))',
#   array([ 3.37664729, -1.37664675]),
#   3.154737447304242e-05),
#  ('Add(Add(R,R),Div(age,weight))',
#   'Add(Add(x[0],x[1]),Div(age,weight))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[0]),(xdata[2])))',
#   array([2.07664705, 2.67664705]),
#   3.1547374473042495e-05),
#  ('Add(Div(age,weight),Pow(R,R))',
#   'Add(Div(age,weight),Pow(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[0]),(xdata[2])),Pow(x[0],x[1]))',
#   array([2.08243655, 2.12509307]),
#   3.1547374473042535e-05),
#  ('Add(Div(age,weight),R)',
#   'Add(Div(age,weight),x[0])',
#   'lambda x,xdata:Add(Div((xdata[0]),(xdata[2])),x[0])',
#   array([4.7532941]),
#   3.1547374473042535e-05),
#  ('Add(Div(age,weight),Div(R,R))',
#   'Add(Div(age,weight),Div(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[0]),(xdata[2])),Div(x[0],x[1]))',
#   array([1.90900783, 0.40161786]),
#   3.1547374473043165e-05),
#  ('Add(Div(Div(R,R),weight),R)',
#   'Add(Div(Div(x[0],x[1]),weight),x[2])',
#   'lambda x,xdata:Add(Div(Div(x[0],x[1]),(xdata[2])),x[2])',
#   array([-1.22528658e+04,  1.02867197e+04,  5.05543458e+00]),
#   3.2505100352614905e-05),
#  ('Add(Add(R,R),Div(weight,height))',
#   'Add(Add(x[0],x[1]),Div(weight,height))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[2]),(xdata[1])))',
#   array([2.24046736, 2.54046736]),
#   3.331277442298334e-05),
#  ('Add(Div(Add(R,R),age),R)',
#   'Add(Div(Add(x[0],x[1]),age),x[2])',
#   'lambda x,xdata:Add(Div(Add(x[0],x[1]),(xdata[0])),x[2])',
#   array([-0.80472972,  0.79527028,  4.98411076]),
#   3.5473529722228996e-05),
#  ('Add(Div(R,age),R)',
#   'Add(Div(x[0],age),x[1])',
#   'lambda x,xdata:Add(Div(x[0],(xdata[0])),x[1])',
#   array([-0.00945945,  4.98411101]),
#   3.547352972223253e-05),
#  ('Add(Div(Mul(R,R),age),R)',
#   'Add(Div(Mul(x[0],x[1]),age),x[2])',
#   'lambda x,xdata:Add(Div(Mul(x[0],x[1]),(xdata[0])),x[2])',
#   array([-2.59453443e-03,  3.64592101e+00,  4.98411090e+00]),
#   3.547352972224245e-05),
#  ('Add(Div(Sub(R,R),age),R)',
#   'Add(Div(Sub(x[0],x[1]),age),x[2])',
#   'lambda x,xdata:Add(Div(Sub(x[0],x[1]),(xdata[0])),x[2])',
#   array([0.74526585, 0.75472526, 4.98411078]),
#   3.5473529722242474e-05),
#  ('Add(Div(Div(R,R),age),R)',
#   'Add(Div(Div(x[0],x[1]),age),x[2])',
#   'lambda x,xdata:Add(Div(Div(x[0],x[1]),(xdata[0])),x[2])',
#   array([-0.01583355,  1.67383185,  4.98411223]),
#   3.547352972229794e-05),
#  ('Add(Div(age,height),Sub(R,R))',
#   'Add(Div(age,height),Sub(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[0]),(xdata[1])),Sub(x[0],x[1]))',
#   array([ 3.30675794, -1.6067535 ]),
#   3.558190364151349e-05),
#  ('Add(Div(age,height),R)',
#   'Add(Div(age,height),x[0])',
#   'lambda x,xdata:Add(Div((xdata[0]),(xdata[1])),x[0])',
#   array([4.91351142]),
#   3.55819036415135e-05),
#  ('Add(Add(R,R),Div(age,height))',
#   'Add(Add(x[0],x[1]),Div(age,height))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[0]),(xdata[1])))',
#   array([1.65675574, 3.25675574]),
#   3.5581903641513515e-05),
#  ('Add(Div(age,height),Mul(R,R))',
#   'Add(Div(age,height),Mul(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[0]),(xdata[1])),Mul(x[0],x[1]))',
#   array([1.95010826, 2.51960955]),
#   3.558190364151361e-05),
#  ('Add(Div(age,height),Div(R,R))',
#   'Add(Div(age,height),Div(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[0]),(xdata[1])),Div(x[0],x[1]))',
#   array([7.00048222, 1.42474117]),
#   3.558190364151406e-05),
#  ('Add(Div(age,height),Pow(R,R))',
#   'Add(Div(age,height),Pow(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[0]),(xdata[1])),Pow(x[0],x[1]))',
#   array([2.69236716, 1.60738622]),
#   3.5581903641524845e-05),
#  ('Add(Div(Div(R,R),height),R)',
#   'Add(Div(Div(x[0],x[1]),height),x[2])',
#   'lambda x,xdata:Add(Div(Div(x[0],x[1]),(xdata[1])),x[2])',
#   array([-1822.57716438,  3989.06277706,     4.95600954]),
#   3.7127573819316816e-05),
#  ('Add(Add(R,R),Div(weight,Pow(R,R)))',
#   'Add(Add(x[0],x[1]),Div(weight,Pow(x[2],x[3])))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[2]),Pow(x[2],x[3])))',
#   array([ 1.27557486,  3.67557486,  4.9320722 , 19.9521583 ]),
#   3.723781815801509e-05),
#  ('Add(Add(Add(R,R),R),R)',
#   'Add(Add(Add(x[0],x[1]),x[2]),x[3])',
#   'lambda x,xdata:Add(Add(Add(x[0],x[1]),x[2]),x[3])',
#   array([1.23778745, 1.53778745, 2.13778745, 0.03778745]),
#   3.723781815802626e-05),
#  ('Add(Add(Pow(R,R),R),R)',
#   'Add(Add(Pow(x[0],x[1]),x[2]),x[3])',
#   'lambda x,xdata:Add(Add(Pow(x[0],x[1]),x[2]),x[3])',
#   array([1.83429061, 0.2009134 , 2.26076242, 1.56076242]),
#   3.723781815802626e-05),
#  ('Add(Add(R,R),Div(R,R))',
#   'Add(Add(x[0],x[1]),Div(x[2],x[3]))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div(x[2],x[3]))',
#   array([2.62523259, 1.52523259, 1.57742732, 1.97009816]),
#   3.723781815802626e-05),
#  ('Add(Add(R,R),Div(Sub(R,R),R))',
#   'Add(Add(x[0],x[1]),Div(Sub(x[2],x[3]),x[4]))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div(Sub(x[2],x[3]),x[4]))',
#   array([2.65144387, 2.45144387, 0.13930483, 0.26069517, 0.8       ]),
#   3.723781815802626e-05),
#  ('Add(Add(R,R),Div(age,age))',
#   'Add(Add(x[0],x[1]),Div(age,age))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[0]),(xdata[0])))',
#   array([1.5255749, 2.4255749]),
#   3.723781815802626e-05),
#  ('Add(Add(R,R),R)',
#   'Add(Add(x[0],x[1]),x[2])',
#   'lambda x,xdata:Add(Add(x[0],x[1]),x[2])',
#   array([2.21704994, 2.71704994, 0.01704994]),
#   3.723781815802626e-05),
#  ('Add(Div(Mul(R,R),Pow(R,R)),R)',
#   'Add(Div(Mul(x[0],x[1]),Pow(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Mul(x[0],x[1]),Pow(x[2],x[3])),x[4])',
#   array([ 3.14216193,  0.81861835,  2.46564157, -0.39570606,  1.27495017]),
#   3.723781815802626e-05),
#  ('Add(Div(Mul(R,R),Sub(R,R)),R)',
#   'Add(Div(Mul(x[0],x[1]),Sub(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Mul(x[0],x[1]),Sub(x[2],x[3])),x[4])',
#   array([1.65827184, 2.2357902 , 2.12790932, 0.37209028, 2.83957233]),
#   3.723781815802626e-05),
#  ('Add(Div(Pow(R,R),R),Div(R,R))',
#   'Add(Div(Pow(x[0],x[1]),x[2]),Div(x[3],x[4]))',
#   'lambda x,xdata:Add(Div(Pow(x[0],x[1]),x[2]),Div(x[3],x[4]))',
#   array([2.54772039, 1.51591097, 1.99232769, 2.55867405, 0.88860159]),
#   3.723781815802626e-05),
#  ('Add(Div(R,Div(R,R)),R)',
#   'Add(Div(x[0],Div(x[1],x[2])),x[3])',
#   'lambda x,xdata:Add(Div(x[0],Div(x[1],x[2])),x[3])',
#   array([1.48625207, 1.23113215, 2.95205864, 1.3873543 ]),
#   3.723781815802626e-05),
#  ('Add(Div(Sub(R,R),Add(R,R)),R)',
#   'Add(Div(Sub(x[0],x[1]),Add(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Sub(x[0],x[1]),Add(x[2],x[3])),x[4])',
#   array([1.37087764, 1.22912104, 2.13414299, 0.63414299, 4.89994245]),
#   3.723781815802626e-05),
#  ('Add(Div(Sub(R,R),Pow(R,R)),R)',
#   'Add(Div(Sub(x[0],x[1]),Pow(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Sub(x[0],x[1]),Pow(x[2],x[3])),x[4])',
#   array([1.71093782, 1.28906203, 1.37332254, 3.57231331, 4.81531287]),
#   3.723781815802626e-05),
#  ('Add(Div(Sub(R,R),R),Sub(R,R))',
#   'Add(Div(Sub(x[0],x[1]),x[2]),Sub(x[3],x[4]))',
#   'lambda x,xdata:Add(Div(Sub(x[0],x[1]),x[2]),Sub(x[3],x[4]))',
#   array([ 0.68855921,  0.81144043,  1.97889213,  4.75662342, -0.25662235]),
#   3.723781815802626e-05),
#  ('Add(Div(Sub(R,R),Sub(R,R)),R)',
#   'Add(Div(Sub(x[0],x[1]),Sub(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Sub(x[0],x[1]),Sub(x[2],x[3])),x[4])',
#   array([2.329917  , 1.17008274, 2.34854618, 1.85145206, 2.61792112]),
#   3.723781815802626e-05),
#  ('Add(Div(age,age),R)',
#   'Add(Div(age,age),x[0])',
#   'lambda x,xdata:Add(Div((xdata[0]),(xdata[0])),x[0])',
#   array([3.9511498]),
#   3.723781815802626e-05),
#  ('Add(Add(R,R),Div(height,height))',
#   'Add(Add(x[0],x[1]),Div(height,height))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[1]),(xdata[1])))',
#   array([1.82557491, 2.12557491]),
#   3.723781815802627e-05),
#  ('Add(Add(R,R),Div(weight,weight))',
#   'Add(Add(x[0],x[1]),Div(weight,weight))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[2]),(xdata[2])))',
#   array([1.37557491, 2.57557491]),
#   3.723781815802627e-05),
#  ('Add(Add(R,Sub(R,R)),R)',
#   'Add(Add(x[0],Sub(x[1],x[2])),x[3])',
#   'lambda x,xdata:Add(Add(x[0],Sub(x[1],x[2])),x[3])',
#   array([3.28778745, 0.88778745, 1.91221253, 2.68778745]),
#   3.723781815802627e-05),
#  ('Add(Div(Add(R,R),R),Pow(R,R))',
#   'Add(Div(Add(x[0],x[1]),x[2]),Pow(x[3],x[4]))',
#   'lambda x,xdata:Add(Div(Add(x[0],x[1]),x[2]),Pow(x[3],x[4]))',
#   array([2.47611246, 1.87611246, 1.67812994, 2.33690396, 1.01041391]),
#   3.723781815802627e-05),
#  ('Add(Div(Add(R,R),Sub(R,R)),R)',
#   'Add(Div(Add(x[0],x[1]),Sub(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Add(x[0],x[1]),Sub(x[2],x[3])),x[4])',
#   array([ 7.43612707e-01,  2.34361271e+00,  2.60161518e+00, -1.61535150e-03,
#           3.76522894e+00]),
#   3.723781815802627e-05),
#  ('Add(Div(Mul(R,R),Mul(R,R)),R)',
#   'Add(Div(Mul(x[0],x[1]),Mul(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Mul(x[0],x[1]),Mul(x[2],x[3])),x[4])',
#   array([2.86301946, 2.49436362, 1.77767317, 1.17410334, 1.52957672]),
#   3.723781815802627e-05),
#  ('Add(Div(Mul(R,R),R),R)',
#   'Add(Div(Mul(x[0],x[1]),x[2]),x[3])',
#   'lambda x,xdata:Add(Div(Mul(x[0],x[1]),x[2]),x[3])',
#   array([1.20953974, 1.67640831, 1.05426208, 3.02783066]),
#   3.723781815802627e-05),
#  ('Add(Div(R,Add(R,R)),R)',
#   'Add(Div(x[0],Add(x[1],x[2])),x[3])',
#   'lambda x,xdata:Add(Div(x[0],Add(x[1],x[2])),x[3])',
#   array([1.66774699, 1.59907767, 0.79907767, 4.25572072]),
#   3.723781815802627e-05),
#  ('Add(Div(R,Pow(R,R)),R)',
#   'Add(Div(x[0],Pow(x[1],x[2])),x[3])',
#   'lambda x,xdata:Add(Div(x[0],Pow(x[1],x[2])),x[3])',
#   array([1.62711190e+00, 6.66536268e-01, 3.21234532e-03, 3.32191621e+00]),
#   3.723781815802627e-05),
#  ('Add(Div(R,R),Sub(R,R))',
#   'Add(Div(x[0],x[1]),Sub(x[2],x[3]))',
#   'lambda x,xdata:Add(Div(x[0],x[1]),Sub(x[2],x[3]))',
#   array([ 3.25221728,  1.30079351,  1.67548508, -0.77548522]),
#   3.723781815802627e-05),
#  ('Add(Div(age,age),Pow(R,R))',
#   'Add(Div(age,age),Pow(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[0]),(xdata[0])),Pow(x[0],x[1]))',
#   array([1.77073877, 2.40464512]),
#   3.723781815802627e-05),
#  ('Add(Add(Div(R,R),R),R)',
#   'Add(Add(Div(x[0],x[1]),x[2]),x[3])',
#   'lambda x,xdata:Add(Add(Div(x[0],x[1]),x[2]),x[3])',
#   array([1.9364126 , 1.45246036, 1.8089775 , 1.8089775 ]),
#   3.723781815802628e-05),
#  ('Add(Add(R,R),Div(Mul(R,R),R))',
#   'Add(Add(x[0],x[1]),Div(Mul(x[2],x[3]),x[4]))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div(Mul(x[2],x[3]),x[4]))',
#   array([ 2.63410539,  2.43410539, -0.30913644,  1.07643426,  2.84266391]),
#   3.723781815802628e-05),
#  ('Add(Div(Add(R,R),R),Sub(R,R))',
#   'Add(Div(Add(x[0],x[1]),x[2]),Sub(x[3],x[4]))',
#   'lambda x,xdata:Add(Div(Add(x[0],x[1]),x[2]),Sub(x[3],x[4]))',
#   array([2.89544655, 2.09544655, 1.20205108, 1.19958442, 0.40041549]),
#   3.723781815802628e-05),
#  ('Add(Div(R,Mul(R,R)),R)',
#   'Add(Div(x[0],Mul(x[1],x[2])),x[3])',
#   'lambda x,xdata:Add(Div(x[0],Mul(x[1],x[2])),x[3])',
#   array([2.43886505, 1.1786994 , 1.34972828, 3.41816323]),
#   3.723781815802628e-05),
#  ('Add(Div(R,R),Pow(R,R))',
#   'Add(Div(x[0],x[1]),Pow(x[2],x[3]))',
#   'lambda x,xdata:Add(Div(x[0],x[1]),Pow(x[2],x[3]))',
#   array([2.0111953 , 1.2825141 , 1.94522501, 1.83167862]),
#   3.723781815802628e-05),
#  ('Add(Div(Div(R,R),Add(R,R)),R)',
#   'Add(Div(Div(x[0],x[1]),Add(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Div(x[0],x[1]),Add(x[2],x[3])),x[4])',
#   array([1.8784986 , 2.47769525, 0.03897884, 0.43897884, 3.36489281]),
#   3.723781815802629e-05),
#  ('Add(Div(Div(R,R),R),Mul(R,R))',
#   'Add(Div(Div(x[0],x[1]),x[2]),Mul(x[3],x[4]))',
#   'lambda x,xdata:Add(Div(Div(x[0],x[1]),x[2]),Mul(x[3],x[4]))',
#   array([2.15209671, 1.0501104 , 1.0501104 , 1.28383227, 2.33639952]),
#   3.723781815802629e-05),
#  ('Add(Div(Mul(R,R),R),Div(R,R))',
#   'Add(Div(Mul(x[0],x[1]),x[2]),Div(x[3],x[4]))',
#   'lambda x,xdata:Add(Div(Mul(x[0],x[1]),x[2]),Div(x[3],x[4]))',
#   array([2.17264268, 2.85367462, 2.3037822 , 2.53308219, 1.1208742 ]),
#   3.723781815802629e-05),
#  ('Add(Div(Pow(R,R),R),R)',
#   'Add(Div(Pow(x[0],x[1]),x[2]),x[3])',
#   'lambda x,xdata:Add(Div(Pow(x[0],x[1]),x[2]),x[3])',
#   array([1.45595765, 2.24974675, 1.08323083, 2.80172462]),
#   3.723781815802629e-05),
#  ('Add(Div(Sub(R,R),Mul(R,R)),R)',
#   'Add(Div(Sub(x[0],x[1]),Mul(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Sub(x[0],x[1]),Mul(x[2],x[3])),x[4])',
#   array([0.56736246, 2.83263762, 1.77152916, 1.35929404, 5.89186733]),
#   3.723781815802629e-05),
#  ('Add(Div(Sub(R,R),R),R)',
#   'Add(Div(Sub(x[0],x[1]),x[2]),x[3])',
#   'lambda x,xdata:Add(Div(Sub(x[0],x[1]),x[2]),x[3])',
#   array([ 2.22649536, -0.62649553,  0.88476196,  1.72656401]),
#   3.723781815802629e-05),
#  ('Add(Div(Pow(R,R),R),Sub(R,R))',
#   'Add(Div(Pow(x[0],x[1]),x[2]),Sub(x[3],x[4]))',
#   'lambda x,xdata:Add(Div(Pow(x[0],x[1]),x[2]),Sub(x[3],x[4]))',
#   array([2.27787625, 2.72197217, 1.68748709, 1.58998862, 2.21001127]),
#   3.7237818158026296e-05),
#  ('Add(Div(height,height),Div(R,R))',
#   'Add(Div(height,height),Div(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[1]),(xdata[1])),Div(x[0],x[1]))',
#   array([3.46502104, 0.87696523]),
#   3.7237818158026296e-05),
#  ('Add(Div(Pow(R,R),Div(R,R)),R)',
#   'Add(Div(Pow(x[0],x[1]),Div(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Pow(x[0],x[1]),Div(x[2],x[3])),x[4])',
#   array([2.6088756 , 1.47505507, 2.75200191, 2.90390176, 0.60979941]),
#   3.723781815802632e-05),
#  ('Add(Div(R,Sub(R,R)),R)',
#   'Add(Div(x[0],Sub(x[1],x[2])),x[3])',
#   'lambda x,xdata:Add(Div(x[0],Sub(x[1],x[2])),x[3])',
#   array([3.25298211, 0.54678832, 2.25321152, 6.85746601]),
#   3.723781815802632e-05),
#  ('Add(Div(Sub(R,R),R),Pow(R,R))',
#   'Add(Div(Sub(x[0],x[1]),x[2]),Pow(x[3],x[4]))',
#   'lambda x,xdata:Add(Div(Sub(x[0],x[1]),x[2]),Pow(x[3],x[4]))',
#   array([2.56569053, 2.63430943, 1.04192331, 1.84562649, 2.63182809]),
#   3.723781815802632e-05),
#  ('Add(Div(Div(R,R),Div(R,R)),R)',
#   'Add(Div(Div(x[0],x[1]),Div(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Div(x[0],x[1]),Div(x[2],x[3])),x[4])',
#   array([1.58299168, 0.83253033, 2.35920533, 2.76496732, 2.72270019]),
#   3.7237818158026336e-05),
#  ('Add(Div(Div(R,R),Sub(R,R)),R)',
#   'Add(Div(Div(x[0],x[1]),Sub(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Div(x[0],x[1]),Sub(x[2],x[3])),x[4])',
#   array([1.08871352, 2.48447209, 1.47574933, 1.32421336, 2.05937984]),
#   3.7237818158026336e-05),
#  ('Add(Div(Sub(R,R),R),Div(R,R))',
#   'Add(Div(Sub(x[0],x[1]),x[2]),Div(x[3],x[4]))',
#   'lambda x,xdata:Add(Div(Sub(x[0],x[1]),x[2]),Div(x[3],x[4]))',
#   array([2.36235844, 0.33764061, 0.47194567, 1.2372726 , 1.87182073]),
#   3.723781815802634e-05),
#  ('Add(Div(Div(R,R),Pow(R,R)),R)',
#   'Add(Div(Div(x[0],x[1]),Pow(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Div(x[0],x[1]),Pow(x[2],x[3])),x[4])',
#   array([0.51945195, 0.43042721, 0.44429909, 1.33644937, 1.38245337]),
#   3.723781815802635e-05),
#  ('Add(Div(Div(R,R),R),Pow(R,R))',
#   'Add(Div(Div(x[0],x[1]),x[2]),Pow(x[3],x[4]))',
#   'lambda x,xdata:Add(Div(Div(x[0],x[1]),x[2]),Pow(x[3],x[4]))',
#   array([ 3.03305568,  0.99866436,  0.65018612,  2.27817481, -1.54600389]),
#   3.7237818158026384e-05),
#  ('Add(Div(Sub(R,R),Div(R,R)),R)',
#   'Add(Div(Sub(x[0],x[1]),Div(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Sub(x[0],x[1]),Div(x[2],x[3])),x[4])',
#   array([2.06671276, 0.73328548, 0.61282635, 1.63859732, 1.38578364]),
#   3.723781815802642e-05),
#  ('Add(Div(Div(R,R),R),R)',
#   'Add(Div(Div(x[0],x[1]),x[2]),x[3])',
#   'lambda x,xdata:Add(Div(Div(x[0],x[1]),x[2]),x[3])',
#   array([2.00540413, 1.1291846 , 0.79216009, 2.70920967]),
#   3.723781815802644e-05),
#  ('Add(Add(R,R),Div(Pow(R,R),R))',
#   'Add(Add(x[0],x[1]),Div(Pow(x[2],x[3]),x[4]))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div(Pow(x[2],x[3]),x[4]))',
#   array([1.13582896, 1.23582896, 1.78001059, 2.29286957, 1.45429379]),
#   3.723781815802645e-05),
#  ('Add(Div(Pow(R,R),Sub(R,R)),R)',
#   'Add(Div(Pow(x[0],x[1]),Sub(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Pow(x[0],x[1]),Sub(x[2],x[3])),x[4])',
#   array([0.18174145, 0.60997412, 2.58183283, 2.41814685, 2.79204065]),
#   3.7237818158026485e-05),
#  ('Add(Div(Mul(R,R),R),Sub(R,R))',
#   'Add(Div(Mul(x[0],x[1]),x[2]),Sub(x[3],x[4]))',
#   'lambda x,xdata:Add(Div(Mul(x[0],x[1]),x[2]),Sub(x[3],x[4]))',
#   array([2.59184441, 2.46979323, 1.02832707, 1.21308268, 2.48691715]),
#   3.723781815802649e-05),
#  ('Add(Div(Pow(R,R),Mul(R,R)),R)',
#   'Add(Div(Pow(x[0],x[1]),Mul(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Pow(x[0],x[1]),Mul(x[2],x[3])),x[4])',
#   array([2.67018038, 1.78362589, 1.33283015, 1.32507421, 1.68697161]),
#   3.723781815802649e-05),
#  ('Add(Div(Pow(R,R),R),Pow(R,R))',
#   'Add(Div(Pow(x[0],x[1]),x[2]),Pow(x[3],x[4]))',
#   'lambda x,xdata:Add(Div(Pow(x[0],x[1]),x[2]),Pow(x[3],x[4]))',
#   array([1.00763325, 0.3716024 , 0.32397628, 1.91463721, 0.95192107]),
#   3.7237818158026594e-05),
#  ('Add(Div(Add(R,R),Add(R,R)),R)',
#   'Add(Div(Add(x[0],x[1]),Add(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Add(x[0],x[1]),Add(x[2],x[3])),x[4])',
#   array([2.65597996, 1.65597996, 1.25821098, 0.15821098, 1.90688769]),
#   3.723781815802669e-05),
#  ('Add(Add(Mul(R,R),R),R)',
#   'Add(Add(Mul(x[0],x[1]),x[2]),x[3])',
#   'lambda x,xdata:Add(Add(Mul(x[0],x[1]),x[2]),x[3])',
#   array([0.90224949, 2.68335278, 1.51504801, 1.01504801]),
#   3.723781815802674e-05),
#  ('Add(Div(Mul(R,R),Add(R,R)),R)',
#   'Add(Div(Mul(x[0],x[1]),Add(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Mul(x[0],x[1]),Add(x[2],x[3])),x[4])',
#   array([2.73508935, 2.96827646, 0.98610329, 2.88610329, 2.85454116]),
#   3.7237818158026905e-05),
#  ('Add(Div(Div(R,R),R),Sub(R,R))',
#   'Add(Div(Div(x[0],x[1]),x[2]),Sub(x[3],x[4]))',
#   'lambda x,xdata:Add(Div(Div(x[0],x[1]),x[2]),Sub(x[3],x[4]))',
#   array([3.35923641, 0.43951703, 1.66760834, 1.98396434, 1.61603548]),
#   3.723781815802695e-05),
#  ('Add(Div(height,Pow(R,R)),Mul(R,R))',
#   'Add(Div(height,Pow(x[0],x[1])),Mul(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Pow(x[0],x[1])),Mul(x[2],x[3]))',
#   array([11.28462076, 72.50056686,  0.68798779,  7.19656614]),
#   3.723781815802726e-05),
#  ('Add(Div(Add(R,R),R),Div(R,R))',
#   'Add(Div(Add(x[0],x[1]),x[2]),Div(x[3],x[4]))',
#   'lambda x,xdata:Add(Div(Add(x[0],x[1]),x[2]),Div(x[3],x[4]))',
#   array([0.71530431, 0.71530431, 0.39734785, 1.20669367, 0.89334654]),
#   3.723781815802733e-05),
#  ('Add(Div(R,R),Div(R,R))',
#   'Add(Div(x[0],x[1]),Div(x[2],x[3]))',
#   'lambda x,xdata:Add(Div(x[0],x[1]),Div(x[2],x[3]))',
#   array([0.80816727, 0.21059987, 1.7907368 , 1.60792207]),
#   3.72378181580274e-05),
#  ('Add(Div(Mul(R,R),Div(R,R)),R)',
#   'Add(Div(Mul(x[0],x[1]),Div(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Mul(x[0],x[1]),Div(x[2],x[3])),x[4])',
#   array([0.75340282, 2.35490157, 1.49775442, 2.65931452, 1.80101512]),
#   3.7237818158027434e-05),
#  ('Add(Add(R,R),Div(Add(R,R),R))',
#   'Add(Add(x[0],x[1]),Div(Add(x[2],x[3]),x[4]))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div(Add(x[2],x[3]),x[4]))',
#   array([2.93344479, 0.43344479, 1.24237708, 2.24237708, 2.19960995]),
#   3.723781815802747e-05),
#  ('Add(Div(Add(R,R),Div(R,R)),R)',
#   'Add(Div(Add(x[0],x[1]),Div(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Add(x[0],x[1]),Div(x[2],x[3])),x[4])',
#   array([3.04482105, 2.94482105, 1.39643026, 1.07644645, 0.33399887]),
#   3.723781815802802e-05),
#  ('Add(Div(Div(R,R),R),Div(R,R))',
#   'Add(Div(Div(x[0],x[1]),x[2]),Div(x[3],x[4]))',
#   'lambda x,xdata:Add(Div(Div(x[0],x[1]),x[2]),Div(x[3],x[4]))',
#   array([2.14547381, 3.05598087, 0.15985178, 1.5747196 , 2.81590623]),
#   3.7237818158028396e-05),
#  ('Add(Div(age,age),Sub(R,R))',
#   'Add(Div(age,age),Sub(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[0]),(xdata[0])),Sub(x[0],x[1]))',
#   array([ 2.72557442, -1.22557513]),
#   3.723781815802861e-05),
#  ('Add(Div(age,age),Div(R,R))',
#   'Add(Div(age,age),Div(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[0]),(xdata[0])),Div(x[0],x[1]))',
#   array([5.71256759, 1.44579867]),
#   3.7237818158029636e-05),
#  ('Add(Div(Mul(R,R),R),Mul(R,R))',
#   'Add(Div(Mul(x[0],x[1]),x[2]),Mul(x[3],x[4]))',
#   'lambda x,xdata:Add(Div(Mul(x[0],x[1]),x[2]),Mul(x[3],x[4]))',
#   array([-0.04193148,  2.14117429,  1.29652538,  2.6269139 ,  1.9111392 ]),
#   3.72378181580298e-05),
#  ('Add(Div(Div(R,R),Mul(R,R)),R)',
#   'Add(Div(Div(x[0],x[1]),Mul(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Div(x[0],x[1]),Mul(x[2],x[3])),x[4])',
#   array([2.07723706, 1.58578209, 2.87728672, 1.91989035, 4.71402135]),
#   3.7237818158031276e-05),
#  ('Add(Div(Pow(R,R),Pow(R,R)),R)',
#   'Add(Div(Pow(x[0],x[1]),Pow(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Pow(x[0],x[1]),Pow(x[2],x[3])),x[4])',
#   array([1.48723818, 2.63651632, 0.60354376, 0.74585153, 0.80120128]),
#   3.723781815803758e-05),
#  ('Add(Div(Add(R,R),Mul(R,R)),R)',
#   'Add(Div(Add(x[0],x[1]),Mul(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Add(x[0],x[1]),Mul(x[2],x[3])),x[4])',
#   array([3.06566838, 2.26566838, 1.98733297, 1.71710237, 3.38883172]),
#   3.7237818158038764e-05),
#  ('Add(Div(Pow(R,R),Add(R,R)),R)',
#   'Add(Div(Pow(x[0],x[1]),Add(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Pow(x[0],x[1]),Add(x[2],x[3])),x[4])',
#   array([-0.00659747,  0.39098648,  0.573464  ,  1.673464  ,  5.01364013]),
#   3.7237818158038764e-05),
#  ('Add(Div(R,R),Mul(R,R))',
#   'Add(Div(x[0],x[1]),Mul(x[2],x[3]))',
#   'lambda x,xdata:Add(Div(x[0],x[1]),Mul(x[2],x[3]))',
#   array([1.77895665, 0.5440284 , 1.56634437, 1.07331459]),
#   3.7237818158038784e-05),
#  ('Add(Div(Pow(R,R),R),Mul(R,R))',
#   'Add(Div(Pow(x[0],x[1]),x[2]),Mul(x[3],x[4]))',
#   'lambda x,xdata:Add(Div(Pow(x[0],x[1]),x[2]),Mul(x[3],x[4]))',
#   array([1.6636362 , 1.3829983 , 2.86650328, 1.62144997, 2.61855384]),
#   3.723781815803926e-05),
#  ('Add(Div(R,R),R)',
#   'Add(Div(x[0],x[1]),x[2])',
#   'lambda x,xdata:Add(Div(x[0],x[1]),x[2])',
#   array([3.06310774, 1.19282557, 2.38320647]),
#   3.723781815803949e-05),
#  ('Add(Div(Sub(R,R),R),Mul(R,R))',
#   'Add(Div(Sub(x[0],x[1]),x[2]),Mul(x[3],x[4]))',
#   'lambda x,xdata:Add(Div(Sub(x[0],x[1]),x[2]),Mul(x[3],x[4]))',
#   array([1.08910347, 2.21089653, 1.41622301, 3.15272043, 1.82168106]),
#   3.72378181580431e-05),
#  ('Add(Div(Add(R,R),Pow(R,R)),R)',
#   'Add(Div(Add(x[0],x[1]),Pow(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Add(x[0],x[1]),Pow(x[2],x[3])),x[4])',
#   array([2.04688048, 1.54688048, 2.26326045, 1.74985591, 4.0905223 ]),
#   3.723781815804364e-05),
#  ('Add(Div(Mul(R,R),R),Pow(R,R))',
#   'Add(Div(Mul(x[0],x[1]),x[2]),Pow(x[3],x[4]))',
#   'lambda x,xdata:Add(Div(Mul(x[0],x[1]),x[2]),Pow(x[3],x[4]))',
#   array([1.42425573, 1.45591418, 2.83073965, 2.54036014, 1.54403028]),
#   3.723781815804609e-05),
#  ('Add(Add(R,R),Div(Div(R,R),R))',
#   'Add(Add(x[0],x[1]),Div(Div(x[2],x[3]),x[4]))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div(Div(x[2],x[3]),x[4]))',
#   array([1.88339545, 2.68339545, 2.16986082, 2.11372669, 2.67083512]),
#   3.723781815805171e-05),
#  ('Add(Div(Add(R,R),R),Mul(R,R))',
#   'Add(Div(Add(x[0],x[1]),x[2]),Mul(x[3],x[4]))',
#   'lambda x,xdata:Add(Div(Add(x[0],x[1]),x[2]),Mul(x[3],x[4]))',
#   array([0.9526095 , 2.3526095 , 1.34829474, 1.06163957, 2.3546052 ]),
#   3.723781815805357e-05),
#  ('Add(Div(Add(R,R),R),R)',
#   'Add(Div(Add(x[0],x[1]),x[2]),x[3])',
#   'lambda x,xdata:Add(Div(Add(x[0],x[1]),x[2]),x[3])',
#   array([2.90104669, 1.50104669, 1.1277492 , 1.04771547]),
#   3.7237818158092886e-05),
#  ('Add(Div(age,age),Mul(R,R))',
#   'Add(Div(age,age),Mul(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[0]),(xdata[0])),Mul(x[0],x[1]))',
#   array([1.56023293, 2.5324091 ]),
#   3.723781815812755e-05),
#  ('Add(Add(R,R),Div(height,Pow(R,R)))',
#   'Add(Add(x[0],x[1]),Div(height,Pow(x[2],x[3])))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[1]),Pow(x[2],x[3])))',
#   array([  2.77557297,   2.17557297,  47.65804134, 121.29201194]),
#   3.723781815853249e-05),
#  ('Add(Div(Pow(R,R),weight),R)',
#   'Add(Div(Pow(x[0],x[1]),weight),x[2])',
#   'lambda x,xdata:Add(Div(Pow(x[0],x[1]),(xdata[2])),x[2])',
#   array([0.02999856, 4.1812992 , 4.9511499 ]),
#   3.723781995602919e-05),
#  ('Add(Add(R,R),Div(height,Mul(R,R)))',
#   'Add(Add(x[0],x[1]),Div(height,Mul(x[2],x[3])))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[1]),Mul(x[2],x[3])))',
#   array([ 2.72557702e+00,  2.22557702e+00,  8.60793824e+03, -2.74220217e+03]),
#   3.723790181181175e-05),
#  ('Add(Div(Pow(R,R),age),R)',
#   'Add(Div(Pow(x[0],x[1]),age),x[2])',
#   'lambda x,xdata:Add(Div(Pow(x[0],x[1]),(xdata[0])),x[2])',
#   array([35.90327771, -4.26255374,  4.95114981]),
#   3.7237905837311745e-05),
#  ('Add(Div(height,Mul(R,R)),Sub(R,R))',
#   'Add(Div(height,Mul(x[0],x[1])),Sub(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Mul(x[0],x[1])),Sub(x[2],x[3]))',
#   array([-1.05576663e+03,  5.89045261e+03,  3.21864467e+00, -1.73252073e+00]),
#   3.723813567608245e-05),
#  ('Add(Div(height,Mul(R,R)),Mul(R,R))',
#   'Add(Div(height,Mul(x[0],x[1])),Mul(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Mul(x[0],x[1])),Mul(x[2],x[3]))',
#   array([ 3.55400545e+03, -6.09904364e+02, -2.65544383e-02, -1.86454416e+02]),
#   3.7238729135067466e-05),
#  ('Add(Div(age,Sub(R,R)),Sub(R,R))',
#   'Add(Div(age,Sub(x[0],x[1])),Sub(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Sub(x[0],x[1])),Sub(x[2],x[3]))',
#   array([-2.26853186e+04,  2.26869647e+04,  4.52308361e+00, -4.28166530e-01]),
#   3.7243151113262666e-05),
#  ('Add(Div(age,Sub(R,R)),R)',
#   'Add(Div(age,Sub(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Div((xdata[0]),Sub(x[0],x[1])),x[2])',
#   array([-1.62642638e+04,  1.62687174e+04,  4.95128854e+00]),
#   3.724525592480498e-05),
#  ('Add(Div(age,Sub(R,R)),Mul(R,R))',
#   'Add(Div(age,Sub(x[0],x[1])),Mul(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Sub(x[0],x[1])),Mul(x[2],x[3]))',
#   array([-1.60598153e+04,  1.60637337e+04,  3.57620375e-02,  1.38439190e+02]),
#   3.724535677481869e-05),
#  ('Add(Add(R,R),Div(age,Sub(R,R)))',
#   'Add(Add(x[0],x[1]),Div(age,Sub(x[2],x[3])))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[0]),Sub(x[2],x[3])))',
#   array([ 2.57565453e+00,  2.37565453e+00, -1.45149533e+04,  1.45193298e+04]),
#   3.72461522574649e-05),
#  ('Add(Add(R,R),Div(height,Sub(R,R)))',
#   'Add(Add(x[0],x[1]),Div(height,Sub(x[2],x[3])))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[1]),Sub(x[2],x[3])))',
#   array([ 2.57585796e+00,  2.37585809e+00, -7.59269388e+04,  7.59061359e+04]),
#   3.7250824998410046e-05),
#  ('Add(Div(height,Sub(R,R)),R)',
#   'Add(Div(height,Sub(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Div((xdata[1]),Sub(x[0],x[1])),x[2])',
#   array([9.05084278e+04, 1.36961380e+05, 4.95509771e+00]),
#   3.728044899189247e-05),
#  ('Add(Div(age,Sub(R,R)),Div(R,R))',
#   'Add(Div(age,Sub(x[0],x[1])),Div(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Sub(x[0],x[1])),Div(x[2],x[3]))',
#   array([-12023.96054215,  12547.08571671, -42254.92761591,  -7376.45210001]),
#   5.7665676946533596e-05),
#  ('Add(Div(height,Sub(R,R)),Div(R,R))',
#   'Add(Div(height,Sub(x[0],x[1])),Div(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Sub(x[0],x[1])),Div(x[2],x[3]))',
#   array([-19764441.87369604, -14768008.65182991, -32680437.52072855,
#           -5177782.91487543]),
#   9.983376147269774e-05),
#  ('Add(Div(age,Div(R,R)),age)',
#   'Add(Div(age,Div(x[0],x[1])),age)',
#   'lambda x,xdata:Add(Div((xdata[0]),Div(x[0],x[1])),(xdata[0]))',
#   array([ 2.2642588 , -0.59829497]),
#   0.00022119024937745555),
#  ('Add(Add(Mul(R,R),age),R)',
#   'Add(Add(Mul(x[0],x[1]),age),x[2])',
#   'lambda x,xdata:Add(Add(Mul(x[0],x[1]),(xdata[0])),x[2])',
#   array([-0.33415192,  2.44842271,  1.25575025]),
#   0.0002979095632474478),
#  ('Add(Add(R,age),Pow(R,R))',
#   'Add(Add(x[0],age),Pow(x[1],x[2]))',
#   'lambda x,xdata:Add(Add(x[0],(xdata[0])),Pow(x[1],x[2]))',
#   array([-1.40738916,  1.60466732,  1.29510437]),
#   0.0002979095632474478),
#  ('Add(Add(R,age),Sub(R,R))',
#   'Add(Add(x[0],age),Sub(x[1],x[2]))',
#   'lambda x,xdata:Add(Add(x[0],(xdata[0])),Sub(x[1],x[2]))',
#   array([0.67920169, 1.97920169, 2.22079827]),
#   0.0002979095632474478),
#  ('Add(Add(Sub(R,R),age),R)',
#   'Add(Add(Sub(x[0],x[1]),age),x[2])',
#   'lambda x,xdata:Add(Add(Sub(x[0],x[1]),(xdata[0])),x[2])',
#   array([1.81253505, 1.68746495, 0.31253505]),
#   0.0002979095632474478),
#  ('Add(Add(Div(R,R),age),R)',
#   'Add(Add(Div(x[0],x[1]),age),x[2])',
#   'lambda x,xdata:Add(Add(Div(x[0],x[1]),(xdata[0])),x[2])',
#   array([ 1.22257928,  2.73727676, -0.00903566]),
#   0.0002979095632474479),
#  ('Add(Add(R,R),Sub(age,R))',
#   'Add(Add(x[0],x[1]),Sub(age,x[2]))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Sub((xdata[0]),x[2]))',
#   array([0.7125351 , 0.6125351 , 0.88746512]),
#   0.0002979095632474479),
#  ('Add(Div(Mul(R,R),R),age)',
#   'Add(Div(Mul(x[0],x[1]),x[2]),age)',
#   'lambda x,xdata:Add(Div(Mul(x[0],x[1]),x[2]),(xdata[0]))',
# ...
#   0.0052164386390415405),
#  ('Add(R,Sub(weight,Add(R,R)))',
#   'Add(x[0],Sub(weight,Add(x[1],x[2])))',
#   'lambda x,xdata:Add(x[0],Sub((xdata[2]),Add(x[1],x[2])))',
#   array([-2.63363287,  6.13368631,  5.23368631]),
#   0.005216438639041568),
#  ('Sub(Sub(weight,R),R)',
#   'Sub(Sub(weight,x[0]),x[1])',
#   'lambda x,xdata:Sub(Sub((xdata[2]),x[0]),x[1])',
#   array([7.65050381, 6.35050381]),
#   0.005216438639041894),
#  ('Add(R,weight)',
#   'Add(x[0],weight)',
#   'lambda x,xdata:Add(x[0],(xdata[2]))',
#   array([-14.00100819]),
#   0.005216438639042033),
#  ('Add(R,Sub(weight,Div(R,R)))',
#   'Add(x[0],Sub(weight,Div(x[1],x[2])))',
#   'lambda x,xdata:Add(x[0],Sub((xdata[2]),Div(x[1],x[2])))',
#   array([-15.23063388,   5.34805619,  -4.34930782]),
#   0.005216438639042139),
#  ('Sub(weight,R)',
#   'Sub(weight,x[0])',
#   'lambda x,xdata:Sub((xdata[2]),x[0])',
#   array([14.00099953]),
#   0.005216438639042288),
#  ('Add(Sub(age,R),weight)',
#   'Add(Sub(age,x[0]),weight)',
#   'lambda x,xdata:Add(Sub((xdata[0]),x[0]),(xdata[2]))',
#   array([18.51455044]),
#   0.008651990725126742),
#  ('Add(Sub(weight,R),age)',
#   'Add(Sub(weight,x[0]),age)',
#   'lambda x,xdata:Add(Sub((xdata[2]),x[0]),(xdata[0]))',
#   array([18.51454656]),
#   0.008651990725126872),
#  ('Add(R,Sub(height,weight))',
#   'Add(x[0],Sub(height,weight))',
#   'lambda x,xdata:Add(x[0],Sub((xdata[1]),(xdata[2])))',
#   array([-76.23556865]),
#   0.010711720848377229),
#  ('Add(Pow(weight,R),weight)',
#   'Add(Pow(weight,x[0]),weight)',
#   'lambda x,xdata:Add(Pow((xdata[2]),x[0]),(xdata[2]))',
#   array([-5.07848109]),
#   0.011845723444327619),
#  ('Add(Pow(height,R),weight)',
#   'Add(Pow(height,x[0]),weight)',
#   'lambda x,xdata:Add(Pow((xdata[1]),x[0]),(xdata[2]))',
#   array([-3.75625888]),
#   0.011845729202665278),
#  ('Add(Div(weight,Add(R,R)),weight)',
#   'Add(Div(weight,Add(x[0],x[1])),weight)',
#   'lambda x,xdata:Add(Div((xdata[2]),Add(x[0],x[1])),(xdata[2]))',
#   array([13808.56194431, 13807.16194431]),
#   0.011846781976912538),
#  ('Add(Div(weight,Sub(R,R)),weight)',
#   'Add(Div(weight,Sub(x[0],x[1])),weight)',
#   'lambda x,xdata:Add(Div((xdata[2]),Sub(x[0],x[1])),(xdata[2]))',
#   array([ 5573.73345542, -5570.9146843 ]),
#   0.011848338031694133),
#  ('Add(Div(weight,R),weight)',
#   'Add(Div(weight,x[0]),weight)',
#   'lambda x,xdata:Add(Div((xdata[2]),x[0]),(xdata[2]))',
#   array([10172.24409674]),
#   0.011848587437244531),
#  ('Add(Pow(age,R),weight)',
#   'Add(Pow(age,x[0]),weight)',
#   'lambda x,xdata:Add(Pow((xdata[0]),x[0]),(xdata[2]))',
#   array([-0.46037023]),
#   0.01238450447536252),
#  ('Add(R,Sub(weight,height))',
#   'Add(x[0],Sub(weight,height))',
#   'lambda x,xdata:Add(x[0],Sub((xdata[2]),(xdata[1])))',
#   array([86.13787075]),
#   0.013125901634406502),
#  ('Add(R,Sub(height,age))',
#   'Add(x[0],Sub(height,age))',
#   'lambda x,xdata:Add(x[0],Sub((xdata[1]),(xdata[0])))',
#   array([-90.67418378]),
#   0.02193260120998459),
#  ('Add(Sub(weight,R),weight)',
#   'Add(Sub(weight,x[0]),weight)',
#   'lambda x,xdata:Add(Sub((xdata[2]),x[0]),(xdata[2]))',
#   array([32.95316024]),
#   0.022289103894337765),
#  ('Add(R,Sub(age,height))',
#   'Add(x[0],Sub(age,height))',
#   'lambda x,xdata:Add(x[0],Sub((xdata[0]),(xdata[1])))',
#   array([100.5764822]),
#   0.025397930235144254),
#  ('Add(R,Sub(height,Mul(R,R)))',
#   'Add(x[0],Sub(height,Mul(x[1],x[2])))',
#   'lambda x,xdata:Add(x[0],Sub((xdata[1]),Mul(x[1],x[2])))',
#   array([-2.30035167,  6.27696023, 14.79814596]),
#   0.028745707037019574),
#  ('Sub(Add(R,height),R)',
#   'Sub(Add(x[0],height),x[1])',
#   'lambda x,xdata:Sub(Add(x[0],(xdata[1])),x[1])',
#   array([-45.9438098 ,  49.24391549]),
#   0.028745707037019574),
#  ('Add(Pow(R,R),Sub(height,R))',
#   'Add(Pow(x[0],x[1]),Sub(height,x[2]))',
#   'lambda x,xdata:Add(Pow(x[0],x[1]),Sub((xdata[1]),x[2]))',
#   array([-2.734173  ,  3.77007276, 50.84057003]),
#   0.028745707037019577),
#  ('Add(Mul(R,R),Sub(height,R))',
#   'Add(Mul(x[0],x[1]),Sub(height,x[2]))',
#   'lambda x,xdata:Add(Mul(x[0],x[1]),Sub((xdata[1]),x[2]))',
#   array([-5.93546296,  9.53401256, 38.59894721]),
#   0.02874570703701958),
#  ('Add(R,height)',
#   'Add(x[0],height)',
#   'lambda x,xdata:Add(x[0],(xdata[1]))',
#   array([-95.18772605]),
#   0.028745707037019588),
#  ('Add(R,Sub(height,Pow(R,R)))',
#   'Add(x[0],Sub(height,Pow(x[1],x[2])))',
#   'lambda x,xdata:Add(x[0],Sub((xdata[1]),Pow(x[1],x[2])))',
#   array([-10.50091562,   4.7140186 ,   2.8628463 ]),
#   0.028745707037019615),
#  ('Add(Sub(height,R),Sub(R,R))',
#   'Add(Sub(height,x[0]),Sub(x[1],x[2]))',
#   'lambda x,xdata:Add(Sub((xdata[1]),x[0]),Sub(x[1],x[2]))',
#   array([ 31.99574584, -28.99623551,  34.19574584]),
#   0.02874570703701969),
#  ('Add(R,Sub(height,R))',
#   'Add(x[0],Sub(height,x[1]))',
#   'lambda x,xdata:Add(x[0],Sub((xdata[1]),x[1]))',
#   array([-44.64386935,  50.54385409]),
#   0.028745707037019695),
#  ('Add(R,Sub(height,Sub(R,R)))',
#   'Add(x[0],Sub(height,Sub(x[1],x[2])))',
#   'lambda x,xdata:Add(x[0],Sub((xdata[1]),Sub(x[1],x[2])))',
#   array([-31.22940128,  34.02892049, -29.92940128]),
#   0.02874570703701975),
#  ('Add(R,Sub(height,Add(R,R)))',
#   'Add(x[0],Sub(height,Add(x[1],x[2])))',
#   'lambda x,xdata:Add(x[0],Sub((xdata[1]),Add(x[1],x[2])))',
#   array([-30.06247001,  32.86262896,  32.26262896]),
#   0.028745707037019803),
#  ('Sub(height,R)',
#   'Sub(height,x[0])',
#   'lambda x,xdata:Sub((xdata[1]),x[0])',
#   array([95.18772098]),
#   0.028745707037020212),
#  ('Sub(Sub(height,R),R)',
#   'Sub(Sub(height,x[0]),x[1])',
#   'lambda x,xdata:Sub(Sub((xdata[1]),x[0]),x[1])',
#   array([47.59385993, 47.59385993]),
#   0.028745707037020587),
#  ('Add(R,Sub(height,Div(R,R)))',
#   'Add(x[0],Sub(height,Div(x[1],x[2])))',
#   'lambda x,xdata:Add(x[0],Sub((xdata[1]),Div(x[1],x[2])))',
#   array([1.26841349, 1.27792978, 0.01324881]),
#   0.02874570703705573),
#  ('Add(Sub(height,R),age)',
#   'Add(Sub(height,x[0]),age)',
#   'lambda x,xdata:Add(Sub((xdata[1]),x[0]),(xdata[0]))',
#   array([99.70126885]),
#   0.036564070907749054),
#  ('Add(Sub(age,R),height)',
#   'Add(Sub(age,x[0]),height)',
#   'lambda x,xdata:Add(Sub((xdata[0]),x[0]),(xdata[1]))',
#   array([99.7012718]),
#   0.03656407090774912),
#  ('Add(Div(weight,Div(R,R)),height)',
#   'Add(Div(weight,Div(x[0],x[1])),height)',
#   'lambda x,xdata:Add(Div((xdata[2]),Div(x[0],x[1])),(xdata[1]))',
#   array([ 1.30563184, -5.26755408]),
#   0.04064939705251172),
#  ('Add(Mul(R,weight),height)',
#   'Add(Mul(x[0],weight),height)',
#   'lambda x,xdata:Add(Mul(x[0],(xdata[2])),(xdata[1]))',
#   array([-4.03448653]),
#   0.04064939705251173),
#  ('Add(Div(weight,Mul(R,R)),height)',
#   'Add(Div(weight,Mul(x[0],x[1])),height)',
#   'lambda x,xdata:Add(Div((xdata[2]),Mul(x[0],x[1])),(xdata[1]))',
#   array([ 9.7684429 , -0.02537386]),
#   0.04064939705251953),
#  ('Sub(Div(weight,R),height)',
#   'Sub(Div(weight,x[0]),height)',
#   'lambda x,xdata:Sub(Div((xdata[2]),x[0]),(xdata[1]))',
#   array([0.2258523]),
#   0.05146578210410433),
#  ('Add(Mul(R,age),height)',
#   'Add(Mul(x[0],age),height)',
#   'lambda x,xdata:Add(Mul(x[0],(xdata[0])),(xdata[1]))',
#   array([-15.26322823]),
#   0.05756483828693673),
#  ('Add(Sub(height,R),weight)',
#   'Add(Sub(height,x[0]),weight)',
#   'lambda x,xdata:Add(Sub((xdata[1]),x[0]),(xdata[2]))',
#   array([114.13987777]),
#   0.058673157660074866),
#  ('Add(Sub(weight,R),height)',
#   'Add(Sub(weight,x[0]),height)',
#   'lambda x,xdata:Add(Sub((xdata[2]),x[0]),(xdata[1]))',
#   array([114.13988169]),
#   0.05867315766007495),
#  ('Add(Mul(age,age),R)',
#   'Add(Mul(age,age),x[0])',
#   'lambda x,xdata:Add(Mul((xdata[0]),(xdata[0])),x[0])',
#   array([-30.2836806]),
#   0.06819971483523636),
#  ('Sub(Div(age,R),height)',
#   'Sub(Div(age,x[0]),height)',
#   'lambda x,xdata:Sub(Div((xdata[0]),x[0]),(xdata[1]))',
#   array([0.05975586]),
#   0.07247593034320575),
#  ('Add(Sub(height,R),height)',
#   'Add(Sub(height,x[0]),height)',
#   'lambda x,xdata:Add(Sub((xdata[1]),x[0]),(xdata[1]))',
#   array([195.32661291]),
#   0.1188203582722846),
#  ('Add(Div(weight,age),Pow(R,R))',
#   'Add(Div(weight,age),Pow(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[2]),(xdata[0])),Pow(x[0],x[1]))',
#   array([-1.53068587,  5.5008633 ]),
#   0.17764585532054758),
#  ('Add(Div(weight,age),Mul(R,R))',
#   'Add(Div(weight,age),Mul(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[2]),(xdata[0])),Mul(x[0],x[1]))',
#   array([-4.37188085,  2.37883732]),
#   0.17764585532054766),
#  ('Add(Div(weight,age),Div(R,R))',
#   'Add(Div(weight,age),Div(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[2]),(xdata[0])),Div(x[0],x[1]))',
#   array([-5.892137  ,  0.56655197]),
#   0.17764585532054772),
#  ('Add(Div(weight,age),R)',
#   'Add(Div(weight,age),x[0])',
#   'lambda x,xdata:Add(Div((xdata[2]),(xdata[0])),x[0])',
#   array([-10.39999819]),
#   0.1776458553205489),
#  ('Sub(Div(weight,age),R)',
#   'Sub(Div(weight,age),x[0])',
#   'lambda x,xdata:Sub(Div((xdata[2]),(xdata[0])),x[0])',
#   array([10.39998511]),
#   0.1776458553205492),
#  ('Add(Div(weight,age),Sub(R,R))',
#   'Add(Div(weight,age),Sub(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[2]),(xdata[0])),Sub(x[0],x[1]))',
#   array([-3.54962575,  6.85035908]),
#   0.17764585532054936),
#  ('Add(Pow(weight,R),height)',
#   'Add(Pow(weight,x[0]),height)',
#   'lambda x,xdata:Add(Pow((xdata[2]),x[0]),(xdata[1]))',
#   array([-18.54826916]),
#   0.33516109606560457),
#  ('Add(Pow(height,R),height)',
#   'Add(Pow(height,x[0]),height)',
#   'lambda x,xdata:Add(Pow((xdata[1]),x[0]),(xdata[1]))',
#   array([-3.86623911]),
#   0.3351610962214249),
#  ('Add(Div(weight,Pow(R,R)),height)',
#   'Add(Div(weight,Pow(x[0],x[1])),height)',
#   'lambda x,xdata:Add(Div((xdata[2]),Pow(x[0],x[1])),(xdata[1]))',
#   array([9.68707689, 8.1110064 ]),
#   0.33516109747448697),
#  ('Add(Div(weight,R),height)',
#   'Add(Div(weight,x[0]),height)',
#   'lambda x,xdata:Add(Div((xdata[2]),x[0]),(xdata[1]))',
#   array([31511.02920041]),
#   0.3351657292362669),
#  ('Add(Div(weight,Sub(R,R)),height)',
#   'Add(Div(weight,Sub(x[0],x[1])),height)',
#   'lambda x,xdata:Add(Div((xdata[2]),Sub(x[0],x[1])),(xdata[1]))',
#   array([ 8907.2711733 , -8893.38753075]),
#   0.3351692978499644),
#  ('Add(Div(weight,Add(R,R)),height)',
#   'Add(Div(weight,Add(x[0],x[1])),height)',
#   'lambda x,xdata:Add(Div((xdata[2]),Add(x[0],x[1])),(xdata[1]))',
#   array([7838.6508958, 7840.1508958]),
#   0.33517040783694313),
#  ('Add(Pow(age,R),height)',
#   'Add(Pow(age,x[0]),height)',
#   'lambda x,xdata:Add(Pow((xdata[0]),x[0]),(xdata[1]))',
#   array([-0.41888124]),
#   0.3399088280548169),
#  ('Add(Mul(R,height),Pow(R,R))',
#   'Add(Mul(x[0],height),Pow(x[1],x[2]))',
#   'lambda x,xdata:Add(Mul(x[0],(xdata[1])),Pow(x[1],x[2]))',
#   array([1.69128616, 1.45029087, 2.68880261]),
#   1.0290805842108692),
#  ('Add(Mul(age,weight),R)',
#   'Add(Mul(age,weight),x[0])',
#   'lambda x,xdata:Add(Mul((xdata[0]),(xdata[2])),x[0])',
#   array([-127.53096233]),
#   1.0592512837637997),
#  ('Pow(Div(weight,R),Add(R,R))',
#   'Pow(Div(weight,x[0]),Add(x[1],x[2]))',
#   'lambda x,xdata:Pow(Div((xdata[2]),x[0]),Add(x[1],x[2]))',
#   array([1.13295771, 0.14346405, 1.54346405]),
#   1.7861494788052241),
#  ('Add(Pow(age,Mul(R,R)),R)',
#   'Add(Pow(age,Mul(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Pow((xdata[0]),Mul(x[0],x[1])),x[2])',
#   array([2.06201033, 1.41701266, 1.49999995]),
#   9.035323899947782),
#  ('Add(Mul(age,height),R)',
#   'Add(Mul(age,height),x[0])',
#   'lambda x,xdata:Add(Mul((xdata[0]),(xdata[1])),x[0])',
#   array([-558.77132129]),
#   11.19763220815307),
#  ('Add(Mul(weight,weight),R)',
#   'Add(Mul(weight,weight),x[0])',
#   'lambda x,xdata:Add(Mul((xdata[2]),(xdata[2])),x[0])',
#   array([-530.07754195]),
#   22.15072540838329),
#  ('Add(Div(height,age),Div(R,R))',
#   'Add(Div(height,age),Div(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[1]),(xdata[0])),Div(x[0],x[1]))',
#   array([-5.44764999,  0.02950382]),
#   47.401382170513806),
#  ('Add(Div(height,age),Mul(R,R))',
#   'Add(Div(height,age),Mul(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[1]),(xdata[0])),Mul(x[0],x[1]))',
#   array([-26.03036975,   7.09333627]),
#   47.401382170513806),
#  ('Sub(Div(height,age),R)',
#   'Sub(Div(height,age),x[0])',
#   'lambda x,xdata:Sub(Div((xdata[1]),(xdata[0])),x[0])',
#   array([184.64237374]),
#   47.401382170515305),
#  ('Add(Div(height,age),Sub(R,R))',
#   'Add(Div(height,age),Sub(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[1]),(xdata[0])),Sub(x[0],x[1]))',
#   array([-91.58090462,  93.06374816]),
#   47.40138217072339),
#  ('Add(Add(R,R),Div(height,age))',
#   'Add(Add(x[0],x[1]),Div(height,age))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[1]),(xdata[0])))',
#   array([-92.27264739, -92.37264739]),
#   47.40138217084543),
#  ('Add(Div(height,age),R)',
#   'Add(Div(height,age),x[0])',
#   'lambda x,xdata:Add(Div((xdata[1]),(xdata[0])),x[0])',
#   array([-184.63547169]),
#   47.40138217202812),
#  ('Add(Div(height,age),Pow(R,R))',
#   'Add(Div(height,age),Pow(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[1]),(xdata[0])),Pow(x[0],x[1]))',
#   array([13.76403258, -4.79246629]),
#   48.55433211184928),
#  ('Add(Mul(height,weight),R)',
#   'Add(Mul(height,weight),x[0])',
#   'lambda x,xdata:Add(Mul((xdata[1]),(xdata[2])),x[0])',
#   array([-2258.79916897]),
#   160.99117119333863),
#  ('Add(Pow(height,Div(R,R)),R)',
#   'Add(Pow(height,Div(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Pow((xdata[1]),Div(x[0],x[1])),x[2])',
#   array([1.84691476, 1.10860396, 2.4       ]),
#   212.77538998974933),
#  ('Add(Mul(height,height),R)',
#   'Add(Mul(height,height),x[0])',
#   'lambda x,xdata:Add(Mul((xdata[1]),(xdata[1])),x[0])',
#   array([-10930.1327513]),
#   1314.6184363816492),
#  ('Mul(Pow(height,R),R)',
#   'Mul(Pow(height,x[0]),x[1])',
#   'lambda x,xdata:Mul(Pow((xdata[1]),x[0]),x[1])',
#   array([1.69233657, 2.93133835]),
#   2358.461554600705),
#  ('Pow(Div(height,Pow(R,R)),R)',
#   'Pow(Div(height,Pow(x[0],x[1])),x[2])',
#   'lambda x,xdata:Pow(Div((xdata[1]),Pow(x[0],x[1])),x[2])',
#   array([1.09513304, 2.40834474, 2.75367999]),
#   2474959.0892399363),
#  ('Add(Pow(age,age),R)',
#   'Add(Pow(age,age),x[0])',
#   'lambda x,xdata:Add(Pow((xdata[0]),(xdata[0])),x[0])',
#   array([0.7]),
#   1.6998928043807175e+22),
#  ('Add(Pow(weight,age),R)',
#   'Add(Pow(weight,age),x[0])',
#   'lambda x,xdata:Add(Pow((xdata[2]),(xdata[0])),x[0])',
#   array([2.8]),
#   7.466827623784758e+46),
#  ('Add(Pow(height,age),R)',
#   'Add(Pow(height,age),x[0])',
#   'lambda x,xdata:Add(Pow((xdata[1]),(xdata[0])),x[0])',
#   array([0.2]),
#   3.1343842124909563e+50),
#  ('Pow(Div(age,R),height)',
#   'Pow(Div(age,x[0]),height)',
#   'lambda x,xdata:Pow(Div((xdata[0]),x[0]),(xdata[1]))',
#   array([1.8]),
#   6.3688288911401744e+296),
#  ('Add(Div(weight,Sub(R,R)),Mul(R,R))',
#   'Add(Div(weight,Sub(x[0],x[1])),Mul(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[2]),Sub(x[0],x[1])),Mul(x[2],x[3]))',
#   array([1.1, 1.1, 2.8, 0.4]),
#   inf),
#  ('Add(Pow(age,height),R)',
#   'Add(Pow(age,height),x[0])',
#   'lambda x,xdata:Add(Pow((xdata[0]),(xdata[1])),x[0])',
#   array([0.9]),
#   inf),
#  ('Add(Pow(age,weight),R)',
#   'Add(Pow(age,weight),x[0])',
#   'lambda x,xdata:Add(Pow((xdata[0]),(xdata[2])),x[0])',
#   array([0.9]),
#   inf),
#  ('Add(Pow(height,height),R)',
#   'Add(Pow(height,height),x[0])',
#   'lambda x,xdata:Add(Pow((xdata[1]),(xdata[1])),x[0])',
#   array([1.9]),
#   inf),
#  ('Add(Pow(height,weight),R)',
#   'Add(Pow(height,weight),x[0])',
#   'lambda x,xdata:Add(Pow((xdata[1]),(xdata[2])),x[0])',
#   array([0.1]),
#   inf),
#  ('Add(Pow(weight,height),R)',
#   'Add(Pow(weight,height),x[0])',
#   'lambda x,xdata:Add(Pow((xdata[2]),(xdata[1])),x[0])',
#   array([1.3]),
#   inf),
#  ('Add(Pow(weight,weight),R)',
#   'Add(Pow(weight,weight),x[0])',
#   'lambda x,xdata:Add(Pow((xdata[2]),(xdata[2])),x[0])',
#   array([1.6]),
#   inf),
#  ('Pow(Div(age,R),weight)',
#   'Pow(Div(age,x[0]),weight)',
#   'lambda x,xdata:Pow(Div((xdata[0]),x[0]),(xdata[2]))',
#   array([0.5]),
#   inf),
#  ('Pow(Div(height,R),height)',
#   'Pow(Div(height,x[0]),height)',
#   'lambda x,xdata:Pow(Div((xdata[1]),x[0]),(xdata[1]))',
#   array([2.3]),
#   inf),
#  ('Pow(Div(height,R),weight)',
#   'Pow(Div(height,x[0]),weight)',
#   'lambda x,xdata:Pow(Div((xdata[1]),x[0]),(xdata[2]))',
#   array([1.9]),
#   inf),
#  ('Pow(Div(weight,R),height)',
#   'Pow(Div(weight,x[0]),height)',
#   'lambda x,xdata:Pow(Div((xdata[2]),x[0]),(xdata[1]))',
#   array([1.7]),
#   inf),
#  ('Pow(Div(weight,R),weight)',
#   'Pow(Div(weight,x[0]),weight)',
#   'lambda x,xdata:Pow(Div((xdata[2]),x[0]),(xdata[2]))',
#   array([0.2]),
#   inf)]

# %% [markdown]
# # DASR-HE

# %%
X, y = np.array(df.iloc[:,:-1]).T, np.array(df.iloc[:,-1])
num_of_feature = X.shape[1]
mse_tuple = tuple()
np.random.seed(0)
master_list = []
for repeat_trial in range(1):
    for test_eq in tqdm(exp_set):
        test_eq_orig = test_eq
        R_count = test_eq.count("R")
        if R_count==0:
            continue
        lambda_string = "lambda x,xdata:"
        index = 0    
        for i in range(R_count):
            test_eq = test_eq.replace("R", f"x[{i}]", 1)
        lambda_string += test_eq
        optimized_cost = 0
        ypred =[]
        ytrue =[]
        lambda_string_list = []
        res_x_list =[]
        x0_base = [random_constant() for i in range(R_count)]
        try:
            for xdata, ydata in zip([X],[y]):
                lambda_string_new = lambda_string.replace("height","(xdata[1])")
                lambda_string_new = lambda_string_new.replace("age","(xdata[0])")
                lambda_string_new = lambda_string_new.replace("weight","(xdata[2])")
                x0 = x0_base.copy()
                cur_cost = cost(x0, xdata, ydata, lambda_string_new)
                for step_perc, rounds, absolute in zip([0.1, 0.1, 0.01],[10,10,10],[True, False, False]):
                    for _ in range(rounds):
                        for x0_idx in range(len(x0)):
                            test_x0 = x0.copy()
                            if absolute:
                                test_x0[x0_idx] = x0[x0_idx]+step_perc
                            else:
                                test_x0[x0_idx] = x0[x0_idx]*(1+step_perc)
                            new_cost = cost(test_x0, xdata, ydata, lambda_string_new)
                            if absolute:
                                outcome = step_perc*(new_cost<cur_cost)                                
                            else:
                                outcome = test_x0[x0_idx]*step_perc*(new_cost<cur_cost)
                            x0[x0_idx] = x0[x0_idx] + outcome
                            cur_cost = cost(x0, xdata, ydata, lambda_string_new)

                        for x0_idx in range(len(x0)):
                            test_x0 = x0.copy()
                            if absolute:
                                test_x0[x0_idx] = x0[x0_idx]-step_perc
                            else:
                                test_x0[x0_idx] = x0[x0_idx]*(1-step_perc)
                            new_cost = cost(test_x0, xdata, ydata, lambda_string_new)
                            if absolute:
                                outcome = step_perc*(new_cost<cur_cost)                                
                            else:
                                outcome = test_x0[x0_idx]*step_perc*(new_cost<cur_cost)
                            x0[x0_idx] = x0[x0_idx] - outcome
                            cur_cost = cost(x0, xdata, ydata, lambda_string_new)       
                optimized_cost = cost(x0, xdata, ydata, lambda_string_new)
            optimized_cost = optimized_cost*(1/len(y))
            master_list.append((test_eq_orig,test_eq,lambda_string_new,x0,optimized_cost))
        except RuntimeError:
            print("No fit found")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 873/873 [23:28<00:00,  1.61s/it]

# %%
sorted(master_list,key=lambda x: x[-1])
# Out:
# [('Add(Pow(age,R),Pow(R,R))',
#   'Add(Pow(age,x[0]),Pow(x[1],x[2]))',
#   'lambda x,xdata:Add(Pow((xdata[0]),x[0]),Pow(x[1],x[2]))',
#   [0.49014900499999997, 2.8000000000000003, 1.1],
#   4.910416603070819e-06),
#  ('Add(Pow(age,Sub(R,R)),R)',
#   'Add(Pow(age,Sub(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Pow((xdata[0]),Sub(x[0],x[1])),x[2])',
#   [0.378585811481803, -0.11154152109679867, 3.1020809989499027],
#   4.910453882367391e-06),
#  ('Add(Pow(age,Div(R,R)),R)',
#   'Add(Pow(age,Div(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Pow((xdata[0]),Div(x[0],x[1])),x[2])',
#   [1.5543916906631206, 3.162936231000001, 3.096005634674638],
#   4.912541692533803e-06),
#  ('Add(Add(R,R),Pow(age,R))',
#   'Add(Add(x[0],x[1]),Pow(age,x[2]))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Pow((xdata[0]),x[2]))',
#   [0.6419757911463772, 2.4534446738255995, 0.49194108599999986],
#   4.9132975558270385e-06),
#  ('Add(Pow(age,R),R)',
#   'Add(Pow(age,x[0]),x[1])',
#   'lambda x,xdata:Add(Pow((xdata[0]),x[0]),x[1])',
#   [0.49019802480199, 3.088729359722097],
#   4.9175464519609555e-06),
#  ('Add(Pow(age,Pow(R,R)),R)',
#   'Add(Pow(age,Pow(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Pow((xdata[0]),Pow(x[0],x[1])),x[2])',
#   [3.5747196811442117, -0.55505550555, 3.084259909034976],
#   4.919576189415489e-06),
#  ('Add(Pow(age,Add(R,R)),R)',
#   'Add(Pow(age,Add(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Pow((xdata[0]),Add(x[0],x[1])),x[2])',
#   [0.8311415493365544, -0.3371801873973666, 3.0771222938767386],
#   4.926247090927325e-06),
#  ('Add(Div(R,R),Pow(age,R))',
#   'Add(Div(x[0],x[1]),Pow(age,x[2]))',
#   'lambda x,xdata:Add(Div(x[0],x[1]),Pow((xdata[0]),x[2]))',
#   [0.96098418840996, 0.30609060299999996, 0.4811693317702567],
#   4.93107633767311e-06),
#  ('Add(Div(height,Pow(R,R)),R)',
#   'Add(Div(height,Pow(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Div((xdata[1]),Pow(x[0],x[1])),x[2])',
#   [2.7000000000000006, 3.500000000000001, 1.8625662189999994],
#   5.519004430481457e-06),
#  ('Pow(Div(height,R),R)',
#   'Pow(Div(height,x[0]),x[1])',
#   'lambda x,xdata:Pow(Div((xdata[1]),x[0]),x[1])',
#   [4.8097328414112015, 0.5328274469699996],
#   5.846426866206253e-06),
#  ('Mul(Pow(age,R),R)',
#   'Mul(Pow(age,x[0]),x[1])',
#   'lambda x,xdata:Mul(Pow((xdata[0]),x[0]),x[1])',
#   [0.17119189231555276, 4.1288054439287105],
#   6.0959681800629286e-06),
#  ('Add(Div(height,Pow(R,R)),Pow(R,R))',
#   'Add(Div(height,Pow(x[0],x[1])),Pow(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Pow(x[0],x[1])),Pow(x[2],x[3]))',
#   [2.900000000000001,
#    3.100000000000001,
#    4.0705113326558005,
#    0.16518591561788037],
#   6.1414365355933934e-06),
#  ('Add(Div(height,Mul(R,R)),R)',
#   'Add(Div(height,Mul(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Div((xdata[1]),Mul(x[0],x[1])),x[2])',
#   [5.074164592151463, 5.333760900000001, 1.2196373637180917],
#   6.2004616034250715e-06),
#  ('Add(Pow(height,R),Sub(R,R))',
#   'Add(Pow(height,x[0]),Sub(x[1],x[2]))',
#   'lambda x,xdata:Add(Pow((xdata[1]),x[0]),Sub(x[1],x[2]))',
#   [0.40000000000000013, 0.9294033039290992, 2.220000000000001],
#   6.2798294816516835e-06),
#  ('Pow(Div(height,Add(R,R)),R)',
#   'Pow(Div(height,Add(x[0],x[1])),x[2])',
#   'lambda x,xdata:Pow(Div((xdata[1]),Add(x[0],x[1])),x[2])',
#   [1.6988028466500003, 2.2424220000000012, 0.5],
#   6.43127778494141e-06),
#  ('Pow(Div(height,R),Sub(R,R))',
#   'Pow(Div(height,x[0]),Sub(x[1],x[2]))',
#   'lambda x,xdata:Pow(Div((xdata[1]),x[0]),Sub(x[1],x[2]))',
#   [3.9268652139900015, 2.099999999999999, 1.6000000000000003],
#   6.433108752941118e-06),
#  ('Pow(Div(height,R),Pow(R,R))',
#   'Pow(Div(height,x[0]),Pow(x[1],x[2]))',
#   'lambda x,xdata:Pow(Div((xdata[1]),x[0]),Pow(x[1],x[2]))',
#   [3.8297497749736693, 2.34845492427, -0.8205785999999999],
#   6.5104789794478855e-06),
#  ('Add(Add(R,R),Div(height,Mul(R,R)))',
#   'Add(Add(x[0],x[1]),Div(height,Mul(x[2],x[3])))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[1]),Mul(x[2],x[3])))',
#   [0.69259455749585,
#    0.4040134918725789,
#    7.235568229319552,
#    3.6507565532757837],
#   6.594845826925391e-06),
#  ('Add(Div(height,Pow(R,R)),Mul(R,R))',
#   'Add(Div(height,Pow(x[0],x[1])),Mul(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Pow(x[0],x[1])),Mul(x[2],x[3]))',
#   [2.3590814171400005,
#    3.7951760250000004,
#    0.8525922609286221,
#    1.2801685599528865],
#   6.692823863850144e-06),
#  ('Add(Div(height,Div(R,R)),R)',
#   'Add(Div(height,Div(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Div((xdata[1]),Div(x[0],x[1])),x[2])',
#   [6.5178780833368055, 0.2507823294561095, 1.0399317680117866],
#   6.800440659891642e-06),
#  ('Sub(Pow(height,R),R)',
#   'Sub(Pow(height,x[0]),x[1])',
#   'lambda x,xdata:Sub(Pow((xdata[1]),x[0]),x[1])',
#   [0.46508491742157865, 3.484119372314842],
#   6.884557964395062e-06),
#  ('Add(Mul(Pow(R,R),height),R)',
#   'Add(Mul(Pow(x[0],x[1]),height),x[2])',
#   'lambda x,xdata:Add(Mul(Pow(x[0],x[1]),(xdata[1])),x[2])',
#   [0.19605960199999997, 2.0, 1.0051956294379878],
#   6.9875724127508025e-06),
#  ('Add(Pow(weight,Mul(R,R)),R)',
#   'Add(Pow(weight,Mul(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Pow((xdata[2]),Mul(x[0],x[1])),x[2])',
#   [0.5940599999999998, 0.6999999999999997, 1.7289999999999992],
#   7.512134707713112e-06),
#  ('Add(Pow(weight,Div(R,R)),R)',
#   'Add(Pow(weight,Div(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Pow((xdata[2]),Div(x[0],x[1])),x[2])',
#   [1.3131299999999995, 3.2000000000000006, 1.7821799999999994],
#   7.513910935296039e-06),
#  ('Add(Add(R,R),Pow(weight,R))',
#   'Add(Add(x[0],x[1]),Pow(weight,x[2]))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Pow((xdata[2]),x[2]))',
#   [1.8443112445545107, -0.0366923180661613, 0.4081208039999998],
#   7.5277928577093045e-06),
#  ('Add(Mul(R,R),Pow(weight,R))',
#   'Add(Mul(x[0],x[1]),Pow(weight,x[2]))',
#   'lambda x,xdata:Add(Mul(x[0],x[1]),Pow((xdata[2]),x[2]))',
#   [1.3862786278613997, 1.3001300129999995, 0.4081208040000001],
#   7.529107115886149e-06),
#  ('Add(Pow(weight,Sub(R,R)),R)',
#   'Add(Pow(weight,Sub(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Pow((xdata[2]),Sub(x[0],x[1])),x[2])',
#   [1.5000000000000002, 1.0999999999999999, 1.88119],
#   7.64592554481162e-06),
#  ('Pow(Div(height,R),Div(R,R))',
#   'Pow(Div(height,x[0]),Div(x[1],x[2]))',
#   'lambda x,xdata:Pow(Div((xdata[1]),x[0]),Div(x[1],x[2]))',
#   [2.576517650752501, 0.70707, 1.6000000000000005],
#   7.88216032459719e-06),
#  ('Add(Pow(weight,Pow(R,R)),R)',
#   'Add(Pow(weight,Pow(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Pow((xdata[2]),Pow(x[0],x[1])),x[2])',
#   [0.7000000000000001, 2.6377424851112967, 1.9916512167271903],
#   7.926673769997982e-06),
#  ('Add(Add(R,R),Div(age,Div(R,R)))',
#   'Add(Add(x[0],x[1]),Div(age,Div(x[2],x[3])))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[0]),Div(x[2],x[3])))',
#   [2.847452030295661, 1.01928170799, 3.5952641197520614, 0.8648857695689633],
#   8.11933510065967e-06),
#  ('Add(Add(R,R),Div(age,Pow(R,R)))',
#   'Add(Add(x[0],x[1]),Div(age,Pow(x[2],x[3])))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[0]),Pow(x[2],x[3])))',
#   [2.5252500000000007,
#    1.3397891783913,
#    2.9887604748729006,
#    1.3000000000000003],
#   8.119341735946917e-06),
#  ('Add(Div(age,Add(R,R)),Sub(R,R))',
#   'Add(Div(age,Add(x[0],x[1])),Sub(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Add(x[0],x[1])),Sub(x[2],x[3]))',
#   [2.5045253263951017,
#    1.654467502821065,
#    4.863077835618602,
#    0.9994790093460754],
#   8.1194731756306e-06),
#  ('Add(Div(age,Mul(R,R)),Sub(R,R))',
#   'Add(Div(age,Mul(x[0],x[1])),Sub(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Mul(x[0],x[1])),Sub(x[2],x[3]))',
#   [2.684679086194902,
#    1.5459105904514991,
#    2.126267962534326,
#    -1.7348961988321738],
#   8.119499944680503e-06),
#  ('Add(Add(R,R),Div(age,Mul(R,R)))',
#   'Add(Add(x[0],x[1]),Div(age,Mul(x[2],x[3])))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[0]),Mul(x[2],x[3])))',
#   [3.5730899999999997, 0.28762112958016467, 3.4536101827500016, 1.2],
#   8.119506519000764e-06),
#  ('Add(Add(R,R),Div(age,R))',
#   'Add(Add(x[0],x[1]),Div(age,x[2]))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[0]),x[2]))',
#   [2.966239699536572, 0.9036535158495884, 4.175218113293541],
#   8.11996834811062e-06),
#  ('Add(Div(age,Pow(R,R)),Div(R,R))',
#   'Add(Div(age,Pow(x[0],x[1])),Div(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Pow(x[0],x[1])),Div(x[2],x[3]))',
#   [3.374794791234796,
#    1.1660316064060732,
#    3.163832425381813,
#    0.8199018099999993],
#   8.120309903457995e-06),
#  ('Add(Div(age,Div(R,R)),Sub(R,R))',
#   'Add(Div(age,Div(x[0],x[1])),Sub(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Div(x[0],x[1])),Sub(x[2],x[3]))',
#   [5.118671058618572,
#    1.239941900418161,
#    4.6821237046552895,
#    0.8219738160129508],
#   8.120654132783181e-06),
#  ('Add(Add(R,R),Mul(R,age))',
#   'Add(Add(x[0],x[1]),Mul(x[2],age))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Mul(x[2],(xdata[0])))',
#   [2.1910137824719755, 1.6850581551000006, 0.23885272522467782],
#   8.121265990759477e-06),
#  ('Add(Mul(Pow(R,R),age),R)',
#   'Add(Mul(Pow(x[0],x[1]),age),x[2])',
#   'lambda x,xdata:Add(Mul(Pow(x[0],x[1]),(xdata[0])),x[2])',
#   [0.543177604561961, 2.3296563089109625, 3.8700070433432985],
#   8.121513525054549e-06),
#  ('Add(Mul(Div(R,R),age),R)',
#   'Add(Mul(Div(x[0],x[1]),age),x[2])',
#   'lambda x,xdata:Add(Mul(Div(x[0],x[1]),(xdata[0])),x[2])',
#   [0.6182677790295371, 2.542161539911718, 3.850619785740001],
#   8.122706409823474e-06),
#  ('Add(Add(R,R),Div(age,Add(R,R)))',
#   'Add(Add(x[0],x[1]),Div(age,Add(x[2],x[3])))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[0]),Add(x[2],x[3])))',
#   [1.423726015147831,
#    2.4242399999999997,
#    1.9932164212069634,
#    2.1157251570000004],
#   8.123624671963741e-06),
#  ('Add(Div(age,R),Mul(R,R))',
#   'Add(Div(age,x[0]),Mul(x[1],x[2]))',
#   'lambda x,xdata:Add(Div((xdata[0]),x[0]),Mul(x[1],x[2]))',
#   [4.144332219300002, 3.812117400000001, 1.0101],
#   8.123871919600187e-06),
#  ('Add(Div(age,Mul(R,R)),Div(R,R))',
#   'Add(Div(age,Mul(x[0],x[1])),Div(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Mul(x[0],x[1])),Div(x[2],x[3]))',
#   [3.0701796660878204, 1.3455877587745313, 1.5237731507962344, 0.39604],
#   8.124352741762424e-06),
#  ('Add(Div(age,Mul(R,R)),Pow(R,R))',
#   'Add(Div(age,Mul(x[0],x[1])),Pow(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Mul(x[0],x[1])),Pow(x[2],x[3]))',
#   [1.6161600000000005, 2.6000000000000005, 3.43434, 1.1],
#   8.12529459228961e-06),
#  ('Add(Div(age,Pow(R,R)),Mul(R,R))',
#   'Add(Div(age,Pow(x[0],x[1])),Mul(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Pow(x[0],x[1])),Mul(x[2],x[3]))',
#   [3.469373771373669, 1.1336677663311, 2.958875829000001, 1.3],
#   8.125330305938008e-06),
#  ('Add(Div(age,R),Sub(R,R))',
#   'Add(Div(age,x[0]),Sub(x[1],x[2]))',
#   'lambda x,xdata:Add(Div((xdata[0]),x[0]),Sub(x[1],x[2]))',
#   [4.112888089864299, 4.077126831960002, 0.23291494797954104],
#   8.125338067465462e-06),
#  ('Add(Div(age,Add(R,R)),R)',
#   'Add(Div(age,Add(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Div((xdata[0]),Add(x[0],x[1])),x[2])',
#   [2.0290227619749297, 2.074970567859466, 3.844060240899144],
#   8.125507000319587e-06),
#  ('Add(Div(age,Add(R,R)),Pow(R,R))',
#   'Add(Div(age,Add(x[0],x[1])),Pow(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Add(x[0],x[1])),Pow(x[2],x[3]))',
#   [2.733979183377785,
#    1.3669895916888921,
#    2.4734569447223995,
#    1.4851499999999995],
#   8.129500442707298e-06),
#  ('Add(Div(age,Mul(R,R)),R)',
#   'Add(Div(age,Mul(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Div((xdata[0]),Mul(x[0],x[1])),x[2])',
#   [1.5386153999999996, 2.67327, 3.838380000000001],
#   8.130277261821673e-06),
#  ('Add(Div(age,Div(R,R)),R)',
#   'Add(Div(age,Div(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Div((xdata[0]),Div(x[0],x[1])),x[2])',
#   [1.2839186857324132, 0.315196589842152, 3.83349192893886],
#   8.133980867696833e-06),
#  ('Add(Div(age,Add(R,R)),Mul(R,R))',
#   'Add(Div(age,Add(x[0],x[1])),Mul(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Add(x[0],x[1])),Mul(x[2],x[3]))',
#   [2.3232299999999997, 1.9191899999999995, 2.6, 1.5000000000000002],
#   8.137218866720014e-06),
#  ('Add(Div(age,Div(R,R)),Mul(R,R))',
#   'Add(Div(age,Div(x[0],x[1])),Mul(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Div(x[0],x[1])),Mul(x[2],x[3]))',
#   [1.6161600000000005,
#    0.3960796079604,
#    2.5252500000000007,
#    1.5151500000000002],
#   8.140950174143993e-06),
#  ('Add(Div(age,Mul(R,R)),Mul(R,R))',
#   'Add(Div(age,Mul(x[0],x[1])),Mul(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Mul(x[0],x[1])),Mul(x[2],x[3]))',
#   [1.6215966129669768,
#    2.5115981603392528,
#    3.9693517225208894,
#    0.9638312215734302],
#   8.140979830107299e-06),
#  ('Add(Div(age,Pow(R,R)),R)',
#   'Add(Div(age,Pow(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Div((xdata[0]),Pow(x[0],x[1])),x[2])',
#   [2.0798544365769334, 1.919189999999999, 3.825323543186352],
#   8.141743749268912e-06),
#  ('Add(Div(age,Div(R,R)),Pow(R,R))',
#   'Add(Div(age,Div(x[0],x[1])),Pow(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Div(x[0],x[1])),Pow(x[2],x[3]))',
#   [2.5787853000000003, 0.63706370637, 4.3727229, 0.90909],
#   8.144611808784438e-06),
#  ('Add(Div(age,Pow(R,R)),Pow(R,R))',
#   'Add(Div(age,Pow(x[0],x[1])),Pow(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Pow(x[0],x[1])),Pow(x[2],x[3]))',
#   [3.032964811422836,
#    1.2698109589968611,
#    2.9522758138285248,
#    1.239112232515619],
#   8.144842593517853e-06),
#  ('Add(Div(age,Div(R,R)),Div(R,R))',
#   'Add(Div(age,Div(x[0],x[1])),Div(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Div(x[0],x[1])),Div(x[2],x[3]))',
#   [2.02309630366298,
#    0.5016110567809298,
#    3.8698076918124746,
#    1.0139391360945904],
#   8.153752381891569e-06),
#  ('Add(Mul(Sub(R,R),age),R)',
#   'Add(Mul(Sub(x[0],x[1]),age),x[2])',
#   'lambda x,xdata:Add(Mul(Sub(x[0],x[1]),(xdata[0])),x[2])',
#   [2.67327, 2.4242399999999997, 3.83131080422067],
#   8.15479702489302e-06),
#  ('Add(Div(age,R),Div(R,R))',
#   'Add(Div(age,x[0]),Div(x[1],x[2]))',
#   'lambda x,xdata:Add(Div((xdata[0]),x[0]),Div(x[1],x[2]))',
#   [4.0138570162465115, 3.150279144857848, 0.8259295780894002],
#   8.160341951502817e-06),
#  ('Add(Div(age,R),Pow(R,R))',
#   'Add(Div(age,x[0]),Pow(x[1],x[2]))',
#   'lambda x,xdata:Add(Div((xdata[0]),x[0]),Pow(x[1],x[2]))',
#   [3.9805786731531065, 2.5765176507525007, 1.41414],
#   8.175608877728968e-06),
#  ('Add(Mul(R,age),Pow(R,R))',
#   'Add(Mul(x[0],age),Pow(x[1],x[2]))',
#   'lambda x,xdata:Add(Mul(x[0],(xdata[0])),Pow(x[1],x[2]))',
#   [0.24964198275745675, 3.7476582897961452, 1.0101],
#   8.183060559716544e-06),
#  ('Add(Div(age,R),R)',
#   'Add(Div(age,x[0]),x[1])',
#   'lambda x,xdata:Add(Div((xdata[0]),x[0]),x[1])',
#   [3.956378583773861, 3.8127828490214526],
#   8.192628644457412e-06),
#  ('Add(Div(age,Add(R,R)),Div(R,R))',
#   'Add(Div(age,Add(x[0],x[1])),Div(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Add(x[0],x[1])),Div(x[2],x[3]))',
#   [2.2358355184045924,
#    1.6802337491914394,
#    4.793685493002747,
#    1.2613873999999992],
#   8.22748323838839e-06),
#  ('Add(Div(age,Sub(R,R)),Pow(R,R))',
#   'Add(Div(age,Sub(x[0],x[1])),Pow(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Sub(x[0],x[1])),Pow(x[2],x[3]))',
#   [3.863572915045301,
#    1.3877787807814457e-16,
#    3.0258428697603876,
#    1.2034877558307953],
#   8.286512830207055e-06),
#  ('Sub(Div(age,R),Sub(R,R))',
#   'Sub(Div(age,x[0]),Sub(x[1],x[2]))',
#   'lambda x,xdata:Sub(Div((xdata[0]),x[0]),Sub(x[1],x[2]))',
#   [3.677002053960108, 0.2282575690358348, 3.954496372175073],
#   8.610935729022401e-06),
#  ('Add(Mul(Mul(R,R),age),R)',
#   'Add(Mul(Mul(x[0],x[1]),age),x[2])',
#   'lambda x,xdata:Add(Mul(Mul(x[0],x[1]),(xdata[0])),x[2])',
#   [0.9767705567554048, 0.2715888022809805, 3.677002053960108],
#   8.622583416926664e-06),
#  ('Pow(Sub(height,R),R)',
#   'Pow(Sub(height,x[0]),x[1])',
#   'lambda x,xdata:Pow(Sub((xdata[1]),x[0]),x[1])',
#   [10.360660402812215, 0.3634451059488637],
#   8.96888157890913e-06),
#  ('Div(Pow(height,R),R)',
#   'Div(Pow(height,x[0]),x[1])',
#   'lambda x,xdata:Div(Pow((xdata[1]),x[0]),x[1])',
#   [0.408120804, 1.300130013],
#   8.972744908197163e-06),
#  ('Pow(Div(height,R),Add(R,R))',
#   'Pow(Div(height,x[0]),Add(x[1],x[2]))',
#   'lambda x,xdata:Pow(Div((xdata[1]),x[0]),Add(x[1],x[2]))',
#   [1.8758924389898435, -0.69307, 1.0999999999999992],
#   9.011438202710462e-06),
#  ('Pow(Div(height,Div(R,R)),R)',
#   'Pow(Div(height,Div(x[0],x[1])),x[2])',
#   'lambda x,xdata:Pow(Div((xdata[1]),Div(x[0],x[1])),x[2])',
#   [1.3999999999999997, 0.7999999999999999, 0.4],
#   9.258488030188715e-06),
#  ('Add(Mul(Mul(R,R),height),R)',
#   'Add(Mul(Mul(x[0],x[1]),height),x[2])',
#   'lambda x,xdata:Add(Mul(Mul(x[0],x[1]),(xdata[1])),x[2])',
#   [0.21762615822000003, 0.19802000000000003, 0.5528581490490425],
#   9.357301970712352e-06),
#  ('Add(Pow(height,Mul(R,R)),R)',
#   'Add(Pow(height,Mul(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Pow((xdata[1]),Mul(x[0],x[1])),x[2])',
#   [0.20202000000000003, 1.7999999999999994, -0.27247061017733015],
#   9.864336038265921e-06),
#  ('Add(Div(height,Add(R,R)),Pow(R,R))',
#   'Add(Div(height,Add(x[0],x[1])),Pow(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Add(x[0],x[1])),Pow(x[2],x[3]))',
#   [10.67461980895804,
#    12.24441683968716,
#    0.5640589712458965,
#    0.638843056154207],
#   9.916215571138007e-06),
#  ('Add(Div(height,Mul(R,R)),Div(R,R))',
#   'Add(Div(height,Mul(x[0],x[1])),Div(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Mul(x[0],x[1])),Div(x[2],x[3]))',
#   [4.952262740087763,
#    4.604813577000001,
#    1.4086825637769596,
#    3.1151235621628475],
#   1.0042147615278745e-05),
#  ('Add(Div(age,Pow(R,R)),Sub(R,R))',
#   'Add(Div(age,Pow(x[0],x[1])),Sub(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[0]),Pow(x[0],x[1])),Sub(x[2],x[3]))',
#   [1.2968862644583103,
#    4.78505987981803,
#    3.7675128737498955,
#    0.2820294856229483],
#   1.017277559557322e-05),
#  ('Mul(Pow(weight,R),R)',
#   'Mul(Pow(weight,x[0]),x[1])',
#   'lambda x,xdata:Mul(Pow((xdata[2]),x[0]),x[1])',
#   [0.36573922133249914, 1.7339435379108343],
#   1.0641297640048567e-05),
#  ('Pow(Pow(height,R),R)',
#   'Pow(Pow(height,x[0]),x[1])',
#   'lambda x,xdata:Pow(Pow((xdata[1]),x[0]),x[1])',
#   [0.44603559454999975, 0.7920799999999995],
#   1.1177327745951204e-05),
#  ('Add(Pow(age,R),Sub(R,R))',
#   'Add(Pow(age,x[0]),Sub(x[1],x[2]))',
#   'lambda x,xdata:Add(Pow((xdata[0]),x[0]),Sub(x[1],x[2]))',
#   [0.5793937920540515, 1.8837564368749478, -0.6279188122916491],
#   1.1250886233494233e-05),
#  ('Pow(Add(R,height),R)',
#   'Pow(Add(x[0],height),x[1])',
#   'lambda x,xdata:Pow(Add(x[0],(xdata[1])),x[1])',
#   [0.7818491907810775, 0.3528219786615644],
#   1.134417040598524e-05),
#  ('Add(Pow(height,R),Pow(R,R))',
#   'Add(Pow(height,x[0]),Pow(x[1],x[2]))',
#   'lambda x,xdata:Add(Pow((xdata[1]),x[0]),Pow(x[1],x[2]))',
#   [0.3476388835647772, 0.5140897667133709, 3.167433651073172],
#   1.180140894210635e-05),
#  ('Add(Div(R,R),Pow(weight,R))',
#   'Add(Div(x[0],x[1]),Pow(weight,x[2]))',
#   'lambda x,xdata:Add(Div(x[0],x[1]),Pow((xdata[2]),x[2]))',
#   [1.6585744471471275, 1.645826495996245, 0.47102544376987443],
#   1.1977791919716329e-05),
#  ('Pow(Div(height,Mul(R,R)),R)',
#   'Pow(Div(height,Mul(x[0],x[1])),x[2])',
#   'lambda x,xdata:Pow(Div((xdata[1]),Mul(x[0],x[1])),x[2])',
#   [3.435757703584143, 5.720398308353325, 0.9550867448438427],
#   1.2286410656962671e-05),
#  ('Add(Div(weight,Mul(R,R)),Mul(R,R))',
#   'Add(Div(weight,Mul(x[0],x[1])),Mul(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[2]),Mul(x[0],x[1])),Mul(x[2],x[3]))',
#   [4.399899372823501, 3.535350000000001, 2.331, 1.5999999999999999],
#   1.2472630093834153e-05),
#  ('Add(Div(weight,Pow(R,R)),R)',
#   'Add(Div(weight,Pow(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Div((xdata[2]),Pow(x[0],x[1])),x[2])',
#   [6.622870699677442, 1.443, 3.708734011799472],
#   1.2476391409919796e-05),
#  ('Add(Div(weight,Mul(R,R)),Div(R,R))',
#   'Add(Div(weight,Mul(x[0],x[1])),Div(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[2]),Mul(x[0],x[1])),Div(x[2],x[3]))',
#   [3.7263925306743233, 4.139259176553634, 3.0426362976875567, 0.81990181],
#   1.2476905621218866e-05),
#  ('Add(Div(weight,Pow(R,R)),Mul(R,R))',
#   'Add(Div(weight,Pow(x[0],x[1])),Mul(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[2]),Pow(x[0],x[1])),Mul(x[2],x[3]))',
#   [3.8623630930594777, 2.0202000000000004, 1.9118716429360845, 1.938573819],
#   1.247731313291053e-05),
#  ('Add(Add(R,R),Div(weight,Mul(R,R)))',
#   'Add(Add(x[0],x[1]),Div(weight,Mul(x[2],x[3])))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[2]),Mul(x[2],x[3])))',
#   [4.009442174918347,
#    -0.3071233929586537,
#    9.979856088248884,
#    1.5326837670870945],
#   1.2479402194032395e-05),
#  ('Add(Div(weight,Div(R,R)),R)',
#   'Add(Div(weight,Div(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Div((xdata[2]),Div(x[0],x[1])),x[2])',
#   [5.048986468103884, 0.3340567644286224, 3.6891322944998715],
#   1.2489924231342983e-05),
#  ('Add(Div(weight,Pow(R,R)),Div(R,R))',
#   'Add(Div(weight,Pow(x[0],x[1])),Div(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[2]),Pow(x[0],x[1])),Div(x[2],x[3]))',
#   [7.424885491622549,
#    1.3533210490930523,
#    4.116694753097414,
#    1.1185784542158985],
#   1.249750010572667e-05),
#  ('Add(Div(weight,Add(R,R)),Mul(R,R))',
#   'Add(Div(weight,Add(x[0],x[1])),Mul(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[2]),Add(x[0],x[1])),Mul(x[2],x[3]))',
#   [10.360670763482979, 4.480290059884532, 3.274718445798179, 1.120089789],
#   1.252141748947967e-05),
#  ('Add(Div(weight,Pow(R,R)),Pow(R,R))',
#   'Add(Div(weight,Pow(x[0],x[1])),Pow(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[2]),Pow(x[0],x[1])),Pow(x[2],x[3]))',
#   [1.8365436180000005,
#    4.420621033920001,
#    2.5789023339231325,
#    1.3662633690000001],
#   1.2551515479763777e-05),
#  ('Add(Add(R,R),Mul(R,weight))',
#   'Add(Add(x[0],x[1]),Mul(x[2],weight))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Mul(x[2],(xdata[2])))',
#   [0.6745677846513398, 2.9743319760286866, 0.06822048177456025],
#   1.2555691896869717e-05),
#  ('Add(Div(weight,Mul(R,R)),Pow(R,R))',
#   'Add(Div(weight,Mul(x[0],x[1])),Pow(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[2]),Mul(x[0],x[1])),Pow(x[2],x[3]))',
#   [3.9275042908443996,
#    3.648863783723681,
#    2.124301825484539,
#    1.7173417341717003],
#   1.2646950845729927e-05),
#  ('Add(Div(weight,Div(R,R)),Mul(R,R))',
#   'Add(Div(weight,Div(x[0],x[1])),Mul(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[2]),Div(x[0],x[1])),Mul(x[2],x[3]))',
#   [4.6639113453777234,
#    0.32952774676758967,
#    2.6464313247364113,
#    1.3533210490930518],
#   1.2726430481305298e-05),
#  ('Add(Div(R,R),Pow(height,R))',
#   'Add(Div(x[0],x[1]),Pow(height,x[2]))',
#   'lambda x,xdata:Add(Div(x[0],x[1]),Pow((xdata[1]),x[2]))',
#   [0.30817674644746235, 1.0509279559132438, 0.3397605693300001],
#   1.273084553298093e-05),
#  ('Add(Div(weight,Add(R,R)),Sub(R,R))',
#   'Add(Div(weight,Add(x[0],x[1])),Sub(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[2]),Add(x[0],x[1])),Sub(x[2],x[3]))',
#   [6.593147529062321, 7.22106634135397, 4.702649037127501, 1.1117768993886656],
#   1.2843471990428246e-05),
#  ('Add(Mul(Add(R,R),height),R)',
#   'Add(Mul(Add(x[0],x[1]),height),x[2])',
#   'lambda x,xdata:Add(Mul(Add(x[0],x[1]),(xdata[1])),x[2])',
#   [0.5495055000000001, -0.50505, 0.21313916866908245],
#   1.2865484693706821e-05),
#  ('Add(Pow(height,R),R)',
#   'Add(Pow(height,x[0]),x[1])',
#   'lambda x,xdata:Add(Pow((xdata[1]),x[0]),x[1])',
#   [0.3363633000000001, 0.341102408872801],
#   1.303569392688153e-05),
#  ('Add(Div(height,Div(R,R)),Mul(R,R))',
#   'Add(Div(height,Div(x[0],x[1])),Mul(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Div(x[0],x[1])),Mul(x[2],x[3]))',
#   [6.263928517453838,
#    0.2965853065759522,
#    0.18926758177814518,
#    0.42585205900082634],
#   1.3094090854458976e-05),
#  ('Add(Div(R,R),Mul(R,weight))',
#   'Add(Div(x[0],x[1]),Mul(x[2],weight))',
#   'lambda x,xdata:Add(Div(x[0],x[1]),Mul(x[2],(xdata[2])))',
#   [4.187763646687199, 1.1881199999999998, 0.07496756238962667],
#   1.3120382279514843e-05),
#  ('Pow(Div(height,Pow(R,R)),R)',
#   'Pow(Div(height,Pow(x[0],x[1])),x[2])',
#   'lambda x,xdata:Pow(Div((xdata[1]),Pow(x[0],x[1])),x[2])',
#   [2.261166784123514, 3.7000911012930233, 0.9819441311910256],
#   1.3201997739958447e-05),
#  ('Sub(Pow(weight,R),R)',
#   'Sub(Pow(weight,x[0]),x[1])',
#   'lambda x,xdata:Sub(Pow((xdata[2]),x[0]),x[1])',
#   [0.4757352224723507, -0.9073271318905091],
#   1.328437984022492e-05),
#  ('Add(Div(height,Mul(R,R)),Pow(R,R))',
#   'Add(Div(height,Mul(x[0],x[1])),Pow(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Mul(x[0],x[1])),Pow(x[2],x[3]))',
#   [2.9662396995365734,
#    7.073340821971832,
#    0.23443564678314197,
#    1.982913042206526],
#   1.3328371713909612e-05),
#  ('Pow(Add(R,age),R)',
#   'Pow(Add(x[0],age),x[1])',
#   'lambda x,xdata:Pow(Add(x[0],(xdata[0])),x[1])',
#   [5.1426550726686076, 0.6995964891624507],
#   1.333601270810812e-05),
#  ('Pow(Mul(R,height),R)',
#   'Pow(Mul(x[0],height),x[1])',
#   'lambda x,xdata:Pow(Mul(x[0],(xdata[1])),x[1])',
#   [2.08832973297121, 0.30303],
#   1.3545495568551727e-05),
#  ('Add(Pow(weight,R),R)',
#   'Add(Pow(weight,x[0]),x[1])',
#   'lambda x,xdata:Add(Pow((xdata[2]),x[0]),x[1])',
#   [0.4757352224723507, 0.8845730384784677],
#   1.3633431434528041e-05),
#  ('Add(Pow(height,Add(R,R)),R)',
#   'Add(Pow(height,Add(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Pow((xdata[1]),Add(x[0],x[1])),x[2])',
#   [0.2521339479062039, 0.08004061254661057, 0.4678216877091676],
#   1.3719014176228901e-05),
#  ('Add(Div(weight,R),Sub(R,R))',
#   'Add(Div(weight,x[0]),Sub(x[1],x[2]))',
#   'lambda x,xdata:Add(Div((xdata[2]),x[0]),Sub(x[1],x[2]))',
#   [12.558376245832989, 4.034780597067937, 0.5935883912343463],
#   1.3826834326082393e-05),
#  ('Mul(Div(height,Sub(R,R)),R)',
#   'Mul(Div(height,Sub(x[0],x[1])),x[2])',
#   'lambda x,xdata:Mul(Div((xdata[1]),Sub(x[0],x[1])),x[2])',
#   [7.099262391404585, -2.607360245390159, 0.46606262461935355],
#   1.3855753611682737e-05),
#  ('Div(Div(height,R),Add(R,R))',
#   'Div(Div(height,x[0]),Add(x[1],x[2]))',
#   'lambda x,xdata:Div(Div((xdata[1]),x[0]),Add(x[1],x[2]))',
#   [4.176241800000001, 1.4851500000000002, 3.500000000000001],
#   1.385592942332701e-05),
#  ('Mul(Div(height,Add(R,R)),R)',
#   'Mul(Div(height,Add(x[0],x[1])),x[2])',
#   'lambda x,xdata:Mul(Div((xdata[1]),Add(x[0],x[1])),x[2])',
#   [1.0101, 3.2000000000000006, 0.20202000000000003],
#   1.3855990342789245e-05),
#  ('Div(Div(height,Pow(R,R)),R)',
#   'Div(Div(height,Pow(x[0],x[1])),x[2])',
#   'lambda x,xdata:Div(Div((xdata[1]),Pow(x[0],x[1])),x[2])',
#   [2.5252500000000007, 2.3000000000000003, 2.47525],
#   1.3856036684308102e-05),
#  ('Mul(Div(height,Div(R,R)),R)',
#   'Mul(Div(height,Div(x[0],x[1])),x[2])',
#   'lambda x,xdata:Mul(Div((xdata[1]),Div(x[0],x[1])),x[2])',
#   [0.6121812059999999, 0.09901000000000003, 0.2970300000000001],
#   1.3856062812144338e-05),
#  ('Div(Div(height,R),Mul(R,R))',
#   'Div(Div(height,x[0]),Mul(x[1],x[2]))',
#   'lambda x,xdata:Div(Div((xdata[1]),x[0]),Mul(x[1],x[2]))',
#   [1.9802000000000008, 3.900000000000001, 2.7000000000000006],
#   1.3856751774380341e-05),
#  ('Mul(Div(height,R),Mul(R,R))',
#   'Mul(Div(height,x[0]),Mul(x[1],x[2]))',
#   'lambda x,xdata:Mul(Div((xdata[1]),x[0]),Mul(x[1],x[2]))',
#   [1.8352136873009608, 0.1273402503900283, 0.6926756810609993],
#   1.3856763933354667e-05),
#  ('Div(Div(height,Add(R,R)),R)',
#   'Div(Div(height,Add(x[0],x[1])),x[2])',
#   'lambda x,xdata:Div(Div((xdata[1]),Add(x[0],x[1])),x[2])',
#   [2.8000000000000007, 3.7000000000000006, 3.2000000000000006],
#   1.3857386141265118e-05),
#  ('Mul(Div(height,R),Pow(R,R))',
#   'Mul(Div(height,x[0]),Pow(x[1],x[2]))',
#   'lambda x,xdata:Mul(Div((xdata[1]),x[0]),Pow(x[1],x[2]))',
#   [2.456097460879174, 0.22944189259464556, 1.453312107029097],
#   1.3858099711955542e-05),
#  ('Div(Div(height,R),R)',
#   'Div(Div(height,x[0]),x[1])',
#   'lambda x,xdata:Div(Div((xdata[1]),x[0]),x[1])',
#   [5.260645295293502, 3.9661299000000017],
#   1.3858220236354073e-05),
#  ('Mul(Div(height,R),Div(R,R))',
#   'Mul(Div(height,x[0]),Div(x[1],x[2]))',
#   'lambda x,xdata:Mul(Div((xdata[1]),x[0]),Div(x[1],x[2]))',
#   [3.083577679742914, 1.5787555409372769, 10.682980729566347],
#   1.3858400300544658e-05),
#  ('Mul(Div(height,R),Sub(R,R))',
#   'Mul(Div(height,x[0]),Sub(x[1],x[2]))',
#   'lambda x,xdata:Mul(Div((xdata[1]),x[0]),Sub(x[1],x[2]))',
#   [2.079210000000001, 1.9999999999999996, 1.9000000000000006],
#   1.3858409335098127e-05),
#  ('Div(Mul(R,height),R)',
#   'Div(Mul(x[0],height),x[1])',
#   'lambda x,xdata:Div(Mul(x[0],(xdata[1])),x[1])',
#   [0.10101000000000003, 2.0999999999999996],
#   1.385871980811034e-05),
#  ('Div(Div(height,Div(R,R)),R)',
#   'Div(Div(height,Div(x[0],x[1])),x[2])',
#   'lambda x,xdata:Div(Div((xdata[1]),Div(x[0],x[1])),x[2])',
#   [2.0202, 0.30000000000000004, 3.1],
#   1.3859983565254525e-05),
#  ('Div(Div(height,R),Pow(R,R))',
#   'Div(Div(height,x[0]),Pow(x[1],x[2]))',
#   'lambda x,xdata:Div(Div((xdata[1]),x[0]),Pow(x[1],x[2]))',
#   [2.5252499999999998, 2.4999999999999996, 2.3],
#   1.3861217855085515e-05),
#  ('Mul(Div(height,R),R)',
#   'Mul(Div(height,x[0]),x[1])',
#   'lambda x,xdata:Mul(Div((xdata[1]),x[0]),x[1])',
#   [6.906699695843554, 0.3325014547008453],
#   1.386214540879795e-05),
#  ('Div(Div(height,R),Div(R,R))',
#   'Div(Div(height,x[0]),Div(x[1],x[2]))',
#   'lambda x,xdata:Div(Div((xdata[1]),x[0]),Div(x[1],x[2]))',
#   [3.5168352000000014, 1.8000000000000007, 0.30303000000000013],
#   1.3863054017253333e-05),
#  ('Mul(Add(R,R),Div(height,R))',
#   'Mul(Add(x[0],x[1]),Div(height,x[2]))',
#   'lambda x,xdata:Mul(Add(x[0],x[1]),Div((xdata[1]),x[2]))',
#   [0.8112417886299993, -0.6740232620400002, 2.849357932859062],
#   1.3863778090122335e-05),
#  ('Mul(Div(height,Pow(R,R)),R)',
#   'Mul(Div(height,Pow(x[0],x[1])),x[2])',
#   'lambda x,xdata:Mul(Div((xdata[1]),Pow(x[0],x[1])),x[2])',
#   [4.036359600000002, 1.5151500000000002, 0.3960399999999998],
#   1.3869705522555698e-05),
#  ('Div(Div(height,Mul(R,R)),R)',
#   'Div(Div(height,Mul(x[0],x[1])),x[2])',
#   'lambda x,xdata:Div(Div((xdata[1]),Mul(x[0],x[1])),x[2])',
#   [5.826931100335802, 2.1467640895974003, 1.65773288772],
#   1.3872595467582632e-05),
#  ('Add(Div(height,Div(R,R)),Div(R,R))',
#   'Add(Div(height,Div(x[0],x[1])),Div(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Div(x[0],x[1])),Div(x[2],x[3]))',
#   [4.182003784740217,
#    0.2036882066583,
#    -0.2840745045070194,
#    3.5845413678278932],
#   1.4642620108139064e-05),
#  ('Pow(Div(height,R),Mul(R,R))',
#   'Pow(Div(height,x[0]),Mul(x[1],x[2]))',
#   'lambda x,xdata:Pow(Div((xdata[1]),x[0]),Mul(x[1],x[2]))',
#   [0.3091821180903, 2.8000000000000003, 0.09999999999999998],
#   1.4793748631224553e-05),
#  ('Add(Div(height,Sub(R,R)),height)',
#   'Add(Div(height,Sub(x[0],x[1])),height)',
#   'lambda x,xdata:Add(Div((xdata[1]),Sub(x[0],x[1])),(xdata[1]))',
#   [1.030607060301, 2.0792100000000002],
#   1.4874946119030648e-05),
#  ('Add(Mul(Sub(R,R),weight),R)',
#   'Add(Mul(Sub(x[0],x[1]),weight),x[2])',
#   'lambda x,xdata:Add(Mul(Sub(x[0],x[1]),(xdata[2])),x[2])',
#   [1.4000000000000001, 1.3263926129999994, 3.3171488942942555],
#   1.489295127198897e-05),
#  ('Add(Div(height,Div(R,R)),Pow(R,R))',
#   'Add(Div(height,Div(x[0],x[1])),Pow(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Div(x[0],x[1])),Pow(x[2],x[3]))',
#   [7.751619291968417,
#    0.38000166251525186,
#    -0.3455311580611055,
#    2.1141448867560824],
#   1.4913889985831679e-05),
#  ('Add(Mul(R,weight),Pow(R,R))',
#   'Add(Mul(x[0],weight),Pow(x[1],x[2]))',
#   'lambda x,xdata:Add(Mul(x[0],(xdata[2])),Pow(x[1],x[2]))',
#   [0.08514354716306867, 4.43549159477728, 0.8069561194135872],
#   1.500157485420144e-05),
#  ('Add(Mul(R,R),Pow(height,R))',
#   'Add(Mul(x[0],x[1]),Pow(height,x[2]))',
#   'lambda x,xdata:Add(Mul(x[0],x[1]),Pow((xdata[1]),x[2]))',
#   [0.543177604561961, 1.5390032129255566, 0.31230485748301196],
#   1.599455398332117e-05),
#  ('Add(Pow(height,Div(R,R)),R)',
#   'Add(Pow(height,Div(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Pow((xdata[1]),Div(x[0],x[1])),x[2])',
#   [0.5730311267551269, 1.8352136873009608, 0.8474007143626996],
#   1.6045025711177087e-05),
#  ('Add(Pow(height,Sub(R,R)),R)',
#   'Add(Pow(height,Sub(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Pow((xdata[1]),Sub(x[0],x[1])),x[2])',
#   [1.2, 0.8910899999999995, 0.9144394972800611],
#   1.646661837450838e-05),
#  ('Add(Div(height,Add(R,R)),Div(R,R))',
#   'Add(Div(height,Add(x[0],x[1])),Div(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Add(x[0],x[1])),Div(x[2],x[3]))',
#   [12.558376245832989,
#    7.22106634135397,
#    0.45829791413729065,
#    7.848985153645619],
#   1.681128544239603e-05),
#  ('Sub(Div(height,R),height)',
#   'Sub(Div(height,x[0]),height)',
#   'lambda x,xdata:Sub(Div((xdata[1]),x[0]),(xdata[1]))',
#   [0.9514704449447013],
#   1.7171725483347613e-05),
#  ('Add(Add(R,R),Div(weight,Pow(R,R)))',
#   'Add(Add(x[0],x[1]),Div(weight,Pow(x[2],x[3])))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[2]),Pow(x[2],x[3])))',
#   [-0.34933486365052385, 3.421841210186395, 2.6989973201349184, 2.43736461558],
#   1.7273524533132487e-05),
#  ('Sub(Div(age,R),Add(R,R))',
#   'Sub(Div(age,x[0]),Add(x[1],x[2]))',
#   'lambda x,xdata:Sub(Div((xdata[0]),x[0]),Add(x[1],x[2]))',
#   [2.685688310395908, -0.9418782184374739, -2.1977158430207724],
#   1.7411032168681022e-05),
#  ('Add(Div(height,Mul(R,R)),Mul(R,R))',
#   'Add(Div(height,Mul(x[0],x[1])),Mul(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Mul(x[0],x[1])),Mul(x[2],x[3]))',
#   [6.412696819743366,
#    3.0261576815492304,
#    -0.42490993761568396,
#    0.8498198752313679],
#   1.7742029063467894e-05),
#  ('Add(Div(R,R),Mul(R,age))',
#   'Add(Div(x[0],x[1]),Mul(x[2],age))',
#   'lambda x,xdata:Add(Div(x[0],x[1]),Mul(x[2],(xdata[0])))',
#   [3.760265066138895, 1.1771512308341674, 0.3877905427315536],
#   1.8996595706107444e-05),
#  ('Add(Pow(height,Pow(R,R)),R)',
#   'Add(Pow(height,Pow(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Pow((xdata[1]),Pow(x[0],x[1])),x[2])',
#   [0.50505, 1.8441268134319002, 1.3579440114049017],
#   1.9433362164743238e-05),
#  ('Add(Div(height,Div(R,R)),Sub(R,R))',
#   'Add(Div(height,Div(x[0],x[1])),Sub(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Div(x[0],x[1])),Sub(x[2],x[3]))',
#   [1.6340783272957988,
#    0.0874495611453065,
#    1.350079599977761,
#    1.9203229442881302],
#   2.033068428427309e-05),
#  ('Div(Add(R,age),R)',
#   'Div(Add(x[0],age),x[1])',
#   'lambda x,xdata:Div(Add(x[0],(xdata[0])),x[1])',
#   [7.6521470617397185, 2.562588651306441],
#   2.0762571382569238e-05),
#  ('Add(Mul(R,age),R)',
#   'Add(Mul(x[0],age),x[1])',
#   'lambda x,xdata:Add(Mul(x[0],(xdata[0])),x[1])',
#   [0.3724838304890989, 2.8256346553124225],
#   2.3525059289150828e-05),
#  ('Sub(Div(age,Pow(R,R)),R)',
#   'Sub(Div(age,Pow(x[0],x[1])),x[2])',
#   'lambda x,xdata:Sub(Div((xdata[0]),Pow(x[0],x[1])),x[2])',
#   [1.4721426372034216, 2.5310080553011076, -2.8256346553124225],
#   2.3527563390016185e-05),
#  ('Pow(Div(weight,R),Div(R,R))',
#   'Pow(Div(weight,x[0]),Div(x[1],x[2]))',
#   'lambda x,xdata:Pow(Div((xdata[2]),x[0]),Div(x[1],x[2]))',
#   [0.7242368060826144, 0.7764744477607999, 1.5999999999999996],
#   2.5217140732955603e-05),
#  ('Pow(Div(weight,R),Sub(R,R))',
#   'Pow(Div(weight,x[0]),Sub(x[1],x[2]))',
#   'lambda x,xdata:Pow(Div((xdata[2]),x[0]),Sub(x[1],x[2]))',
#   [0.7242368060826145, 0.7999999999999999, 0.3123048574830121],
#   2.5295764011235825e-05),
#  ('Add(Add(R,R),Div(weight,Sub(R,R)))',
#   'Add(Add(x[0],x[1]),Div(weight,Sub(x[2],x[3])))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[2]),Sub(x[2],x[3])))',
#   [1.2467969975053532,
#    1.4026466221935214,
#    10.121264008255014,
#    0.3679734344270463],
#   2.5404648492724017e-05),
#  ('Add(Div(weight,Add(R,R)),R)',
#   'Add(Div(weight,Add(x[0],x[1])),x[2])',
#   'lambda x,xdata:Add(Div((xdata[2]),Add(x[0],x[1])),x[2])',
#   [5.0306299164103345, 4.082972093507292, 2.5116752491665966],
#   2.899824140656324e-05),
#  ('Sub(Div(height,Pow(R,R)),R)',
#   'Sub(Div(height,Pow(x[0],x[1])),x[2])',
#   'lambda x,xdata:Sub(Div((xdata[1]),Pow(x[0],x[1])),x[2])',
#   [2.929290000000001, 2.6262600000000007, 1.1597481901675244],
#   2.9131019878632678e-05),
#  ('Add(Div(age,weight),R)',
#   'Add(Div(age,weight),x[0])',
#   'lambda x,xdata:Add(Div((xdata[0]),(xdata[2])),x[0])',
#   [4.753549055537102],
#   3.154737667227577e-05),
#  ('Add(Div(age,weight),Div(R,R))',
#   'Add(Div(age,weight),Div(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[0]),(xdata[2])),Div(x[0],x[1]))',
#   [2.4000000000000004, 0.5050500000000001],
#   3.154743068784098e-05),
#  ('Add(Div(age,weight),Mul(R,R))',
#   'Add(Div(age,weight),Mul(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[0]),(xdata[2])),Mul(x[0],x[1]))',
#   [2.8000000000000007, 1.7000000000000004],
#   3.154889526633308e-05),
#  ('Add(Add(R,R),Div(age,weight))',
#   'Add(Add(x[0],x[1]),Div(age,weight))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[0]),(xdata[2])))',
#   [1.9581534145719008, 2.803027500000001],
#   3.1549478049005044e-05),
#  ('Add(Div(age,weight),Pow(R,R))',
#   'Add(Div(age,weight),Pow(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[0]),(xdata[2])),Pow(x[0],x[1]))',
#   [2.0202000000000004, 2.22222],
#   3.1558563978504426e-05),
#  ('Add(Div(weight,Sub(R,R)),Sub(R,R))',
#   'Add(Div(weight,Sub(x[0],x[1])),Sub(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[2]),Sub(x[0],x[1])),Sub(x[2],x[3]))',
#   [8.95301206223547,
#    0.5170155982027751,
#    3.139594061458243,
#    0.6698200283545025],
#   3.1680634398149716e-05),
#  ('Add(Div(height,Pow(R,R)),Div(R,R))',
#   'Add(Div(height,Pow(x[0],x[1])),Div(x[2],x[3]))',
#   'lambda x,xdata:Add(Div((xdata[1]),Pow(x[0],x[1])),Div(x[2],x[3]))',
#   [2.0782363130516086,
#    3.816775454206237,
#    -2.056413186074572,
#    1.4784229977315257],
#   3.289096895167491e-05),
#  ('Add(Div(weight,height),R)',
#   'Add(Div(weight,height),x[0])',
#   'lambda x,xdata:Add(Div((xdata[2]),(xdata[1])),x[0])',
#   [4.77868736459498],
#   3.331294524509817e-05),
#  ('Add(Add(R,R),Div(weight,height))',
#   'Add(Add(x[0],x[1]),Div(weight,height))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[2]),(xdata[1])))',
#   [2.2444974625931997, 2.5275872326500006],
#   3.331542323310267e-05),
#  ('Add(Div(weight,height),Div(R,R))',
#   'Add(Div(weight,height),Div(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[2]),(xdata[1])),Div(x[0],x[1]))',
#   [2.8422604070550843, 0.5931706131519044],
#   3.331665042937662e-05),
#  ('Add(Div(weight,height),Sub(R,R))',
#   'Add(Div(weight,height),Sub(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[2]),(xdata[1])),Sub(x[0],x[1]))',
#   [5.33730990447902, 0.5394871416291408],
#   3.332241938258205e-05),
#  ('Add(Div(weight,height),Mul(R,R))',
#   'Add(Div(weight,height),Mul(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[2]),(xdata[1])),Mul(x[0],x[1]))',
#   [1.8120563697600003, 2.626260000000001],
#   3.332914785856629e-05),
#  ('Add(Div(weight,height),Pow(R,R))',
#   'Add(Div(weight,height),Pow(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[2]),(xdata[1])),Pow(x[0],x[1]))',
#   [2.0999999999999996, 2.0999999999999996],
#   3.334589878369622e-05),
#  ('Pow(Pow(weight,R),R)',
#   'Pow(Pow(weight,x[0]),x[1])',
#   'lambda x,xdata:Pow(Pow((xdata[2]),x[0]),x[1])',
#   [0.2970300000000001, 1.782179999999999],
#   3.3428540054275164e-05),
#  ('Pow(weight,R)',
#   'Pow(weight,x[0])',
#   'lambda x,xdata:Pow((xdata[2]),x[0])',
#   [0.5280660969443095],
#   3.346179677291717e-05),
#  ('Add(Div(Add(R,R),age),R)',
#   'Add(Div(Add(x[0],x[1]),age),x[2])',
#   'lambda x,xdata:Add(Div(Add(x[0],x[1]),(xdata[0])),x[2])',
#   [-0.8080799999999999, 0.7999999999999995, 4.960660144766323],
#   3.552280332361509e-05),
#  ('Add(Add(R,R),Div(age,height))',
#   'Add(Add(x[0],x[1]),Div(age,height))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[0]),(xdata[1])))',
#   [1.8483348334815004, 3.069310000000001],
#   3.558248142037777e-05),
#  ('Add(Div(age,height),Mul(R,R))',
#   'Add(Div(age,height),Mul(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[0]),(xdata[1])),Mul(x[0],x[1]))',
#   [1.9802, 2.47525],
#   3.558679082033008e-05),
#  ('Add(Div(age,height),Pow(R,R))',
#   'Add(Div(age,height),Pow(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[0]),(xdata[1])),Pow(x[0],x[1]))',
#   [3.808457768850001, 1.18812],
#   3.5590268081065935e-05),
#  ('Add(Div(age,height),Div(R,R))',
#   'Add(Div(age,height),Div(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[0]),(xdata[1])),Div(x[0],x[1]))',
#   [3.8758096459842073, 0.7915149469059951],
#   3.559146374760901e-05),
#  ('Add(Div(age,height),R)',
#   'Add(Div(age,height),x[0])',
#   'lambda x,xdata:Add(Div((xdata[0]),(xdata[1])),x[0])',
#   [4.936024003152881],
#   3.5599043154100914e-05),
#  ('Add(Add(R,R),R)',
#   'Add(Add(x[0],x[1]),x[2])',
#   'lambda x,xdata:Add(Add(x[0],x[1]),x[2])',
#   [2.1999999999999997, 2.6999999999999997, 0.05116450852656725],
#   3.723781816532856e-05),
#  ('Add(Add(Add(R,R),R),R)',
#   'Add(Add(Add(x[0],x[1]),x[2]),x[3])',
#   'lambda x,xdata:Add(Add(Add(x[0],x[1]),x[2]),x[3])',
#   [1.2, 1.5, 2.2, 0.05116450852656725],
#   3.723781816532857e-05),
#  ('Add(Div(Add(R,R),R),Mul(R,R))',
#   'Add(Div(Add(x[0],x[1]),x[2]),Mul(x[3],x[4]))',
#   'lambda x,xdata:Add(Div(Add(x[0],x[1]),x[2]),Mul(x[3],x[4]))',
#   [0.5101510050000001, 1.8999999999999995, 0.90909, 0.9999999999999997, 2.3],
#   3.723781817016101e-05),
#  ('Sub(Div(Sub(R,R),R),R)',
#   'Sub(Div(Sub(x[0],x[1]),x[2]),x[3])',
#   'lambda x,xdata:Sub(Div(Sub(x[0],x[1]),x[2]),x[3])',
#   [5.196997800000001,
#    1.2421499999999992,
#    0.8280999999999993,
#    -0.175417282326364],
#   3.723781835807356e-05),
#  ('Add(Add(Pow(R,R),R),R)',
#   'Add(Add(Pow(x[0],x[1]),x[2]),x[3])',
#   'lambda x,xdata:Add(Add(Pow(x[0],x[1]),x[2]),x[3])',
#   [1.5684768159999996, 0.11101110111000004, 2.3, 1.5999999999999999],
#   3.723781840943195e-05),
#  ('Add(Add(R,R),Div(Mul(R,R),R))',
#   'Add(Add(x[0],x[1]),Div(Mul(x[2],x[3]),x[4]))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div(Mul(x[2],x[3]),x[4]))',
#   [1.617907473,
#    1.2457887542099997,
#    1.3689986309999997,
#    1.6650000000000003,
#    1.0919999999999994],
#   3.7237818543568446e-05),
#  ('Add(Div(Sub(R,R),R),Sub(R,R))',
#   'Add(Div(Sub(x[0],x[1]),x[2]),Sub(x[3],x[4]))',
#   'lambda x,xdata:Add(Div(Sub(x[0],x[1]),x[2]),Sub(x[3],x[4]))',
#   [1.6411571999999999,
#    0.15197393967646275,
#    2.1099988,
#    4.923471600000002,
#    0.6782138999999994],
#   3.723781862616414e-05),
#  ('Sub(R,R)',
#   'Sub(x[0],x[1])',
#   'lambda x,xdata:Sub(x[0],x[1])',
#   [5.424202201266903, 0.4729288688737308],
#   3.72378186739814e-05),
#  ('Add(Div(Div(R,R),Mul(R,R)),R)',
#   'Add(Div(Div(x[0],x[1]),Mul(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Div(x[0],x[1]),Mul(x[2],x[3])),x[4])',
#   [2.828280000000001,
#    0.8999999999999995,
#    2.2999999999999994,
#    1.2999999999999994,
#    3.900000000000001],
#   3.7237818777297145e-05),
#  ('Add(R,Sub(Div(R,R),R))',
#   'Add(x[0],Sub(Div(x[1],x[2]),x[3]))',
#   'lambda x,xdata:Add(x[0],Sub(Div(x[1],x[2]),x[3]))',
#   [3.187131900000001,
#    1.6650000000000003,
#    1.9001900189999992,
#    -0.8879999999999999],
#   3.7237819652868855e-05),
#  ('Add(Div(Mul(R,R),Mul(R,R)),R)',
#   'Add(Div(Mul(x[0],x[1]),Mul(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Mul(x[0],x[1]),Mul(x[2],x[3])),x[4])',
#   [2.2222199999999996, 1.9, 2.6, 0.4, 0.8910899999999999],
#   3.723782002267338e-05),
#  ('Add(Div(Add(R,R),R),R)',
#   'Add(Div(Add(x[0],x[1]),x[2]),x[3])',
#   'lambda x,xdata:Add(Div(Add(x[0],x[1]),x[2]),x[3])',
#   [2.62626, 1.1999999999999997, 0.9, 0.7000000000000001],
#   3.7237820274801184e-05),
#  ('Add(Div(age,age),Sub(R,R))',
#   'Add(Div(age,age),Sub(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[0]),(xdata[0])),Sub(x[0],x[1]))',
#   [3.68726043154811, -0.26363309147833797],
#   3.723782037936759e-05),
#  ('Mul(Div(Add(R,R),R),R)',
#   'Mul(Div(Add(x[0],x[1]),x[2]),x[3])',
#   'lambda x,xdata:Mul(Div(Add(x[0],x[1]),x[2]),x[3])',
#   [2.3, 0.4504955, 1.0, 1.7999999999999998],
#   3.723782040759109e-05),
#  ('Add(Div(Pow(R,R),Add(R,R)),R)',
#   'Add(Div(Pow(x[0],x[1]),Add(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Pow(x[0],x[1]),Add(x[2],x[3])),x[4])',
#   [0.5274997,
#    -0.455421123,
#    0.0692675681061001,
#    0.9937199999999995,
#    3.692603700000001],
#   3.7237821505355484e-05),
#  ('Add(Add(R,R),Div(Sub(R,R),R))',
#   'Add(Add(x[0],x[1]),Div(Sub(x[2],x[3]),x[4]))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div(Sub(x[2],x[3]),x[4]))',
#   [2.6, 2.5, 0.19802, 0.30303, 0.7070700000000001],
#   3.7237821973555555e-05),
#  ('Add(Div(Mul(R,R),Div(R,R)),R)',
#   'Add(Div(Mul(x[0],x[1]),Div(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Mul(x[0],x[1]),Div(x[2],x[3])),x[4])',
#   [0.7070700000000001, 2.4, 1.4, 2.6, 1.8],
#   3.723782259423519e-05),
#  ('Add(R,Sub(Sub(R,R),R))',
#   'Add(x[0],Sub(Sub(x[1],x[2]),x[3]))',
#   'lambda x,xdata:Add(x[0],Sub(Sub(x[1],x[2]),x[3]))',
#   [2.900000000000001, 1.5000000000000002, -0.5515146, 2.7755575615628914e-17],
#   3.723782265815563e-05),
#  ('Add(Pow(Div(R,R),R),R)',
#   'Add(Pow(Div(x[0],x[1]),x[2]),x[3])',
#   'lambda x,xdata:Add(Pow(Div(x[0],x[1]),x[2]),x[3])',
#   [0.8999999999999999, 0.6000000000000001, 2.9703, 1.61616],
#   3.723782327239443e-05),
#  ('Add(Div(Sub(R,R),Pow(R,R)),R)',
#   'Add(Div(Sub(x[0],x[1]),Pow(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Sub(x[0],x[1]),Pow(x[2],x[3])),x[4])',
#   [2.4865993315800012, 1.0037565719999995, 0.8281, 2.997, 2.340990000000001],
#   3.7237823495042945e-05),
#  ('Add(Div(Add(R,R),Div(R,R)),R)',
#   'Add(Div(Add(x[0],x[1]),Div(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Add(x[0],x[1]),Div(x[2],x[3])),x[4])',
#   [3.1, 3.1, 1.5, 1.1, 0.40404],
#   3.723782479920177e-05),
#  ('Add(Div(Pow(R,R),Div(R,R)),R)',
#   'Add(Div(Pow(x[0],x[1]),Div(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Pow(x[0],x[1]),Div(x[2],x[3])),x[4])',
#   [2.6999999999999997,
#    1.5999999999999999,
#    2.9000000000000004,
#    2.8,
#    0.21980220000000003],
#   3.7237825510153585e-05),
#  ('Add(Div(Sub(R,R),R),Mul(R,R))',
#   'Add(Div(Sub(x[0],x[1]),x[2]),Mul(x[3],x[4]))',
#   'lambda x,xdata:Add(Div(Sub(x[0],x[1]),x[2]),Mul(x[3],x[4]))',
#   [1.8870000000000005,
#    1.6161599999999992,
#    1.8625662190000007,
#    3.330000000000001,
#    1.443],
#   3.723782829647093e-05),
#  ('Add(Div(weight,weight),Sub(R,R))',
#   'Add(Div(weight,weight),Sub(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[2]),(xdata[2])),Sub(x[0],x[1]))',
#   [4.156472626103218, 0.20474145396282492],
#   3.7237829587762034e-05),
#  ('Add(Div(Sub(R,R),Add(R,R)),R)',
#   'Add(Div(Sub(x[0],x[1]),Add(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Sub(x[0],x[1]),Add(x[2],x[3])),x[4])',
#   [4.015338793239638,
#    0.5187541447472749,
#    1.5561068079999576,
#    0.997504364102537,
#    3.5812516941411014],
#   3.723783147582707e-05),
#  ('Add(Mul(Add(R,R),R),R)',
#   'Add(Mul(Add(x[0],x[1]),x[2]),x[3])',
#   'lambda x,xdata:Add(Mul(Add(x[0],x[1]),x[2]),x[3])',
#   [0.18021622162198203, 1.8999999999999995, 1.6999999999999997, 1.41414],
#   3.7237832106916224e-05),
#  ('Add(Div(Mul(R,R),Pow(R,R)),R)',
#   'Add(Div(Mul(x[0],x[1]),Pow(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Mul(x[0],x[1]),Pow(x[2],x[3])),x[4])',
#   [3.3000000000000003,
#    0.8999999999999999,
#    2.4242399999999997,
#    -0.20202,
#    1.4000000000000004],
#   3.7237832422601826e-05),
#  ('Mul(R,R)',
#   'Mul(x[0],x[1])',
#   'lambda x,xdata:Mul(x[0],x[1])',
#   [2.4752500000000004, 2.0000000000000004],
#   3.7237832437980116e-05),
#  ('Add(Mul(R,R),R)',
#   'Add(Mul(x[0],x[1]),x[2])',
#   'lambda x,xdata:Add(Mul(x[0],x[1]),x[2])',
#   [1.9801999999999995, 1.8999999999999995, 1.1881199999999996],
#   3.723783243798012e-05),
#  ('Add(R,R)',
#   'Add(x[0],x[1])',
#   'lambda x,xdata:Add(x[0],x[1])',
#   [2.77228, 2.1782199999999996],
#   3.723783243798012e-05),
#  ('Add(Div(Div(R,R),Div(R,R)),R)',
#   'Add(Div(Div(x[0],x[1]),Div(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Div(x[0],x[1]),Div(x[2],x[3])),x[4])',
#   [1.7423618940000003,
#    0.8189999999999993,
#    1.8199999999999992,
#    3.108000000000001,
#    1.3188132],
#   3.723783255192433e-05),
#  ('Sub(Div(Div(R,R),R),R)',
#   'Sub(Div(Div(x[0],x[1]),x[2]),x[3])',
#   'lambda x,xdata:Sub(Div(Div(x[0],x[1]),x[2]),x[3])',
#   [1.6698774509999998,
#    1.0286244149999995,
#    0.37678549999999983,
#    -0.6419115935679042],
#   3.723783306289644e-05),
#  ('Add(Div(Add(R,R),Mul(R,R)),R)',
#   'Add(Div(Add(x[0],x[1]),Mul(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Add(x[0],x[1]),Mul(x[2],x[3])),x[4])',
#   [3.5000000000000004,
#    2.8000000000000007,
#    1.8999999999999995,
#    1.6999999999999993,
#    3.000000000000001],
#   3.7237834045663916e-05),
#  ('Add(Div(Add(R,R),R),Sub(R,R))',
#   'Add(Div(Add(x[0],x[1]),x[2]),Sub(x[3],x[4]))',
#   'lambda x,xdata:Add(Div(Add(x[0],x[1]),x[2]),Sub(x[3],x[4]))',
#   [2.4242399999999993,
#    1.5999999999999996,
#    0.7999999999999999,
#    0.8080799999999999,
#    0.8879999999999999],
#   3.723783819906772e-05),
#  ('Add(Add(R,R),Div(Div(R,R),R))',
#   'Add(Add(x[0],x[1]),Div(Div(x[2],x[3]),x[4]))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div(Div(x[2],x[3]),x[4]))',
#   [1.5540000000000003,
#    2.2000000000000006,
#    3.219000000000001,
#    1.414139999999999,
#    1.899999999999999],
#   3.7237845566253507e-05),
#  ('Add(Div(Sub(R,R),Div(R,R)),R)',
#   'Add(Div(Sub(x[0],x[1]),Div(x[2],x[3])),x[4])',
#   'lambda x,xdata:Add(Div(Sub(x[0],x[1]),Div(x[2],x[3])),x[4])',
#   [2.3249727000000004,
#    0.8373002738099993,
#    1.0037565720000001,
#    2.3249726999999996,
# ...
#   0.3003048400343368),
#  ('Add(Pow(R,R),Sub(height,R))',
#   'Add(Pow(x[0],x[1]),Sub(height,x[2]))',
#   'lambda x,xdata:Add(Pow(x[0],x[1]),Sub((xdata[1]),x[2]))',
#   [1.4999999999999991, 1.3877787807814457e-16, 5.96522871677067],
#   0.3040280504144704),
#  ('Add(Div(R,R),height)',
#   'Add(Div(x[0],x[1]),height)',
#   'lambda x,xdata:Add(Div(x[0],x[1]),(xdata[1]))',
#   [-2.8256346553124225, 0.5993126569487648],
#   0.3055584098834502),
#  ('Add(Sub(age,R),height)',
#   'Add(Sub(age,x[0]),height)',
#   'lambda x,xdata:Add(Sub((xdata[0]),x[0]),(xdata[1]))',
#   [10.360660402812215],
#   0.3064911769922173),
#  ('Add(Mul(R,R),Sub(height,R))',
#   'Add(Mul(x[0],x[1]),Sub(height,x[2]))',
#   'lambda x,xdata:Add(Mul(x[0],x[1]),Sub((xdata[1]),x[2]))',
#   [0.42304422843442224, 0.49355159984015917, 4.70939109218737],
#   0.3068706733816094),
#  ('Add(Div(Add(R,R),R),height)',
#   'Add(Div(Add(x[0],x[1]),x[2]),height)',
#   'lambda x,xdata:Add(Div(Add(x[0],x[1]),x[2]),(xdata[1]))',
#   [-1.2558376245832987, -0.31395940614582424, 0.3525368570286855],
#   0.30716355985203675),
#  ('Add(Add(R,height),Sub(R,R))',
#   'Add(Add(x[0],height),Sub(x[1],x[2]))',
#   'lambda x,xdata:Add(Add(x[0],(xdata[1])),Sub(x[1],x[2]))',
#   [0.6345663426516336, 0.5640589712458965, 5.33730990447902],
#   0.30909497379731793),
#  ('Add(Sub(height,R),age)',
#   'Add(Sub(height,x[0]),age)',
#   'lambda x,xdata:Add(Sub((xdata[1]),x[0]),(xdata[0]))',
#   [9.418782184374743],
#   0.3122126204491204),
#  ('Add(Add(R,height),Pow(R,R))',
#   'Add(Add(x[0],height),Pow(x[1],x[2]))',
#   'lambda x,xdata:Add(Add(x[0],(xdata[1])),Pow(x[1],x[2]))',
#   [-2.5116752491665966, -0.31395940614582424, 0.31728317132581696],
#   0.3148799354021567),
#  ('Add(Add(Div(R,R),height),R)',
#   'Add(Add(Div(x[0],x[1]),height),x[2])',
#   'lambda x,xdata:Add(Add(Div(x[0],x[1]),(xdata[1])),x[2])',
#   [-0.9418782184374739, 0.42304422843442246, 0.49355159984015917],
#   0.32410615601871323),
#  ('Add(Add(Mul(R,R),height),R)',
#   'Add(Add(Mul(x[0],x[1]),height),x[2])',
#   'lambda x,xdata:Add(Add(Mul(x[0],x[1]),(xdata[1])),x[2])',
#   [0.24677579992007959, 0.3525368570286852, -1.2558376245832987],
#   0.32768215566596304),
#  ('Add(Add(R,height),R)',
#   'Add(Add(x[0],height),x[1])',
#   'lambda x,xdata:Add(Add(x[0],(xdata[1])),x[1])',
#   [-1.5697970307291234, 0.6345663426516336],
#   0.3291695401350167),
#  ('Add(Add(Pow(R,R),height),R)',
#   'Add(Add(Pow(x[0],x[1]),height),x[2])',
#   'lambda x,xdata:Add(Add(Pow(x[0],x[1]),(xdata[1])),x[2])',
#   [0.3525368570286852, 1.697077871058511, -0.6279188122916488],
#   0.33222286468619816),
#  ('Add(Add(Add(R,R),height),R)',
#   'Add(Add(Add(x[0],x[1]),height),x[2])',
#   'lambda x,xdata:Add(Add(Add(x[0],x[1]),(xdata[1])),x[2])',
#   [-0.6279188122916488, 1.3877787807814457e-16, 0.3525368570286852],
#   0.3333907162813721),
#  ('Add(Div(Div(R,R),R),height)',
#   'Add(Div(Div(x[0],x[1]),x[2]),height)',
#   'lambda x,xdata:Add(Div(Div(x[0],x[1]),x[2]),(xdata[1]))',
#   [1.3877787807814457e-16, 3.900000000000001, 2.2000000000000006],
#   0.33516109601120314),
#  ('Add(Div(Pow(R,R),R),height)',
#   'Add(Div(Pow(x[0],x[1]),x[2]),height)',
#   'lambda x,xdata:Add(Div(Pow(x[0],x[1]),x[2]),(xdata[1]))',
#   [0.10576105710860562, 6.907106935208142, 10.67461980895804],
#   0.335161096121185),
#  ('Add(Div(age,Pow(R,R)),height)',
#   'Add(Div(age,Pow(x[0],x[1])),height)',
#   'lambda x,xdata:Add(Div((xdata[0]),Pow(x[0],x[1])),(xdata[1]))',
#   [10.360660402812215, 7.5350257474997955],
#   0.33516109682370926),
#  ('Add(Div(Mul(R,R),R),height)',
#   'Add(Div(Mul(x[0],x[1]),x[2]),height)',
#   'lambda x,xdata:Add(Div(Mul(x[0],x[1]),x[2]),(xdata[1]))',
#   [0.3877905427315536, 0.17626842851434266, 8.790863372083091],
#   0.3352111590922164),
#  ('Add(Pow(height,R),height)',
#   'Add(Pow(height,x[0]),height)',
#   'lambda x,xdata:Add(Pow((xdata[1]),x[0]),(xdata[1]))',
#   [-0.9418782184374739],
#   0.33524477055087776),
#  ('Add(Div(age,Div(R,R)),height)',
#   'Add(Div(age,Div(x[0],x[1])),height)',
#   'lambda x,xdata:Add(Div((xdata[0]),Div(x[0],x[1])),(xdata[1]))',
#   [12.558376245832989, 0.31728317132581674],
#   0.33608084652013187),
#  ('Add(Div(age,Mul(R,R)),height)',
#   'Add(Div(age,Mul(x[0],x[1])),height)',
#   'lambda x,xdata:Add(Div((xdata[0]),Mul(x[0],x[1])),(xdata[1]))',
#   [4.081472279895721, 8.162944559791445],
#   0.33625394539109993),
#  ('Add(Pow(weight,R),height)',
#   'Add(Pow(weight,x[0]),height)',
#   'lambda x,xdata:Add(Pow((xdata[2]),x[0]),(xdata[1]))',
#   [-0.6279188122916488],
#   0.33629587597669336),
#  ('Add(Div(weight,Mul(R,R)),height)',
#   'Add(Div(weight,Mul(x[0],x[1])),height)',
#   'lambda x,xdata:Add(Div((xdata[2]),Mul(x[0],x[1])),(xdata[1]))',
#   [11.930457433541337, 7.848985153645619],
#   0.336722258349412),
#  ('Mul(Div(weight,R),weight)',
#   'Mul(Div(weight,x[0]),weight)',
#   'lambda x,xdata:Mul(Div((xdata[2]),x[0]),(xdata[2]))',
#   [9.418782184374743],
#   0.33723677333171925),
#  ('Add(Div(weight,Pow(R,R)),height)',
#   'Add(Div(weight,Pow(x[0],x[1])),height)',
#   'lambda x,xdata:Add(Div((xdata[2]),Pow(x[0],x[1])),(xdata[1]))',
#   [5.023350498333195, 2.5116752491665966],
#   0.33769978320308935),
#  ('Add(Div(height,Pow(R,R)),height)',
#   'Add(Div(height,Pow(x[0],x[1])),height)',
#   'lambda x,xdata:Add(Div((xdata[1]),Pow(x[0],x[1])),(xdata[1]))',
#   [4.395431686041545, 3.7675128737498955],
#   0.3378278207185721),
#  ('Add(Div(age,Add(R,R)),height)',
#   'Add(Div(age,Add(x[0],x[1])),height)',
#   'lambda x,xdata:Add(Div((xdata[0]),Add(x[0],x[1])),(xdata[1]))',
#   [6.593147529062321, 6.907106935208142],
#   0.33786199156482943),
#  ('Add(R,height)',
#   'Add(x[0],height)',
#   'lambda x,xdata:Add(x[0],(xdata[1]))',
#   [0.5993126569487648],
#   0.33903169434748953),
#  ('Add(Add(R,height),Mul(R,R))',
#   'Add(Add(x[0],height),Mul(x[1],x[2]))',
#   'lambda x,xdata:Add(Add(x[0],(xdata[1])),Mul(x[1],x[2]))',
#   [0.42304422843442224, 0.7050737140573706, 0.3525368570286852],
#   0.33950025282827295),
#  ('Add(Add(R,height),Div(R,R))',
#   'Add(Add(x[0],height),Div(x[1],x[2]))',
#   'lambda x,xdata:Add(Add(x[0],(xdata[1])),Div(x[1],x[2]))',
#   [0.6698200283545018, 0.5640589712458965, 10.360660402812215],
#   0.3398417296831876),
#  ('Add(Pow(age,R),height)',
#   'Add(Pow(age,x[0]),height)',
#   'lambda x,xdata:Add(Pow((xdata[0]),x[0]),(xdata[1]))',
#   [-0.4206121820581207],
#   0.33990886460022307),
#  ('Add(Add(R,height),Add(R,R))',
#   'Add(Add(x[0],height),Add(x[1],x[2]))',
#   'lambda x,xdata:Add(Add(x[0],(xdata[1])),Add(x[1],x[2]))',
#   [0.17626842851434266, 0.5640589712458965, 0.24677579992007959],
#   0.3415491443439048),
#  ('Add(Div(age,R),height)',
#   'Add(Div(age,x[0]),height)',
#   'lambda x,xdata:Add(Div((xdata[0]),x[0]),(xdata[1]))',
#   [5.023350498333195],
#   0.3424494031156157),
#  ('Add(Div(weight,Add(R,R)),height)',
#   'Add(Div(weight,Add(x[0],x[1])),height)',
#   'lambda x,xdata:Add(Div((xdata[2]),Add(x[0],x[1])),(xdata[1]))',
#   [5.651269310624847, 10.360660402812215],
#   0.3443496903181315),
#  ('Add(Div(weight,Sub(R,R)),height)',
#   'Add(Div(weight,Sub(x[0],x[1])),height)',
#   'lambda x,xdata:Add(Div((xdata[2]),Sub(x[0],x[1])),(xdata[1]))',
#   [12.558376245832989, -2.5116752491665966],
#   0.34492866395148564),
#  ('Add(Mul(R,age),height)',
#   'Add(Mul(x[0],age),height)',
#   'lambda x,xdata:Add(Mul(x[0],(xdata[0])),(xdata[1]))',
#   [0.3525368570286852],
#   0.3481325443388477),
#  ('Add(Div(weight,R),height)',
#   'Add(Div(weight,x[0]),height)',
#   'lambda x,xdata:Add(Div((xdata[2]),x[0]),(xdata[1]))',
#   [10.988579215103861],
#   0.34859720084124574),
#  ('Add(Div(height,Div(R,R)),height)',
#   'Add(Div(height,Div(x[0],x[1])),height)',
#   'lambda x,xdata:Add(Div((xdata[1]),Div(x[0],x[1])),(xdata[1]))',
#   [9.732741590520565, 0.24677579992007959],
#   0.3532514094486637),
#  ('Add(Div(height,Mul(R,R)),height)',
#   'Add(Div(height,Mul(x[0],x[1])),height)',
#   'lambda x,xdata:Add(Div((xdata[1]),Mul(x[0],x[1])),(xdata[1]))',
#   [5.96522871677067, 3.7675128737498955],
#   0.36722262109559967),
#  ('Add(Add(R,height),age)',
#   'Add(Add(x[0],height),age)',
#   'lambda x,xdata:Add(Add(x[0],(xdata[1])),(xdata[0]))',
#   [0.42304422843442224],
#   0.37558599528664555),
#  ('Add(Add(age,height),R)',
#   'Add(Add(age,height),x[0])',
#   'lambda x,xdata:Add(Add((xdata[0]),(xdata[1])),x[0])',
#   [0.49355159984015917],
#   0.3760636407283925),
#  ('Add(Add(R,age),height)',
#   'Add(Add(x[0],age),height)',
#   'lambda x,xdata:Add(Add(x[0],(xdata[0])),(xdata[1]))',
#   [0.7050737140573706],
#   0.3774985944859319),
#  ('Add(Div(height,Add(R,R)),height)',
#   'Add(Div(height,Add(x[0],x[1])),height)',
#   'lambda x,xdata:Add(Div((xdata[1]),Add(x[0],x[1])),(xdata[1]))',
#   [9.10482277822892, 4.70939109218737],
#   0.38806807095970686),
#  ('Add(Sub(weight,R),height)',
#   'Add(Sub(weight,x[0]),height)',
#   'lambda x,xdata:Add(Sub((xdata[2]),x[0]),(xdata[1]))',
#   [12.24441683968716],
#   0.40979541997544344),
#  ('Add(Sub(height,R),weight)',
#   'Add(Sub(height,x[0]),weight)',
#   'lambda x,xdata:Add(Sub((xdata[1]),x[0]),(xdata[2]))',
#   [11.930457433541337],
#   0.4119625031123002),
#  ('Add(Div(height,R),height)',
#   'Add(Div(height,x[0]),height)',
#   'lambda x,xdata:Add(Div((xdata[1]),x[0]),(xdata[1]))',
#   [6.907106935208142],
#   0.444850733956718),
#  ('Add(Mul(R,height),height)',
#   'Add(Mul(x[0],height),height)',
#   'lambda x,xdata:Add(Mul(x[0],(xdata[1])),(xdata[1]))',
#   [0.17626842851434266],
#   0.4707614332234756),
#  ('Add(Add(R,height),weight)',
#   'Add(Add(x[0],height),weight)',
#   'lambda x,xdata:Add(Add(x[0],(xdata[1])),(xdata[2]))',
#   [-0.6279188122916488],
#   0.4944176691063833),
#  ('Add(Add(height,weight),R)',
#   'Add(Add(height,weight),x[0])',
#   'lambda x,xdata:Add(Add((xdata[1]),(xdata[2])),x[0])',
#   [0.0705073714057371],
#   0.49979633836751675),
#  ('Add(Add(R,weight),height)',
#   'Add(Add(x[0],weight),height)',
#   'lambda x,xdata:Add(Add(x[0],(xdata[2])),(xdata[1]))',
#   [0.5288052855430276],
#   0.5033436769223586),
#  ('Mul(Div(height,R),age)',
#   'Mul(Div(height,x[0]),age)',
#   'lambda x,xdata:Mul(Div((xdata[1]),x[0]),(xdata[0]))',
#   [4.395431686041545],
#   1.0877327285711877),
#  ('Add(Sub(height,R),height)',
#   'Add(Sub(height,x[0]),height)',
#   'lambda x,xdata:Add(Sub((xdata[1]),x[0]),(xdata[1]))',
#   [7.848985153645619],
#   1.3074526288224548),
#  ('Add(Add(height,height),R)',
#   'Add(Add(height,height),x[0])',
#   'lambda x,xdata:Add(Add((xdata[1]),(xdata[1])),x[0])',
#   [-2.8256346553124225],
#   1.3720033760243138),
#  ('Add(Add(R,height),height)',
#   'Add(Add(x[0],height),height)',
#   'lambda x,xdata:Add(Add(x[0],(xdata[1])),(xdata[1]))',
#   [0.14101474281147414],
#   1.4109268375503332),
#  ('Add(Mul(age,weight),R)',
#   'Add(Mul(age,weight),x[0])',
#   'lambda x,xdata:Add(Mul((xdata[0]),(xdata[2])),x[0])',
#   [0.7050737140573706],
#   1.6153707399721462),
#  ('Mul(Div(weight,R),height)',
#   'Mul(Div(weight,x[0]),height)',
#   'lambda x,xdata:Mul(Div((xdata[2]),x[0]),(xdata[1]))',
#   [10.67461980895804],
#   2.8533749996485978),
#  ('Div(Div(height,R),age)',
#   'Div(Div(height,x[0]),age)',
#   'lambda x,xdata:Div(Div((xdata[1]),x[0]),(xdata[0]))',
#   [4.081472279895721],
#   2.907262832638069),
#  ('Div(Div(height,age),R)',
#   'Div(Div(height,age),x[0])',
#   'lambda x,xdata:Div(Div((xdata[1]),(xdata[0])),x[0])',
#   [4.081472279895721],
#   2.9072628326380707),
#  ('Mul(Div(height,R),weight)',
#   'Mul(Div(height,x[0]),weight)',
#   'lambda x,xdata:Mul(Div((xdata[1]),x[0]),(xdata[2]))',
#   [9.418782184374743],
#   3.67719212701805),
#  ('Mul(Div(height,age),R)',
#   'Mul(Div(height,age),x[0])',
#   'lambda x,xdata:Mul(Div((xdata[1]),(xdata[0])),x[0])',
#   [0.3877905427315536],
#   7.291815762721118),
#  ('Add(Mul(age,height),R)',
#   'Add(Mul(age,height),x[0])',
#   'lambda x,xdata:Add(Mul((xdata[0]),(xdata[1])),x[0])',
#   [0.5640589712458965],
#   21.777790478760778),
#  ('Add(Mul(weight,weight),R)',
#   'Add(Mul(weight,weight),x[0])',
#   'lambda x,xdata:Add(Mul((xdata[2]),(xdata[2])),x[0])',
#   [0.17626842851434266],
#   31.65933035826738),
#  ('Sub(Div(height,age),R)',
#   'Sub(Div(height,age),x[0])',
#   'lambda x,xdata:Sub(Div((xdata[1]),(xdata[0])),x[0])',
#   [12.24441683968716],
#   48.40648812225706),
#  ('Add(Div(height,age),Mul(R,R))',
#   'Add(Div(height,age),Mul(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[1]),(xdata[0])),Mul(x[0],x[1]))',
#   [-2.1977158430207724, 5.33730990447902],
#   48.41249661355833),
#  ('Add(Div(height,age),Sub(R,R))',
#   'Add(Div(height,age),Sub(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[1]),(xdata[0])),Sub(x[0],x[1]))',
#   [-0.31395940614582424, 5.023350498333195],
#   48.488640556039044),
#  ('Add(Add(R,R),Div(height,age))',
#   'Add(Add(x[0],x[1]),Div(height,age))',
#   'lambda x,xdata:Add(Add(x[0],x[1]),Div((xdata[1]),(xdata[0])))',
#   [-1.8837564368749478, -2.1977158430207724],
#   48.50392404236065),
#  ('Add(Div(height,age),Div(R,R))',
#   'Add(Div(height,age),Div(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[1]),(xdata[0])),Div(x[0],x[1]))',
#   [0.31728317132581674, 9.418782184374743],
#   48.554752796319974),
#  ('Add(Div(height,age),R)',
#   'Add(Div(height,age),x[0])',
#   'lambda x,xdata:Add(Div((xdata[1]),(xdata[0])),x[0])',
#   [0.3525368570286852],
#   48.55873892043806),
#  ('Add(Div(height,age),Pow(R,R))',
#   'Add(Div(height,age),Pow(x[0],x[1]))',
#   'lambda x,xdata:Add(Div((xdata[1]),(xdata[0])),Pow(x[0],x[1]))',
#   [1.9999999999999991, 1.3877787807814457e-16],
#   48.56685436543456),
#  ('Mul(Div(height,R),height)',
#   'Mul(Div(height,x[0]),height)',
#   'lambda x,xdata:Mul(Div((xdata[1]),x[0]),(xdata[1]))',
#   [5.96522871677067],
#   149.91820595994182),
#  ('Add(Mul(height,weight),R)',
#   'Add(Mul(height,weight),x[0])',
#   'lambda x,xdata:Add(Mul((xdata[1]),(xdata[2])),x[0])',
#   [0.0705073714057371],
#   333.5475452758429),
#  ('Add(Mul(height,height),R)',
#   'Add(Mul(height,height),x[0])',
#   'lambda x,xdata:Add(Mul((xdata[1]),(xdata[1])),x[0])',
#   [-0.9418782184374739],
#   5354.098277570058),
#  ('Add(Pow(age,age),R)',
#   'Add(Pow(age,age),x[0])',
#   'lambda x,xdata:Add(Pow((xdata[0]),(xdata[0])),x[0])',
#   [-0.8691200817967196],
#   1.69989280438068e+22),
#  ('Pow(Div(height,R),age)',
#   'Pow(Div(height,x[0]),age)',
#   'lambda x,xdata:Pow(Div((xdata[1]),x[0]),(xdata[0]))',
#   [10.988579215103861],
#   5.0016298035430786e+23),
#  ('Pow(Div(weight,R),age)',
#   'Pow(Div(weight,x[0]),age)',
#   'lambda x,xdata:Pow(Div((xdata[2]),x[0]),(xdata[0]))',
#   [7.5350257474997955],
#   4.0511096489485103e+24),
#  ('Add(Pow(weight,age),R)',
#   'Add(Pow(weight,age),x[0])',
#   'lambda x,xdata:Add(Pow((xdata[2]),(xdata[0])),x[0])',
#   [2.8],
#   7.466827623784758e+46),
#  ('Add(Pow(height,age),R)',
#   'Add(Pow(height,age),x[0])',
#   'lambda x,xdata:Add(Pow((xdata[1]),(xdata[0])),x[0])',
#   [0.2],
#   3.1343842124909563e+50),
#  ('Pow(Div(age,R),height)',
#   'Pow(Div(age,x[0]),height)',
#   'lambda x,xdata:Pow(Div((xdata[0]),x[0]),(xdata[1]))',
#   [8.790863372083091],
#   1.7090771368837505e+51),
#  ('Add(Pow(age,height),R)',
#   'Add(Pow(age,height),x[0])',
#   'lambda x,xdata:Add(Pow((xdata[0]),(xdata[1])),x[0])',
#   [0.9],
#   inf),
#  ('Add(Pow(age,weight),R)',
#   'Add(Pow(age,weight),x[0])',
#   'lambda x,xdata:Add(Pow((xdata[0]),(xdata[2])),x[0])',
#   [0.9],
#   inf),
#  ('Add(Pow(height,height),R)',
#   'Add(Pow(height,height),x[0])',
#   'lambda x,xdata:Add(Pow((xdata[1]),(xdata[1])),x[0])',
#   [1.9],
#   inf),
#  ('Add(Pow(height,weight),R)',
#   'Add(Pow(height,weight),x[0])',
#   'lambda x,xdata:Add(Pow((xdata[1]),(xdata[2])),x[0])',
#   [0.1],
#   inf),
#  ('Add(Pow(weight,height),R)',
#   'Add(Pow(weight,height),x[0])',
#   'lambda x,xdata:Add(Pow((xdata[2]),(xdata[1])),x[0])',
#   [1.3],
#   inf),
#  ('Add(Pow(weight,weight),R)',
#   'Add(Pow(weight,weight),x[0])',
#   'lambda x,xdata:Add(Pow((xdata[2]),(xdata[2])),x[0])',
#   [1.6],
#   inf),
#  ('Pow(Div(age,R),weight)',
#   'Pow(Div(age,x[0]),weight)',
#   'lambda x,xdata:Pow(Div((xdata[0]),x[0]),(xdata[2]))',
#   [0.5],
#   inf),
#  ('Pow(Div(height,R),height)',
#   'Pow(Div(height,x[0]),height)',
#   'lambda x,xdata:Pow(Div((xdata[1]),x[0]),(xdata[1]))',
#   [2.3],
#   inf),
#  ('Pow(Div(height,R),weight)',
#   'Pow(Div(height,x[0]),weight)',
#   'lambda x,xdata:Pow(Div((xdata[1]),x[0]),(xdata[2]))',
#   [1.9],
#   inf),
#  ('Pow(Div(weight,R),height)',
#   'Pow(Div(weight,x[0]),height)',
#   'lambda x,xdata:Pow(Div((xdata[2]),x[0]),(xdata[1]))',
#   [1.7],
#   inf),
#  ('Pow(Div(weight,R),weight)',
#   'Pow(Div(weight,x[0]),weight)',
#   'lambda x,xdata:Pow(Div((xdata[2]),x[0]),(xdata[2]))',
#   [0.2],
#   inf)]

# %%
import tenseal as ts

# controls precision of the fractional part
bits_scale = 40
multiplicative_depth = 7

# Create TenSEAL context
context = ts.context(
    ts.SCHEME_TYPE.CKKS,
    poly_modulus_degree=16384,
    coeff_mod_bit_sizes=[bits_scale+20] + [bits_scale]*multiplicative_depth + [bits_scale+20]
)

# set the scale
context.generate_galois_keys()
context.global_scale = pow(2, bits_scale)

def cost(x, xdata, ydata, lambda_string): 
    y_pred = eval(lambda_string)(x, xdata)
    return (((y_pred - ydata))**2).sum()

def Pow(op1, op2):
    if type(op1)==ts.tensors.ckksvector.CKKSVector:
        op1 = op1.decrypt()
    if type(op2)==ts.tensors.ckksvector.CKKSVector:
        op2 = op2.decrypt()
    if (not isinstance(op1, Iterable)) and (not isinstance(op2, Iterable)):
        if op1>0:
            return ts.ckks_vector(context, [op1**op2])
        else:
            return ts.ckks_vector(context, [-((-op1)**op2)])
    if not isinstance(op1, Iterable):
        op1 = [op1]*len(op2)
    elif len(op1) == 1:
        op1 = [op1[0]]*len(op2)
    if not isinstance(op2, Iterable):
        op2 = [op2]*len(op1)
    elif len(op2) == 1:
        op2 = [op2[0]]*len(op1)
    temp_list = []
    for i, j in zip(op1,op2):
        if i>0:
            temp_list.append(i**j)
        else:
            temp_list.append(-((-i)**j))
    return ts.ckks_vector(context,temp_list)

def Mul(op1, op2):
    return op1 * op2

def Add(op1, op2):
    return op1 + op2

def Sub(op1, op2):
    return op1 - op2

def Div(op1, op2):
    if type(op1)==ts.tensors.ckksvector.CKKSVector:
        op1 = np.array(op1.decrypt())
    if type(op2)==ts.tensors.ckksvector.CKKSVector:
        op2 = np.array(op2.decrypt())
    if isinstance(op1, Iterable) or isinstance(op2, Iterable):
        return ts.ckks_vector(context, op1 / op2)
    else:
        return ts.ckks_vector(context, [op1 / op2])
    
def random_constant():
        return np.random.randint(1, 31)/10
    
X, y = np.array(df.iloc[:5000,:-1]).T, np.array(df.iloc[:5000,-1]).astype(float)
X1 = [ts.ckks_vector(context, x.tolist()) for x in X]
y1 = ts.ckks_vector(context, y)

num_of_feature = X.shape[1]
mse_tuple = tuple()
np.random.seed(0)
master_list = []
for repeat_trial in range(1):
    for test_eq in ['Add(Pow(age,R),Pow(R,R))']:
        test_eq_orig = test_eq
        R_count = test_eq.count("R")
        if R_count==0:
            continue
        lambda_string = "lambda x,xdata:"
        index = 0    
        for i in range(R_count):
            test_eq = test_eq.replace("R", f"x[{i}]", 1)
        lambda_string += test_eq
        optimized_cost = 0
        ypred =[]
        ytrue =[]
        lambda_string_list = []
        res_x_list =[]
        x0_base = [random_constant() for i in range(R_count)]
        x0_base = [ts.ckks_vector(context,[i]) for i in x0_base]
        try:
            for xdata, ydata in zip([X1],[y1]):
                lambda_string_new = lambda_string.replace("height","(xdata[1])")
                lambda_string_new = lambda_string_new.replace("age","(xdata[0])")
                lambda_string_new = lambda_string_new.replace("weight","(xdata[2])")
                x0 = x0_base.copy()
                cur_cost = cost(x0, xdata, ydata, lambda_string_new)
                for step_perc, rounds, absolute in zip([0.1, 0.1, 0.01],[10,10,10],[True, False, False]):
                    for _ in tqdm(range(rounds)):
                        for x0_idx in range(len(x0)):
                            test_x0 = x0.copy()
                            if absolute:
                                test_x0[x0_idx] = x0[x0_idx]+step_perc
                            else:
                                test_x0[x0_idx] = x0[x0_idx]*(1+step_perc)
                            new_cost = cost(test_x0, xdata, ydata, lambda_string_new)
                            if absolute:
                                outcome = ts.ckks_vector(context, [step_perc*(new_cost.decrypt()[0]<cur_cost.decrypt()[0])])                              
                            else:
                                outcome = ts.ckks_vector(context, [x0[x0_idx].decrypt()[0]*step_perc*(new_cost.decrypt()[0]<cur_cost.decrypt()[0])])
                            x0[x0_idx] = x0[x0_idx] + outcome
                            cur_cost = cost(x0, xdata, ydata, lambda_string_new)

                        for x0_idx in range(len(x0)):
                            test_x0 = x0.copy()
                            if absolute:
                                test_x0[x0_idx] = x0[x0_idx]-step_perc
                            else:
                                test_x0[x0_idx] = x0[x0_idx]*(1-step_perc)
                            new_cost = cost(test_x0, xdata, ydata, lambda_string_new)
                            if absolute:
                                outcome = ts.ckks_vector(context, [step_perc*(new_cost.decrypt()[0]<cur_cost.decrypt()[0])])                              
                            else:
                                outcome = ts.ckks_vector(context, [x0[x0_idx].decrypt()[0]*step_perc*(new_cost.decrypt()[0]<cur_cost.decrypt()[0])])
                            x0[x0_idx] = x0[x0_idx] - outcome
                            cur_cost = cost(x0, xdata, ydata, lambda_string_new)
                            
                res_x_list.append([i.decrypt() for i in x0])                          
                optimized_cost_temp = cost(x0, xdata, ydata, lambda_string_new)
                optimized_cost+=optimized_cost_temp
                lambda_string_list.append(lambda_string_new)
            ypred = np.array(ypred)
            ytrue = np.array(ytrue)
            optimized_cost = optimized_cost*(1/len(y))
            master_list.append((test_eq_orig,test_eq,lambda_string_list,res_x_list,optimized_cost))
        except RuntimeError:
            print("No fit found")
print(master_list)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:54<00:00, 11.47s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:55<00:00, 11.55s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:56<00:00, 11.61s/it]
# [('Add(Pow(age,R),Pow(R,R))', 'Add(Pow(age,x[0]),Pow(x[1],x[2]))', ['lambda x,xdata:Add(Pow((xdata[0]),x[0]),Pow(x[1],x[2]))'], [[[0.49828212964937485], [1.6000000056191943], [2.4037952693075675]]], <tenseal.tensors.ckksvector.CKKSVector object at 0x0000014157A26DF0>)]
